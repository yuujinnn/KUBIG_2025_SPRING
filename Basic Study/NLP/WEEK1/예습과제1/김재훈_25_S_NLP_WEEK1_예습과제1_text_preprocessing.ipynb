# %% [markdown]
# ##0. GOAL
# 승현은 부쩍 헬스에 관심이 많이 생겼다고 합니다.
# 주변 헬스인들에게 이 사실을 알리니, 프로틴 보충제 사이트를 추천해주더군요.
#
# 며칠 전 텍스트 전처리를 배운 동주는 해당 사이트에서 보충제 리뷰를 크롤링해와 워드클라우드를 그려보기로 결심합니다.
#
# 파이프라인은 다음과 같습니다.
#
#  1. 정규표현식으로 한글만 추린다
#  2. 띄어쓰기를 교정한다(PyKospacing)
#  3. 형태소로 토큰화한다(okt)
#  4. 불용어를 제거한다
#  5. 원하는 단어를 Konlpy 사전에 추가한다
#  6. 워드클라우드를 그린다

# %% [markdown]
# ##1. import, load data

# %%
# !pip install konlpy
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-imeotxf8
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-imeotxf8
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit b32a889cbd10b006d2f4aba118f0cd5b677e2979
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=2.16.2 in /usr/local/lib/python3.10/dist-packages (from pykospacing==0.5) (2.17.1)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from pykospacing==0.5) (3.12.1)
# Collecting argparse>=1.1.0 (from pykospacing==0.5)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from h5py>=3.10.0->pykospacing==0.5) (1.26.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.16.2->pykospacing==0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (0.1.2)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import pandas as pd
import numpy as np
import re
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/KU-BIG/KUBIG_2024_SPRING/main/BASIC%20STUDY/NLP/WEEK1/protein.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            title  \
# 0           0  처음 사먹어 보는데 맛있네요
# 1           1   말해 뭐합니까 ㅋㅋㅋ 역시
# 2           2              좋넹요
# 3           3         매우 만족합니다
# 4           4             마싯어요
#
#                                              content  \
# 0                              맛이 좋아서 꾸준히 먹고 있습니다.^^
# 1  가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있습니다요! \n\n    ...
# 2              맛있습니다. 저번에 말차라떼도 먹어봤는데 그것보다 더 나은거 같네요
# 3  5키로는 정말 엄청크네요.\n    평점이 좋아서 스트로베리크림으로 주문했는데 좋습...
# 4                   약간 달긴 하지만 물에 잘 녹고 가루날림이 거의없어 좋아요
#
#                                                 text
# 0               처음 사먹어 보는데 맛있네요맛이 좋아서 꾸준히 먹고 있습니다.^^
# 1  말해 뭐합니까 ㅋㅋㅋ 역시가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있...
# 2           좋넹요맛있습니다. 저번에 말차라떼도 먹어봤는데 그것보다 더 나은거 같네요
# 3  매우 만족합니다5키로는 정말 엄청크네요.\n    평점이 좋아서 스트로베리크림으로 ...
# 4               마싯어요약간 달긴 하지만 물에 잘 녹고 가루날림이 거의없어 좋아요

# %% [markdown]
# ## 2. 정규표현식으로 한글 단어만 남기기
#
# 이제 정규표현식으로 한글 단어만 남기고 모두 제외합니다.

# %%
def extract_hangul(text):
  hangul = re.sub('[^가-힣]', ' ', text)
  return hangul

# %%
example = extract_hangul(df['text'][1])
print("전처리 이전: ",df['text'][1])
print("전처리 이후: ",example)
# Out:
# 전처리 이전:  말해 뭐합니까 ㅋㅋㅋ 역시가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있습니다요!
#
#     스트로베리 크림치즈가 가장 맛있었네요!
# 전처리 이후:  말해 뭐합니까     역시가성비 갑 제품   맛도 다양해서     항상 구매하고 있습니다요        스트로베리 크림치즈가 가장 맛있었네요

# %% [markdown]
# ## 3. 띄어쓰기 교정(PyKoSpacing)
#
# `PyKoSpacing`은 띄어쓰기가 되지 않은 문장을 띄어쓰기가 된 문장으로 교정해주는 패키지입니다다. 앞서 한글 외 다른 문자를 공백으로 치환했는데, 중첩된 공백들도 이 띄어쓰기 교정으로 하나의 공백으로 바꿔줄 수 있습니다.

# %%
from pykospacing import Spacing
spacing = Spacing()

# %%
def spacing_text(text):
  spaced_text = spacing(text)
  return spaced_text

# %%
spaced = spacing_text(example)
print("전처리 이전: ",example)
print("전처리 이후: ",spaced)
# Out:
# 전처리 이전:  말해 뭐합니까     역시가성비 갑 제품   맛도 다양해서     항상 구매하고 있습니다요        스트로베리 크림치즈가 가장 맛있었네요
# 전처리 이후:  말해 뭐 합니까 역시 가성비 갑 제품 맛도 다양해서 항상 구매하고 있습니다 요 스트로베리 크림치즈가 가장 맛있었네요

# %% [markdown]
# ## 4. 형태소 분석기(okt)
#
# 한국어에서 토큰화를 해주는 대표적인 도구는 `konlpy`입니다. 가장 대표적인 형태소 분석기는 `Okt` 모델입니다.

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
def extract_morphs(text):
  morphs_ = okt.morphs(text, stem=True)
  return morphs_

# %%
morphs_ = extract_morphs(spaced)
print("전처리 이전: ",spaced)
print("전처리 이후: ",morphs_)
# Out:
# 전처리 이전:  말해 뭐 합니까 역시 가성비 갑 제품 맛도 다양해서 항상 구매하고 있습니다 요 스트로베리 크림치즈가 가장 맛있었네요
# 전처리 이후:  ['말', '하다', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '있다', '요', '스트로베리', '크림', '치즈', '가', '가장', '맛있다']

# %% [markdown]
# ## 5. 불용어 제거
#
# 분석에 있어 큰 의미가 없는 '불용어(stopword)'를 지정해줘야 합니다. '하다', '도', '는', '이다' 등 의미가 없는 어미나 조사같은 것을 지워주기로 합니다.
#
# 불용어 참고 사이트: https://www.ranks.nl/stopwords/korean
#
# 위 불용어 자료에서 몇 개의 단어를 추가해서 저장해두었습니다.

# %%
with open('/content/drive/MyDrive/stopword.txt') as f:
    list_file = f.readlines()

stopwords_list = []
for stopword in list_file:
  stopwords = re.sub('[\n]', '', stopword)
  stopwords_list.append(stopwords)

def remove_stopwords(text):
  remove_stop = [x for x in text if x not in stopwords_list]
  return remove_stop

# %%
remove_stop = remove_stopwords(morphs_)
print("전처리 이전: ",morphs_)
print("전처리 이후: ",remove_stop)
# Out:
# 전처리 이전:  ['말', '하다', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '있다', '요', '스트로베리', '크림', '치즈', '가', '가장', '맛있다']
# 전처리 이후:  ['말', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '요', '스트로베리', '크림', '치즈', '가장', '맛있다']

# %% [markdown]
# 추가적으로, 불용어로만 걸러내기엔 한계가 있고 아예 한 글자 단어들을 전부 없애주는 것이 나은 경우가 있습니다. 하지만, '맛', '향', '짱'과 같은 핵심적인 단어들은 남겨두기로 했다.

# %%
def remove_one(text):
  except_list = ['맛','향','짱']
  remove_one_ = [x for x in text if len(x)>1 or x in except_list]
  return remove_one_

# %%
remove_one_ = remove_one(remove_stop)
print("전처리 이전: ",remove_stop)
print("전처리 이후: ",remove_one_)
# Out:
# 전처리 이전:  ['말', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '요', '스트로베리', '크림', '치즈', '가장', '맛있다']
# 전처리 이후:  ['니까', '역시', '가성비', '제품', '맛', '다양하다', '항상', '구매', '하고', '스트로베리', '크림', '치즈', '가장', '맛있다']

# %% [markdown]
# 그런데 몇 단어들을 찾아보니 `가성비`는 `가`, `성비`가 나뉘고 `프로틴`은 `프로`, `틴`이 나뉘는 안타까운 상황이 발생했습니다.
#
# 이런 경우, konlpy 사전에 직접 단어를 등재시키는 방법이 있습니다.
#
# 아래처럼 `os` 모듈을 사용하여 코랩 패키지에 저장된 konlpy 폴더에 손을 대는 방식입니다.
#
# 우선 `chdir`로 경로를 이동해주고 `makedirs`로 임시폴더를 만들어준 후. 이 임시폴더에서 단어 사전을 수정한 뒤 원본 폴더에 저장해줍니다.
#
# ** FileNotFoundError가 발생하는 경우 아래 directory에서 python 버전이 잘못된 경우일 수 있습니다.

# %%
import os

os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java')
os.getcwd()
os.makedirs('./aaaa')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-18-c9c52aa9b4d5> in <cell line: 5>()
#       3 os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java')
#       4 os.getcwd()
# ----> 5 os.makedirs('./aaaa')
#
# /usr/lib/python3.10/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: './aaaa'

# %%
os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa') #임시 폴더로 이동
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa'

# %% [markdown]
# 임시폴더에 konlpy 사전 파일의 압축을 풀어줍니다.

# %%
# !jar xvf ../open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: META-INF/maven/
#   created: META-INF/maven/org.openkoreantext/
#   created: META-INF/maven/org.openkoreantext/open-korean-text/
#  inflated: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml
#  inflated: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/qa/
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class
#   created: org/openkoreantext/processor/tools/
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class
#  inflated: org/openkoreantext/processor/tools/Runnable.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class
#   created: org/openkoreantext/processor/util/
#  inflated: org/openkoreantext/processor/util/KoreanPos$.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar$.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class
#  inflated: org/openkoreantext/processor/util/Hangul$.class
#  inflated: org/openkoreantext/processor/util/KoreanConjugation$.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class
#   created: org/openkoreantext/processor/util/verb/
#  inflated: org/openkoreantext/processor/util/verb/eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/pre_eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/verb_prefix.txt
#  inflated: org/openkoreantext/processor/util/verb/verb.txt
#   created: org/openkoreantext/processor/util/freq/
#  inflated: org/openkoreantext/processor/util/freq/entity-freq.txt.gz
#  inflated: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class
#  inflated: org/openkoreantext/processor/util/CharArraySet.class
#   created: org/openkoreantext/processor/util/auxiliary/
#  inflated: org/openkoreantext/processor/util/auxiliary/exclamation.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/conjunctions.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/determiner.txt
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class
#   created: org/openkoreantext/processor/util/typos/
#  inflated: org/openkoreantext/processor/util/typos/typos.txt
#   created: org/openkoreantext/processor/util/josa/
#  inflated: org/openkoreantext/processor/util/josa/josa.txt
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos.class
#   created: org/openkoreantext/processor/util/adverb/
#  inflated: org/openkoreantext/processor/util/adverb/adverb.txt
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$1.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/Hangul.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda.class
#   created: org/openkoreantext/processor/util/adjective/
#  inflated: org/openkoreantext/processor/util/adjective/adjective.txt
#   created: org/openkoreantext/processor/util/substantives/
#  inflated: org/openkoreantext/processor/util/substantives/given_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/modifier.txt
#  inflated: org/openkoreantext/processor/util/substantives/suffix.txt
#  inflated: org/openkoreantext/processor/util/substantives/family_names.txt
#  inflated: org/openkoreantext/processor/util/example_tweets.txt
#   created: org/openkoreantext/processor/util/noun/
#  inflated: org/openkoreantext/processor/util/noun/lol.txt
#  inflated: org/openkoreantext/processor/util/noun/names.txt
#  inflated: org/openkoreantext/processor/util/noun/kpop.txt
#  inflated: org/openkoreantext/processor/util/noun/slangs.txt
#  inflated: org/openkoreantext/processor/util/noun/nouns.txt
#  inflated: org/openkoreantext/processor/util/noun/geolocations.txt
#  inflated: org/openkoreantext/processor/util/noun/twitter.txt
#  inflated: org/openkoreantext/processor/util/noun/pokemon.txt
#  inflated: org/openkoreantext/processor/util/noun/spam.txt
#  inflated: org/openkoreantext/processor/util/noun/congress.txt
#  inflated: org/openkoreantext/processor/util/noun/company_names.txt
#  inflated: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt
#  inflated: org/openkoreantext/processor/util/noun/entities.txt
#  inflated: org/openkoreantext/processor/util/noun/foreign.txt
#  inflated: org/openkoreantext/processor/util/noun/profane.txt
#  inflated: org/openkoreantext/processor/util/noun/bible.txt
#  inflated: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/KoreanConjugation.class
#  inflated: org/openkoreantext/processor/util/example_chunks.txt
#  inflated: org/openkoreantext/processor/KoreanPosJava.class
#   created: org/openkoreantext/processor/normalizer/
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class
#   created: org/openkoreantext/processor/phrase_extractor/
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor$.class
#   created: org/openkoreantext/processor/stemmer/
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer$.class
#   created: org/openkoreantext/processor/tokenizer/
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor.class
#  inflated: org/openkoreantext/processor/KoreanTokenJava.class

# %% [markdown]
# 압축이 잘 풀렸으니 이제 명사들이 등재되어 있는 names.txt를 열어봅니다.

# %%
with open(f"/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

# %% [markdown]
# 아래처럼 다양한 단어들이 저장되어있는 것을 볼 수 있다. 여러 사용자들의 니즈를 반영하여 몇 단어들이 추가된 것으로 보입니다.

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n프로틴\n가성비\n밀크티\n프로틴\n가성비\n밀크티\n프로틴\n가성비\n밀크티\n프로틴\n가성비\n밀크티\n'

# %% [markdown]
# 일단 세 개의 단어를 추가해보도록 합시다. 그리고 쓰기 모드로 변경하여 새롭게 파일을 저장합니다.
#
# 예시로는 아래 세 가지 단어를 넣었지만, 여러분께서 마음껏 원하는 단어를 넣어보셔도 좋습니다.

# %%
data += '프로틴\n가성비\n밀크티\n'

with open("/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)

# %% [markdown]
# 이제 다시 파일을 압축시키면 완료! 런타임을 재실행해야 제대로 반영이 됩니다.

# %%
# !jar cvf ../open-korean-text-2.1.0.jar *
# Out:
# added manifest
# ignoring entry META-INF/
# ignoring entry META-INF/MANIFEST.MF
# adding: META-INF/maven/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml(in = 9127) (out= 2208)(deflated 75%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties(in = 119) (out= 110)(deflated 7%)
# adding: org/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/qa/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class(in = 2418) (out= 1015)(deflated 58%)
# adding: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class(in = 824) (out= 575)(deflated 30%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets.class(in = 2720) (out= 2031)(deflated 25%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class(in = 8751) (out= 3532)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class(in = 10867) (out= 4401)(deflated 59%)
# adding: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class(in = 1464) (out= 823)(deflated 43%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class(in = 2307) (out= 1702)(deflated 26%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class(in = 3080) (out= 1338)(deflated 56%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class(in = 2376) (out= 952)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class(in = 3153) (out= 1446)(deflated 54%)
# adding: org/openkoreantext/processor/tools/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/tools/UpdateAllTheExamples.class(in = 1089) (out= 756)(deflated 30%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class(in = 2516) (out= 1784)(deflated 29%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class(in = 2842) (out= 1010)(deflated 64%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$.class(in = 5881) (out= 2385)(deflated 59%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class(in = 2974) (out= 1020)(deflated 65%)
# adding: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class(in = 833) (out= 566)(deflated 32%)
# adding: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class(in = 4383) (out= 1794)(deflated 59%)
# adding: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class(in = 5487) (out= 2305)(deflated 57%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class(in = 3718) (out= 1429)(deflated 61%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class(in = 5989) (out= 2472)(deflated 58%)
# adding: org/openkoreantext/processor/tools/Runnable.class(in = 964) (out= 694)(deflated 28%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class(in = 3825) (out= 1443)(deflated 62%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class(in = 2787) (out= 997)(deflated 64%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class(in = 3569) (out= 1415)(deflated 60%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples.class(in = 2367) (out= 1659)(deflated 29%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples.class(in = 2427) (out= 1732)(deflated 28%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$.class(in = 5517) (out= 2327)(deflated 57%)
# adding: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class(in = 7154) (out= 3133)(deflated 56%)
# adding: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class(in = 1117) (out= 823)(deflated 26%)
# adding: org/openkoreantext/processor/util/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/KoreanPos$.class(in = 12173) (out= 4669)(deflated 61%)
# adding: org/openkoreantext/processor/util/KoreanDictionaryProvider.class(in = 3430) (out= 2003)(deflated 41%)
# adding: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class(in = 20197) (out= 7488)(deflated 62%)
# adding: org/openkoreantext/processor/util/Hangul$HangulChar$.class(in = 2389) (out= 1022)(deflated 57%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class(in = 2053) (out= 725)(deflated 64%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class(in = 2788) (out= 1181)(deflated 57%)
# adding: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class(in = 2155) (out= 963)(deflated 55%)
# adding: org/openkoreantext/processor/util/CharacterUtils.class(in = 3703) (out= 1716)(deflated 53%)
# adding: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class(in = 4390) (out= 1610)(deflated 63%)
# adding: org/openkoreantext/processor/util/Hangul$.class(in = 7625) (out= 3114)(deflated 59%)
# adding: org/openkoreantext/processor/util/KoreanConjugation$.class(in = 22440) (out= 7972)(deflated 64%)
# adding: org/openkoreantext/processor/util/CharArrayMap.class(in = 11923) (out= 4878)(deflated 59%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class(in = 3118) (out= 1270)(deflated 59%)
# adding: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class(in = 2433) (out= 1078)(deflated 55%)
# adding: org/openkoreantext/processor/util/verb/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/verb/eomi.txt(in = 12618) (out= 3556)(deflated 71%)
# adding: org/openkoreantext/processor/util/verb/pre_eomi.txt(in = 285) (out= 185)(deflated 35%)
# adding: org/openkoreantext/processor/util/verb/verb_prefix.txt(in = 47) (out= 52)(deflated -10%)
# adding: org/openkoreantext/processor/util/verb/verb.txt(in = 32758) (out= 10723)(deflated 67%)
# adding: org/openkoreantext/processor/util/freq/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/freq/entity-freq.txt.gz(in = 385753) (out= 385873)(deflated 0%)
# adding: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class(in = 1634) (out= 659)(deflated 59%)
# adding: org/openkoreantext/processor/util/CharArraySet.class(in = 4886) (out= 1944)(deflated 60%)
# adding: org/openkoreantext/processor/util/auxiliary/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/auxiliary/exclamation.txt(in = 1759) (out= 757)(deflated 56%)
# adding: org/openkoreantext/processor/util/auxiliary/conjunctions.txt(in = 398) (out= 189)(deflated 52%)
# adding: org/openkoreantext/processor/util/auxiliary/determiner.txt(in = 63) (out= 63)(deflated 0%)
# adding: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class(in = 3157) (out= 1089)(deflated 65%)
# adding: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class(in = 2577) (out= 1282)(deflated 50%)
# adding: org/openkoreantext/processor/util/typos/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/typos/typos.txt(in = 5146) (out= 2300)(deflated 55%)
# adding: org/openkoreantext/processor/util/josa/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/josa/josa.txt(in = 5219) (out= 1476)(deflated 71%)
# adding: org/openkoreantext/processor/util/KoreanSubstantive$.class(in = 14990) (out= 6195)(deflated 58%)
# adding: org/openkoreantext/processor/util/KoreanPos.class(in = 6890) (out= 3877)(deflated 43%)
# adding: org/openkoreantext/processor/util/adverb/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/adverb/adverb.txt(in = 65572) (out= 18741)(deflated 71%)
# adding: org/openkoreantext/processor/util/KoreanSubstantive.class(in = 1336) (out= 1087)(deflated 18%)
# adding: org/openkoreantext/processor/util/CharArrayMap$1.class(in = 1531) (out= 571)(deflated 62%)
# adding: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class(in = 2824) (out= 1393)(deflated 50%)
# adding: org/openkoreantext/processor/util/Hangul.class(in = 3981) (out= 2731)(deflated 31%)
# adding: org/openkoreantext/processor/util/Hangul$HangulChar.class(in = 3185) (out= 1421)(deflated 55%)
# adding: org/openkoreantext/processor/util/Hangul$DoubleCoda.class(in = 2930) (out= 1348)(deflated 53%)
# adding: org/openkoreantext/processor/util/adjective/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/adjective/adjective.txt(in = 27250) (out= 9357)(deflated 65%)
# adding: org/openkoreantext/processor/util/substantives/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/substantives/given_names.txt(in = 1407) (out= 609)(deflated 56%)
# adding: org/openkoreantext/processor/util/substantives/modifier.txt(in = 3395) (out= 1346)(deflated 60%)
# adding: org/openkoreantext/processor/util/substantives/suffix.txt(in = 325) (out= 224)(deflated 31%)
# adding: org/openkoreantext/processor/util/substantives/family_names.txt(in = 299) (out= 197)(deflated 34%)
# adding: org/openkoreantext/processor/util/example_tweets.txt(in = 86271) (out= 38336)(deflated 55%)
# adding: org/openkoreantext/processor/util/noun/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/noun/lol.txt(in = 1337) (out= 744)(deflated 44%)
# adding: org/openkoreantext/processor/util/noun/names.txt(in = 1053) (out= 571)(deflated 45%)
# adding: org/openkoreantext/processor/util/noun/kpop.txt(in = 5371) (out= 2495)(deflated 53%)
# adding: org/openkoreantext/processor/util/noun/slangs.txt(in = 1565) (out= 921)(deflated 41%)
# adding: org/openkoreantext/processor/util/noun/nouns.txt(in = 219319) (out= 84134)(deflated 61%)
# adding: org/openkoreantext/processor/util/noun/geolocations.txt(in = 5423) (out= 2267)(deflated 58%)
# adding: org/openkoreantext/processor/util/noun/twitter.txt(in = 254) (out= 162)(deflated 36%)
# adding: org/openkoreantext/processor/util/noun/pokemon.txt(in = 1781) (out= 965)(deflated 45%)
# adding: org/openkoreantext/processor/util/noun/spam.txt(in = 202) (out= 157)(deflated 22%)
# adding: org/openkoreantext/processor/util/noun/congress.txt(in = 26494) (out= 9351)(deflated 64%)
# adding: org/openkoreantext/processor/util/noun/company_names.txt(in = 1631) (out= 905)(deflated 44%)
# adding: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt(in = 1971964) (out= 686708)(deflated 65%)
# adding: org/openkoreantext/processor/util/noun/entities.txt(in = 108142) (out= 44095)(deflated 59%)
# adding: org/openkoreantext/processor/util/noun/foreign.txt(in = 10485) (out= 4686)(deflated 55%)
# adding: org/openkoreantext/processor/util/noun/profane.txt(in = 569) (out= 337)(deflated 40%)
# adding: org/openkoreantext/processor/util/noun/bible.txt(in = 2032) (out= 1005)(deflated 50%)
# adding: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class(in = 3062) (out= 859)(deflated 71%)
# adding: org/openkoreantext/processor/util/KoreanConjugation.class(in = 1550) (out= 1237)(deflated 20%)
# adding: org/openkoreantext/processor/util/example_chunks.txt(in = 522978) (out= 163253)(deflated 68%)
# adding: org/openkoreantext/processor/KoreanPosJava.class(in = 2457) (out= 1241)(deflated 49%)
# adding: org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class(in = 11553) (out= 5102)(deflated 55%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer.class(in = 2980) (out= 2181)(deflated 26%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class(in = 2577) (out= 989)(deflated 61%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class(in = 3470) (out= 1422)(deflated 59%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class(in = 5901) (out= 1995)(deflated 66%)
# adding: org/openkoreantext/processor/phrase_extractor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class(in = 6005) (out= 3967)(deflated 33%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class(in = 37855) (out= 12404)(deflated 67%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class(in = 3564) (out= 1087)(deflated 69%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class(in = 4857) (out= 1609)(deflated 66%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class(in = 6942) (out= 2591)(deflated 62%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class(in = 3358) (out= 1148)(deflated 65%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor$.class(in = 7716) (out= 2400)(deflated 68%)
# adding: org/openkoreantext/processor/stemmer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/stemmer/KoreanStemmer.class(in = 1439) (out= 972)(deflated 32%)
# adding: org/openkoreantext/processor/stemmer/KoreanStemmer$.class(in = 7044) (out= 2892)(deflated 58%)
# adding: org/openkoreantext/processor/tokenizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/tokenizer/ParsedChunk$.class(in = 3973) (out= 1500)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class(in = 8169) (out= 2408)(deflated 70%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class(in = 25564) (out= 8451)(deflated 66%)
# adding: org/openkoreantext/processor/tokenizer/ParsedChunk.class(in = 20517) (out= 8914)(deflated 56%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$.class(in = 17975) (out= 6790)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class(in = 9889) (out= 4174)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/Sentence.class(in = 5985) (out= 3125)(deflated 47%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class(in = 3399) (out= 1429)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker.class(in = 4232) (out= 2887)(deflated 31%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class(in = 4616) (out= 1645)(deflated 64%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunk.class(in = 5611) (out= 2907)(deflated 48%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunk$.class(in = 2361) (out= 1010)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class(in = 3459) (out= 1111)(deflated 67%)
# adding: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class(in = 3359) (out= 1497)(deflated 55%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class(in = 4043) (out= 1704)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class(in = 1660) (out= 1133)(deflated 31%)
# adding: org/openkoreantext/processor/tokenizer/Sentence$.class(in = 2339) (out= 1012)(deflated 56%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class(in = 6968) (out= 4384)(deflated 37%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class(in = 3976) (out= 1402)(deflated 64%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class(in = 2862) (out= 1067)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class(in = 2893) (out= 1136)(deflated 60%)
# adding: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class(in = 1092) (out= 712)(deflated 34%)
# adding: org/openkoreantext/processor/tokenizer/TokenizerProfile.class(in = 16403) (out= 6666)(deflated 59%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class(in = 6336) (out= 2633)(deflated 58%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor.class(in = 4428) (out= 1997)(deflated 54%)
# adding: org/openkoreantext/processor/KoreanTokenJava.class(in = 1976) (out= 931)(deflated 52%)

# %% [markdown]
# 원래 두 단어로 나뉘어서 나오던 것들이 올바르게 한 단어로 출력되는 것을 볼 수 있습니다.

# %%
print(okt.nouns("가성비"))
print(okt.nouns("프로틴"))
# Out:
# ['가성비']
# ['프로틴']

# %% [markdown]
# 전 과정을 하나로 통합하면 아래와 같습니다.

# %%
from konlpy.tag import Okt
okt = Okt()

from pykospacing import Spacing
spacing = Spacing()

except_list = ['맛','향','짱']

with open('/content/drive/MyDrive/stopword.txt') as f:
    list_file = f.readlines()

stopwords_list = []
for stopword in list_file:
  stopwords = re.sub('[\n]', '', stopword)
  stopwords_list.append(stopwords)

def review_to_words(raw_review):
  text = re.sub('[^가-힣]', ' ', raw_review)
  text = spacing(text)
  text = okt.morphs(text, stem=True)
  text = [x for x in text if x not in stopwords_list]
  text = [x for x in text if len(x)>1 or x in except_list]
  text = " ".join(text)
  return text

# %% [markdown]
# 이제 `words_list`를 만들어 전처리한 단어들을 하나의 리스트에 모아줍니다. 띄어쓰기 교정 과정에서 약간 지연됩니다.

# %%
import tqdm
df_len = df.shape[0]
words_list = []
for i in range(df_len):
  words_list.append(review_to_words(df['text'][i]))

# %%
words_list
# Out:
# ['처음 먹다 보다 맛있다 맛 좋다 꾸준하다 먹다',
#  '니까 역시 가성비 제품 맛 다양하다 항상 구매 하고 스트로베리 크림 치즈 가장 맛있다',
#  '좋넹 맛있다 저번 차라 떼다 먹다 보다 그것 보다 나은',
#  '매우 만족하다 로는 정말 엄청 크다 평점 좋다 스트로베리 크림 주문 좋다 단맛 강하다 풀림 만점 맛 우유 섞다 딸기 쉐이크 맛 보다는 츄파츕스 딸기 맛 맛 자다 먹다 재다 의사 마프 입문 으로는',
#  '마싯다 요약 달다 자다 녹다 가루 날림 없다 좋다',
#  '최애 제품 임팩트 웨이 프로틴 항상 구매 하고 제품 풀림 좋다 민트 쵸코 맛 아주 일품',
#  '',
#  '쿠키 크림 훗카이도 밀크 그냥 풀다 자다 풀리다 높다 편이 질리 자다 먹다',
#  '좋다 처음 주문 말다 주문 송료 때문 주문 생각 보다 많이 달다 마시기 차다 에는 초코 마시다 보다',
#  '좋다 자다 먹다 초코 맛 이후 딸기 맛 구매',
#  '밀크티 영국 회사 그렇다 지금 먹다 보다 맛 밀크티 가장 만족스럽다 적다 넣다 추천 드리다',
#  '민초 안성맞춤 파라 그렇다 너무 맛있다 자다 먹다',
#  '화이트 초콜릿 맛있다 제품 비다 대비 단백질 함량 높다 가격 싸다 사다 돼다 화이트 초콜릿 맛 호불호 갈리다 수준 아니다 대부분 평이 좋다 개인 으로는 화이트 초콜릿 좋아하다 불다 좋아하다 맛 이라고 생각 너무 맛있다 에도 맛 먹다 질리 사람 많이 사지 맛 이라서 그렇다 배송 일주일 만에 돼다 화초 맛 강추',
#  '네추럴 스트로베리 우유 먹다 맛',
#  '너무 맛있다 좋다 마이 프로틴 에서만 제품 구입 먹다 매우 만족하다',
#  '믿다 프로틴 믿다 프로틴 싸다 맛있다 프로틴 마이 프로틴 대란 사면 좋숩',
#  '스트로베리 크림 사다 먹다 괜찮다 맛 예정',
#  '웨이 프로틴 바닐라 맛 제일 입맛 맞다 항상 바닐라 먹다 밀크 맛 시도 보다 마싯다 진짜 밀크 느낌 완전 팍팍 파우더 향 잡다 좋다 계기 새롭다 맛 계속',
#  '아이스 라떼 커피 우유 맛 이네 먹다 보다 가장 맞다 맛 이네',
#  '배송 빠르다 만족스럽다 가격 비싸다 마프 배송 빠르다 만족하다',
#  '달다 스트로베리 크림 처음 사보다 맛보다 달다 좋다 맛 피해',
#  '처음 구매 프로틴 좋다 처음 웨이 마이 프로틴 구매 처음 작다 용량 푸로틴 구매 송료 비싸다 용량 프로틴 구매 반신반의 구매 현재 매우 만족하다 저녁 운동 프로틴 먹다 부담 스럽지도 그렇다고 허기지다 마음 듭니 처음 구매 떤다 맛 사다 망설이다 눈데 밀크티 일반 구매 현재 만족하다 효과 아직 자다 모르다 꾸준하다 먹다 보다 효과 나타나다 생각 하고 리뷰 치다',
#  '제품 지금 먹다 프로틴 최고',
#  '스트로베리 크림 말차 라떼 아이스커피 초콜렛 통단 후기 모든 운동 사람 일반인 먹이다 결과 통단 나오다 자다 팔리다 끄다 아이스 라떼 가장 무난 커피 우유 좋아하다 무조건 맛있다 말차 라떼 녹차 향 너무 약하다 싸다 맛 없다 맛 이라고 생각 들다 스트로베리 중간 이고 초콜렛 괜찮다',
#  '맛 잇다 맛 다양하다 좋다',
#  '맛 너무 좋다 운동 시작 추천 받다 구매 초코 맛 좋다 든든하다 단백질 챙기다 수고',
#  '초보 맞다 보충 최근 다시 시작 웨이 역시 마프 맛 좋다 흡수 자다 언제나 찾다 운동 사람 영원하다 친구 생각 제품 이에요',
#  '초콜릿 브라우니 임팩트 웨이 프로틴 꾸준하다 먹다 프로틴 다양하다 맛 먹다 초콜릿 브라우니 제일 맛있다',
#  '운동 먹다 최고 프로틴 라면 끓이다 임팩트 웨이 먹다 매킵니',
#  '너무 좋다 근육 뿜뿜된 운동 프로틴 쉐이크 한잔 말다 모든 근육 피로 회복 너무 좋다 추천',
#  '좋다 항상 자다 먹다 득근 하고',
#  '그대로 임팩 그대로 임팩트 맛 맛있다 질리다 먹다 겁니다',
#  '복숭아 아이스티 좋다 라즈베리 복숭아 아이스티 민트 처코 초콜릿 카라멜 먹다 운동 하고 먹기 에는 청량감 라즈베리 복숭아 아이스티 좋다 보다 복숭아 아이스티 제일 나다 마트 팔다 복숭아 요거트 느낌 좋다',
#  '무맛 없어지다 카카오 너무 달다 무맛 카카오 구매 섞다 먹다 최근 구매 보다 무맛 사라지다 으로도 나오다',
#  '만족스럽다 스트로베리 정말 맛 괜찮다 짱',
#  '벌써 중이 처음 귀찮다 가지 먹다 요즘 여러 가지 맛 먹다 체적 무난 하고 맛 괜찮다 개인 으론 스트로베리 크림 최고 딸기 우유 먹다 타지 말다 우유',
#  '맛 먹다 운동',
#  '원픽 초콜릿 민트 초콜릿 민트 혁명 제일 맛있다 민트 상쾌하다 맛 갖다 프로틴 이라니 정말 귀하다 섞다 자다 섞이다 감동 스투룹 와플 맛 너무 뭉치다 아직도 많이 남아',
#  '빠르다 배송 골드 맛 생수 먹다 단맛 좋다',
#  '다크 초콜릿 맛 맛있다 운동 아니다 생수 먹다 맛있다 좋다 짱',
#  '번째 구입 다크 초콜릿 맛 맛있다 먹다 스트로베리 크림 후기 보고 구입 좋다',
#  '임팩트 웨이 프로틴 세계 가장 다양하다 맛 향 구비 세계 보충 회사 가장 향 좋다 맛있다 다양하다 맛 향 제품 마이 프로틴 생산 마이 프로틴 이용 하고 여러 가지 보충 먹다 보다 보충 대기업 마이 프로틴 임팩트 웨이 프로틴 떠나다 지다',
#  '대란 구매 해봤다 생각 보다 괜찮다 맛 종류 많다 고르다 어렵다 그냥 무난 초코렛 선택 괜찮다 포대 오다 유일하다 단점 끄다 기존 먹다 프로틴 옮기다 담다 크게 문제',
#  '누군가 프로틴 추천 원하다 마이 프로틴 운동 가까이 지금 먹다 보다 제품 맥스 트리 코스트 마이 프로틴 대충 기억나다 가지 지금 먹다 마이 프로틴 맛 부담 없이 제일 맛있다 성분 믿다 먹다 누군가 프로틴 추천 바라다 마이 프로틴 추천 정도 매우 만족하다 먹다 정말 추하다',
#  '임팩트 웨이 프로틴 두유 자다 섭취 하고',
#  '배송 대박 빨르다 안전하다 포장 빠르다 배송 자다 오다 유통 기한 넘다 남다 추천',
#  '믿다 살다 마프 역시 내추럴 초콜릿 물리 적당하다 달달 곱다',
#  '진짜 팔다 맛 먹다 꿀팁 너무 달다 느껴지다 맛 따르다 히말라야 소금 넣다 특히 우유 맛 계열 진짜 환장하다 처럼 먹다',
#  '말차 라떼 추천 엄청나다 맛있다 중상 질리다 좋다 없이 무난 무난 맛 이나 풀림 이나 평균 이상인 느낌 주문 절반 먹다 질리 추천',
#  '녹차 라떼 맛 인데 사라지다',
#  '스토리 베리 크림 정말 딸기 우유 처럼 먹다 우유 넣다 넣다 팔다 딸기 우유 똑같다 주의 먹기 엄청 흔들다 주서 래야 자다 희다',
#  '프로틴 최고 가성비 맛 밀크티 맛 달달 맛 여서 신세계 먹다 수록 너무 달다 남기다 지경 이르다 달달 밀크티 좋아하다 불다 추천 통단 비비 녹이다 맛 최고 근데 겁나다 풀림 아이스 라떼 믹스 커피 맛 생각 보다 달다 자다 먹다 중임 운동 하고 먹다 오다 호불호 없이 무난 스트로베리 크림 제일 맛있다 입맛 화장품 맛 솔티드 카라멜 너무 달다 넣다 먹다 기준 현명하다 소비',
#  '만족하다 저번 에도 먹다 무맛 맛 없다 첨가 물이 들어가다 항상 애용',
#  '달달 먹다 딸기 우유 느낌 나다 자다 녹지 경향 벽면 긁다 경우',
#  '가성비 최고 할인 좋다 가격 구매 아주 만족하다',
#  '인생 맛 찾다 배송 랜덤 좋다 주일 나쁘다 바나나 바나나킥 녹이다 맛 느끼하다 스트로베리 스테비 먹다 버블티 버블티 모르다 초콜렛 민트 민초 민트 맛 너무 약하다 깔끔하다 느낌 골드 카라멜 연유 그렇다 맛 인데 느끼하다 라떼 훗카이도 크다 맛 보다 겠다',
#  '최고 프로틴 스트로베리 맛 그냥 딸기 우유 최고 프로틴',
#  '단백질 왕단 질량 부족하다 역시 채우다 좋다 제품',
#  '맛있다 한스 먹다 맛있다 복숭아 향나 초코렛',
#  '스트로베리 크림 강추 스트로베리 크림 확실하다 맛있다 맨날 초코 먹다 먹다 그렇다 가다 들다 보다',
#  '꾸준하다 먹다 배송 빨르다',
#  '가성비 좋다 흡수 좋다 임팩트 웨이 임팩트 웨이 로만 꾸준하다 먹다 주변 친구 프로틴 추천 부탁 추천 해주다 임팩트 웨이 맛 브랜드 다르다 다양하다 고르다 먹다 재미 쏠쏠하다 너무 많다 선택 장애 오다 수도',
#  '거만 먹다 스트로베리 크림 제일 맛있다',
#  '그냥 블루베리 치즈케이크 거품 여전하다 나다 맛 밍함 우유 맛있다 말다 나다 입안 텁텁',
#  '처음 먹다 보다 프로틴 인데 아주 좋다 허리 아프다 치료 통증 치료 방침 정말 다양하다 치료 받다 보다 마지막 진료 의사 선생님 프로틴 추천 보다 제일 리뷰 좋다 구매 맛 따르다 호불호 갈리다 리뷰 많다 제품 가지 주문 해봤다 초코 브라우니 합격 우유 먹다 초코 라기보다는 코코아 우유 아쉽다 뭉치다 건데 이건 프로틴 마찬가지 나머지 아이스 라떼 스트로우 베리 먹다 보고 리뷰 남다',
#  '요거트 맛 후기 사먹다 너무 맛있다 사르다 오다 파다 고객 센터 문의 남다 한참 다리다 시원하다 먹다 그냥 요구르트 마시다 맛있다',
#  '가성비 아니다 맛 성분 상급 가격 저렴하다 제품 특별하다 원하다 제품 없다 추하다',
#  '좋다 자다 섞이다 맛 성분 깨끗하다 좋다',
#  '좋다 자다 섞이다 맛있다 아이스 라떼',
#  '구매 처음 구매 포장 용기 일부 손상 아직 뜯다 먹다 보다 주변 리뷰 좋다 기대',
#  '임팩트 웨이 프로틴 한결같이 먹다 가다 성비 여러 가지 따지다 거만 없다 국내 조사 들다 믿다 하고 미국 에서도 인정 웨이 프로틴 먹다 득근',
#  '맛있다 스트로베리 크림 정말 맛있다',
#  '프로틴 리뷰 맛 오래 섞다 섞이다 섞다 덩어리 지다',
#  '밀크티 맛있다 가루 먹다 분유 맛 우유 먹다 맛있다 먹다 괜찮다 풀림 자다 흔들다 먹다 지장 없다',
#  '샘플 챙기다 감사하다 여행 갈다 갖다 갈다 사이즈 적당하다',
#  '요거트 맛 제출 해주다 진짜 너무 맛있다 지다 출시 해주다',
#  '초콜릿 브라우니 정말 추하다 마이 프로틴 초콜릿 계열 대부분 먹다 보다 개인 초콜릿 브라우니 초코 맛 찌다 맛 들다 보신 들다 보시 추천 드리다',
#  '맛있다 가성비 맛 영양성분 역시 마프 따르다',
#  '홋카이도 밀크 맛 연유 우유 자판기 우유 좋아하다 이건 찌다 원래 맛있다 맛 상해 맛 없다 이건 그렇다 좋다 베이 먹다 수도 좋다 짱 추천',
#  '스트로베리 크림 구매 먹다 전혀 질리 구매 생각',
#  '믿다 제품 믿다 먹다 가성비 제품',
#  '프로틴 인데 꿀맛 프로틴 맛 잘못 사면 진짜 낭패 길래 고민 고민 고민 거듭 사다 아주 만족',
#  '좋다',
#  '맛 좋다 영양 만점 모사 제품 국내 제품 여러 단백질 쉐이크 먹다 보다 가성비 맛 풀림 소화 부작용 모든 완벽하다 계속 맛 사보다 만족하다 제품 나오다 좋다',
#  '보다 맛있다 밀크티 츄럴 초콜릿 맛 맛있다',
#  '할인 많이 맛 마이 프로틴 이용 가성비',
#  '역시 마프 마이 프로틴 역시 믿다 먹다 맛있다',
#  '가성비 좋다 요새 가격 워낙 올라서다 마프 가장 저렴하다',
#  '맛있다 단백질 쉐이크 아이스 라떼 맛 진짜 카페라떼 맛 나서다 너무 맛있다',
#  '맛있다 단백질 쉐이크 아이스 라떼 맛 진짜 카페라떼 맛 나서다 너무 맛있다',
#  '민초 좋아하다 개강 너무 맛있다 먹다 싶다 참다 맛있다 단백질 맞다 싶다',
#  '말차 라떼 맛 잇다 계속 먹다 싶다 그냥 카페 팔다 맛 이에요',
#  '임팩트 웨이 프로틴 계속 구매 먹다 가성비 너무 좋다 프로틴 파우더',
#  '맛있다 라떼 밀크티 초콜렛 민트 추럴 초콜렛 먹다 보다 맛있다 초코 덕후 라서 그렇다 가다 추럴 초콜렛 먹다 먹다 안질리다',
#  '맛있다 밀크 티맛 우유 먹다 정말 밀크 자체 밀크티 좋아하다 불다 먹다 보다 블루베리 치즈케잌 블루베리 맛 많이 베리 치즈 느끼하다 좋아하다 좋아하다',
#  '스트로베리 짱 스트로베리 무난 하고 안질리다 짱',
#  '역시 마이 프로틴 믿다 먹다 마이 프로틴 저렴하다 가격 반대 퀄리티',
#  '좋다 라떼 맛 이랑 쿠앤크 주로 먹다 가격 슬프다 가성비 마프 행사 코드 통해 저렴하다 구매 관세 지불 가격 확인',
#  '예스 예스 기대 지다 버리다 마이 프로틴',
#  '너무 좋다 스트로베리 크림 너무 맛있다',
#  '맞다 좋다 지속 구매 복용 마다 가격 조금씩 차이 해외 배송 이란 걱정 전혀 없다 배송 기간 생각 보다 빠르다',
#  '초코 민트 깔끔하다 좋다 프로틴 보통 무난 하고 사람 많이 찾다 초코 제품 먹다 마이 프로틴 여러 맛 많다 선택 다양하다 장점 살리다 싶다 유투브 인터넷 서치 찾아보다 초코 민트 추천 사람 많다 주문 해봤다 초코 맛 민트 상큼 맛 프레 쉬다 해주다 좋다',
#  '요거트 맛 후기 단백질 먹기 때문 여러 가지 맛 계속 구매 질리 먹다 요거트 맛 궁금하다 사다 차갑다 말다 완전 맛있다 원래 미지근하다 게도 자다 먹다 야구르트 맛 인데 약하다 맛 용량 작다 금방 먹다 재다 오다 한정판 보이다',
#  '쏘다 쏘다 쏘다 맛 그렇게 크게 신경 쓰다 사람 이라서 그냥 먹다 저번 먹다 그냥 초코 맛 맛있다',
#  '놀랍다 맛 오랜 프로틴 먹다 할인 많이 구매 오늘 받다 오늘 먹다 스트로베리 크림 프로틴 맛 처음 프로틴 특유 맛 전혀 나다 어쩜 맛있다 구매 선택 옳다 매우 추천',
#  '요거트 맛 기대다 맨날 초코 오레오 먹다 질리다 구매 맛 대중',
#  '깔끔하다 맛 달달 맛 질리다 구매 깔끔하다 좋다',
#  '밀크 티맛 풀림 좋다 맛 표현',
#  '아주 만족 가성비 프로틴 대명사 마프 초콜릿 스무 풀림 좋다 맛 좋다 키로 째다 주문 맛 대체로 만족하다 가끔 풀림 아쉽다',
#  '자다 받다 자다 받다',
#  '맛있다 그냥 맛있다 가성비 마이 프로틴 짱',
#  '제일 무난 실패 없다 맛 포만 감다 없다',
#  '개꿀 딱이다 맛 좋다 양은 좋다 마프 사십',
#  '간단하다 단백질 섭취 좋다 초코 스무 맛 괜찮다 근데 에는 무맛',
#  '자다 오다 먹다 만족하다',
#  '추천 맛 가격 좋다 성분 좋다',
#  '제품 리뷰 진짜 가성비 로는 마이 프로틴 이기다 브랜드 별로 없다 항상 만족하다',
#  '스트로베리 크림 솔티드 카라멜 역경 견디다 마무리 느끼다 주더 라도 맛있다 주문 꾸역꾸역 먹다 맛있다 먹다 운동 기다리다 프로틴 꾸다 이냐 만족 따르다 기분 바뀌다',
#  '먹다 보다 가지 맛 소소하다 맛 리뷰 먹다 보다 맛 스트로베리 크림 피넛 초코 아이스커피 밀크티 스트로베리 크림 먹다 보다 맛 가장 그냥 팔다 딸기 우유 자체 예요 질리다 짜다 궁금하다 먹다 보다 너무 맛있다 나머지 현재 구매 열심히 먹다 피넛 초코 이건 호불호 갈릴 맛 없다 맛 너무 강하다 많이 마시다 가장 맛 이라고 표현 팔다 누가 부분 짜다 맛 가다 밉다 맛 이라고 보시 돼다 아이스커피 스트로베리 크림 맛 짜다 구매 주문 맛 신의 모양 현재 먹다 스트로베리 크림 맛 먹다 구매 예정 여름 말다 정말 좋다 팔다 아이스커피 맛 이랑 가장 흡사하다 믹스 커피 좋아하다 인스턴트 커피 라서 마시다 근데 이건 먹다 생각 너무 설레다 밀크티 팔다 밀크티 맛 생각 크게 실망하다 그렇다 팔다 밀크티 엄청 좋아하다 크다 기대 가지 맛 너무 달라 놀래다 짜다 사다 먹다 단맛 맛 보다는 약하다 들어가다 질리 지는 맛 단맛 좋아하다 에게는 추천 드리다 싶다 맛 선택 고민 할인 행사 짜다 맛 별로 여러 주문 들다 보시 추천 드리다 구매 입맛 맛 늘다 용량 구매 추천 드리다 싶다 사실 운동 사람 들이다 두고두고 말다 텐데 들다 맛있다 늘다 들다 전체 섞다 거품 정도 기다리다 금방 없어지다 너무 걱정 에도 자다 섞이다 먹기 정말 좋다 마프 애용',
#  '항상 믿다 먹다 다양하다 맛 최고 가성비 먹다',
#  '역시 가성비 마이 프로틴 마이 프로틴 먹다 사람 정말 맛있다 가격 착하다',
#  '비교 저렴하다 맛있다 좋다 생각 보다 맛있다 아주 좋다',
#  '맛있다 원래 프로틴 맛 인데 이건 진짜 그냥 라즈베리 우유 음료 먹다 뒷맛 깔끔하다 맛 굉장하다 만족하다',
#  '초코 브라우니 맛 좋다 풀림 아주 좋다 먹기 좋다',
#  '',
#  '가성비 끝판 친구 구매 관세 붙다 사람 비다 비싸다 먹다 아주 만족하다 맛 좋다 배송 많이 지는',
#  '임팩트 웨이 프로틴 좋다 가격 품질 만족하다',
#  '맛있다 좋아하다 불다 해보다 맛 이에요 운동 쿠엔크 생각 하고 마시다',
#  '번째 네츄럴 초콜릿 먹다 맛있다 계속 먹다 맛 중요하다 너무 질리다 좋다',
#  '웨이 프로틴 최고',
#  '초코 브라우니 실패하다 수가 없다 맛 너무 맛있다',
#  '한정판 벚꽃 훗카이도 밀크 후기 마프 구매 초코 계열 이랑 훗카이도 밀크 구매 해봤다 초코 대충 느낌 아니다 벚꽃 훗카이도 밀크 해봤다 그대로 딸기 우유 벚꽃 향 첨가 벚꽃 향 첨가 음식 처음 먹다 보다 인지 그닥 별로 먹다 우유 니까 확실하다 너무 달다 싶다 초코 맛 나겠쥬',
#  '항상 자다 먹다 거만 먹다 많다 종류 맛 먹다 보다 으론 스무 초콜렛 괜찮다',
#  '스트로베리 크림 스트로베리 크림 맛 사다 우유 먹다 진짜 딸기 우유 맛 에만 타도 먹다 만해 근데 생각 보다 넘다 달다 먹다 보다 질리다',
#  '항상 먹다 보충 초코 바닐라 맛 시작 스트로베리 크림 먹다 보다 거만 먹다 간편하다 단백질 보충 좋다 우유 말다 맛 아주 좋다',
#  '가성비 최고 가성비 정말 좋다 제품 요즘 원료 미치다 듯이 마이 프로틴 가장 저렴하다 맛 강하다 넘김 부드럽다 좋다 프로틴 맛 가격 부담 없다 좋다 어차피 맛 먹다 아니다',
#  '최고 배송 오래 걸리다 빼다 솔직하다 마프 따르다 오다 없다',
#  '좋다 가성비 좋다 맛 솔직하다 가격 맛 프로틴 많이 없다 무난 무난 맛있다 먹기 편하다 자다 풀다 좋다',
#  '초코 바나나 맛 구입 후기 할인 기한 맞추다 구입 배송 정도 걸리다 가성비 기다리다 보람 제품 처음 받다 완충제 없다 터지다 불안하다 다행하다 안전하다 오다 제품 초코바나나 인데 먹다 유청 단백질 보다 풀림 좋다 먹기 쉽다 맛 인터넷 에서는 호불호 갈리다 보다 매우 만족하다 먹다 먹다 적당 달달 하고 초코 향 바나나 향 적절하다 먹다 마다 만족하다 구입 구입 아마 올해 이나 내년 구입 유청 단백질 단가 내려가다 다시 저렴하다 가격 구입 좋다',
#  '자다 먹다 성장하다 블루베리 맛 처음 구매 해봤다 생각 보다 괜찮다 열심히 운동 성장하다',
#  '만족하다 먹다 다임 팩트 웨이 벌써 번째 구매 인지 모르다 자주 구매 가격 전체 유청 버리다 현재 마이 프로틴 가격 대비 좋다 배송 예전 보다 빨르다',
#  '사다 가격 아직 까진 체제 없다',
#  '자다 먹다 가격 많이 대비 가성비 좋다 꾸준하다 이용 하고',
#  '초콜릿 없다 맛 맛 먹다 보다 베이직 최고',
#  '다크 초코 후기 항상 추럴 초콜릿 먹다 다크 초코 새롭다 나오다 보다 내추럴 초콜릿 많이 질리 자다 먹다 다크 초코 맛있다 진하다 고급 맛 이에요',
#  '후임 후임 이랑 후임 처음 프로틴 먹다 맛 좋다 좋다',
#  '프로틴 은한 맛 넘김 좋다 향 좋다',
#  '최고 필요 없다',
#  '가성비 좋다 배송 빨르다',
#  '프로틴 자다 넘어가다 네이버 리뷰 많다 사서 먹다 사다 맛 하고 풀리다 넘사벽',
#  '맛있다 모르다 마싯다 보충 냄새',
#  '도전 밀크티 좋아하다 맛 처음 에는 맛 없다 적다 먹다 맛있다 달다',
#  '무난 난맛 엄청 좋다 아니다 먹다 만하 가성비 괜찮다 요즘 보충 전체 오른',
#  '스트로베리 크림 다이어트 시작 먹다 맛있다 근육 빠지다 방지 초보자 들다 맛있다 속이다 더부룩하다 맛있다 먹다',
#  '스트로베리 크림 다이어트 손실 방지 위해 먹다 먹다 효과 달다 맛 맛있다 말다 먹다',
#  '초코 맛 최고 맛있다 운동 하고 필수 말다',
#  '재다 의사 가성비 좋다 맛 좋다 재다 의사',
#  '재다 의사 가성비 최고 맛 좋다 재다 의사',
#  '가성비 최고 프로틴 요즘 대가 단백질 부족하다 지다 근육 많이 빠지다 가성비 좋다 믿다 프로틴 찾다 마이 프로틴 먹다 보다 부드럽다 자다 풀리다 맛 유형 다양하다 좋다',
#  '프로틴 역시 임팩트 웨이 먹다 보다 프로틴 가장 선호 제품 예여',
#  '먹다 보다 가지 맛 소소하다 맛 리뷰 스트로베리 크림 장점 진짜 그냥 보통 생각 그렇다 딸기 우유 맛임 엄청 지도 물리다 개인 지금 먹다 보다 보충 지금 먹다 맛 먹다 스트로베리 크림 으로만 구매 향 단점 거품 많이 일어나다 끝임 이건 진짜 추천 아이스 라떼 장점 스트로베리 크림 너무 맛있다 먹다 스트로베리 크림 과는 달리 거품 없다 자다 섞이다 기다 마프 특성 아주 작다 뭉치다 생기다 용서 맛임 팔다 라떼 맛 보다는 부족하다 커피 향 보충 제라 감안 하고 생각 해보다 타협 너무 당연하다 가능하다 추천 맛 진짜 맛있다 물리 단점 딱하다 없다 굳이 너무 맛있다 금방 없어지다 느낌 밀크티 장점 허다 맛 평가 팔고 밀크 맛 이라고 생각 하고 산다 말리 싶다 단순하다 보충 니까 적당하다 달달 적당하다 홍차 향 섞이다 생각 마시다 거품 없다 단점 필자 팔다 밀크티 너무 사랑 밀크 맛 대한 환상 가지 주문 근데 먹다 나서다 먹다 걱정 맛 호기심 생기다 직접 느끼다 보다 추천 개인 필자 말리 싶다 마프 맛 개선 자다 팔리다 초콜렛 피넛 버터 장점 진짜 초콜렛 버터 맛 적절하다 자다 섞이다 맛임 누가 껍데기 맛 생각 편하다 나름 자다 섞이다 기다 보충 처럼 작다 뭉치다 감안 단점 설명 고민 많이 확실하다 호불호 많이 갈릴 개인 필자 말다 들다 생각 짜다 짠맛 단맛 느끼다 인공 맛 장점 적다 맛 적절하다 섞이다 진짜 섞이다 맛임 단맛 짜다 맛 따로 순간 느끼다 거임 주문 빨리 먹다 없애다 그냥 무난 초콜렛 맛 그게 아니다 라떼 맛 밖에 먹다 보다 개인 보충 보다는 확실하다 마프 보충 먹기 좋다 대신 여러 가지 맛 선택 선택 만큼 호불호 많이 생각 리뷰 무난 맛 평가 리뷰 보다 그것 주문 추천 하고 싶다 그것 아니다 짜다 여러 사서 한테 맛 늘다 맛 꾸준하다 먹다 방법 권하다 싶다 마프',
#  '개인 맛 평가 지금 많다 브랜드 많다 맛 먹다 보다 마프 입맛 에는 제일 인위 맛 보통 브랜드 초코렛 맛 에는 자다 마프 에서는 스트로베리 여름 과일 맛 괜찮다',
#  '가성비 짱 마프 프로틴 믿다 꾸준하다 떨어지다 무섭다 미리 미리 주문 하고 찬물 자다 녹다 단점 빼다 딱하다',
#  '믿다 먹다 믿다 먹다 마프 가격 좋다 햠량 좋다 먹다 복통 참고 먹다 마프 이상하다 아니다 몸뚱이 상한 거임',
#  '항상 이용 구입 항상 만족하다 먹다',
#  '프로틴 마이 프로틴 역시 마이 프로틴 가성비 프로틴 진짜',
#  '먹다 바프 때문 먹다 이제 크다 업다 하루 늘리다 먹다 도움',
#  '최고 예전 보다 배송 빨르다 영양성분 맛 만족하다',
#  '가성비 괜찮다 국산 제품 먹다 가격 가격 이면 마이 프로틴 먹다 구매 맛 좋다 가격 괜찮다',
#  '블루베리 치즈케잌 맛 항상 자다 먹다 블루베리 치즈케잌 맛 딸기 맛 헷갈리다 느낌 맛 기다 스테디 맛 이라 생각 하고 자다 먹다',
#  '프로틴 가지 맛 후기 기본 가득 넣다 먹다 플레인 요거트 정도 비비다 먹다 후기 개인 너무 인공 맛 싫어하다 찌다 갈색 설탕 맛 많이 인공 느낌 없다 디저트 땡기다 요거트 카카오 닙스 먹다 맛 인공 맛 전혀 없다 많이 달다 좋다 먹다 옛날 빙수 먹다 마지막 국물 마시다 느낌 요거트 랑은 어울림 요거트 살짝 맛 때문 바닐라 적당하다 요거트 비비다 먹다 완전 슈크림 맛 내추럴 바나나 많이 달다 인공 향 많이 느끼다 예전 아폴로 불량 식품 바나나 맛 대신 요거트 블루베리 오트밀 넣다 먹다 맛있다 현미 녹차 라떼 은은하다 수운 현미 맛 살짝 올라오다 미숫가루 맛 요거트 비비다 먹다 크림 치즈 맛 스트로베리 크림 라떼 호불호 없다 딸기 맛 많이 달다 좋다 질리 맛 이라 먹기 좋다 내추럴 초코 적당하다 먹다 허쉬 느낌 당연하다 살짝 밍밍 느낌 없다 밍밍 싫다 우유 먹다 돼다 개인 으로는 먹다 충분하다 맛있다 피넛 버터 아이스크림 누가 맛 적당하다 인공 맛 강하다 무난 마시기 괜찮다 블루베리 치즈 케익 홋카이도 너무 맛 없다 그렇다 이건 그럭저럭 먹다 달달 디저트 향 맛 때문 먹기 질리다 맛 호불호 홋카이도 밀크 너무 너무 인공 맛 먹다 친구 맛 이라는 보다 호불호 많이 갈릴 맛 재다 의사 제품 스트로베리 크림 내추럴 초코 현미 녹차 라떼 피넛 버터 바닐라 요거트 디저트 대용 용량 아니다 가끔 먹다 용도',
#  '초콜릿 스무 스타 제품 초콜릿 계열 다르다 초콜릿 스무 맛있다 만족하다 에는 스트로베리 크림 주문 보다',
#  '단백질 가성비 근본 마프 믿다 먹다 여러 맛 여러 무게 보다 초콜릿 스무 풀림 좋다 제일 무난 먹다 홋카이도 밀크 비추다 먹다 말다 오래 먹기 힘드다 맛',
#  '믿다 먹다 제품 아들 군대 먹기 시작 지금 운동 챙기다 먹다 제품 가격 할인 많이 영양 제도 꾸준하다 구매 먹다 제품',
#  '추하다 가격 착하다 맛 너무 맛있다 항상 마프 끄다 먹다 후회 없다',
#  '단백질 보충 근본 근본',
#  '넘다 맛있다 계속 먹다 싶다 맛 완전 밀크티 맛 이에요 여러 가지 보다 기대 크게 대박',
#  '강추 맛 임팩트 웨이 프로틴 가지 먹다 보다 초코 브라우니 초코 스무 스트로베리 크림 커피 쿠키 비추다 롤리폴리',
#  '맛있다 맛있다 음식 먹다 스트레스 많이 받다 만의 보내다 바라다',
#  '좋다 아직 초코바나나 아이스 라떼 밖에 먹다 보다 초코바나나 바나나 향 초코 맛 아이스 라떼 처음 까지는 프로틴 특유 비리다 때문 꺼리다 부터는 맛있다 먹다',
#  '너무 좋다 맛 다양하다 좋다 가성비 좋다 괜찮다',
#  '내추럴 초콜렛 저번 차보 꿀떡 꿀떡 들어가다',
#  '네츄럴 스트로베리 좋다 포도 맛 섞다 들다 보다 뭔가 믹스 베리 맛 맛있다',
#  '벌써 번째 구매 부담 없이 아침 대용 먹다 바프 준비 아침 먹다 운동 아주 맛있다 먹다',
#  '밀크티 홋카이도 밀크 후기 마이 프로틴 여러 가지 맛 종류 별로 먹다 후기 좋다 밀크 홋카이도 밀크 맛 처음 구매 기대 밀크 티맛 맛있다 공차 밀크 맛보다 홍차 향 풍부하다 단백질 쉐이크 맛있다 홋카이도 밀크 가루 진하다 유향 기대 엄청 대다 아니다 괜찮다 달달 우유 마시다 맛 맛 살짝 쪼금 단백질 쉐이크 느낌 나다 맛 괜찮다',
#  '국민 프로틴 마프 웨이 임팩트 무적 사심 가성비 좋다 도움 좋다 비싸다 사료 처럼 치다 먹다 널널 이니 거사 할인 코드 입력',
#  '인생 프로틴 찾다 많다 프로틴 제품 먹다 보다 항상 속이다 더부룩하다 화장실 펙트 웨이 무맛 다르다 하루 먹다 전혀 불편하다 느끼다 맛 어쩔 없다 건강 위해 무맛 가장 좋다',
#  '초코렛 스테 비아 난무 난하다',
#  '너무 좋다 제품 먹다 보충 속이다 더부룩하다 이건 그렇다 없다 가성비 좋다 만족',
#  '맛있다 프로틴 게이 처럼 펌핑 목적 보단 운동 손실 막다 위해 여러 맛 구매 역시 마프 맛 잔소리 확실하다 손실 예방 운동 하자 마자 말다 손실 오다 느낌 느낌 듭니 헬창 싶다 헬린이들 필수',
#  '항상 먹다 맛 아주 좋다 가성비 좋다',
#  '밀크티 맛있다 진짜 맛있다',
#  '딸기 맛 리뷰 말차 마시다 보고 초코 마시다 보다 딸기 맛있다 먹다 보다 결과 정말 딸기 마시기 가장 맛있다 좋다 마이 프로틴 가격 저렴하다 좋다 자주 애용',
#  '성분 대한 신뢰 가성비 아침 요플레 넣다 아침 식사 해결 지키다 식단 가능하다',
#  '가성비 맛 언제나 먹다 가성비 좋다 마이 프로틴 제품 고민 말고 지르다',
#  '모카 에는 자다 섞이다 우유 에는 정말 자다 섞이다 맛 질리 맛',
#  '프로틴 리뷰 가성비 확실하다 브랜드 비교 흠잡다 없다 만원 주문 무료 배송 개성 살짝 가리다 단점 맛 좋다 지다 날수 덩어리 많다 포장 지퍼 확실하다 아쉽다',
#  '아이스 라떼 맛 우유 믹스 커피 연하다 섞다 맛 아무튼 맛있다 카페인 소량 포함',
#  '웨이 프로틴 항상 편하다 먹다 좋다',
#  '가성비 끝판 저렴하다 가격 양질 최고',
#  '마이 프로틴 제품 비다 자다 녹다 맛 끄다 먹다 초콜릿 스무 먹다 보다 스트로베리 크림 기대다',
#  '그냥 지다 모르다 사다 프로틴 그냥 가다 싸다 많다 곱다 사시',
#  '마이 프로틴 그냥 먹다 거지 믿다 먹다 마프',
#  '헬린이 구매 라떼 맛 라떼 맛 생각 보다 맛있다 넣다 먹다 냄새 나다 비리 지도 넘다 좋다',
#  '현미 녹차 통단 후기 리뷰 보고 맛있다 끄다 구매 참고 에만 먹다 현미 녹차 현미 구수하다 향 진짜 현미 녹차 진하다 근데 맛 생각 보다 녹차 맛 별로 안나 우유 녹차 가루 살짝 맛 맛 없다 통단 비비 빅맛 기대하다 사다 비비 맛 정도 그냥 구수하다 맛 강하다',
#  '항상 먹다 제품 이에요 항상 먹다 제품 인데 할인 들어오다 구입 맛 좋다 가격 좋다 더하다 나위 없다 제품',
#  '웨이 프로틴 초코 브라우니 맛 먹다 보다 무난 하고 맛있다 자다 풀다',
#  '진짜 자다 섞이다 맛 좋다 감동 받다 자다 섞이다 맛 너무 좋다 감동 받다 으로도 자주 이용',
#  '민트 초코 민트 초코',
#  '맛 별로 편차 크다 기본 맛있다 평소 상큼 달콤하다 좋아하다 적당하다 좋아하다 녹차 민트 좋아하다 여태 사다 맛 순위 보다 먹다 우유 지방 우유 유당 내증 따로 없다 사람 보다 단백질 먹다 속이다 느글 느낌 강하다 받다 편이 초콜렛 민트 먹다 우유 먹다 부담스럽다 맛있다 살짝 화하다 맛 느끼하다 잡다 줍다 요거트 먹다 진짜 맛있다 요거트 보다는 그냥 시판 요구르트 맛 유튜버 우유 먹다 맛있다 이건 그냥 그렇다 스트로베리 밀크 레이 츄파츕스 딸기 우유 녹이다 맛 먹다 적당하다 괜찮다 우유 먹다 먹다 나쁘다 뒷맛 좋다 말차 라떼 먹다 비추다 우유 섞다 먹다 괜찮다 근데 이건 스트로베리 밀크 보다도 텁텁 하고 느끼하다 느낌 오래 남아 가다 훗카이도 밀크 사은 맞추다 살다 살다 고민 사다 인생 최고 선택 근데 그냥 물이 유랑 말고 미숫가루 우유 먹다 맛있다 아침 대용 이렇게 들다 나쁘다',
#  '가장 안질리다 오래 먹다 정착',
#  '임팩트 웨이 프로틴 후기',
#  '근육 성장 크다 도움 줍다 아침 저녁 운동 근육 성장 도움 주기 때문 꾸준하다 구매 먹다 가성비 훌륭하다',
#  '가성비 짱 스트로베리 크림 말차 라떼 메다 아이스 라떼 좋아하다 맛 달라지다 좋다 이전 맛 고소 담백하다 달다 북한 느끼하다 맛 때문 먹다 그냥 참고 주다 프로틴 마프 밖엔 없다 주문 바나나 크림 맛 됫나 고민 신제품 바나나 주문 보다',
#  '시나몬 시나몬 맛 진짜 맛있다 대신 거품 너무 많다 거품 쉐이크 숟가락 덜다 정도 인데 맛있다 감수 하고 먹다',
#  '아이스 라떼 맛 스트로베리 크림 이랑 초코 카라멜 먹다 늘다 맛 잇다 선택 아직 실패 없다',
#  '내추럴 초콜렛 맛 맛있다 프로틴 특유 공허하다 느글거리 맛 정말 질색 사람인 지라 예전 스트로베리 크림 맛 사다 너무 느끼하다 달다 억이 무난 선택 내추럴 초콜렛 맛 사다 엄청 까다롭다 입맛 에도 괜찮다 먹다 역시 느끼다 텁텁 뭔가 비어 맛 이라 이렇게 먹다 먹다 정도 진하다 그나마 농축 맛 느끼하다 덮다 때문 많이 보다 낫다 우유 미치다 듯이 달달 초코 우유 느끼하다 공허하다 맛 우유 잡다 때문 좋다 가끔 이렇게 들다 우유 섞다 먹다 굳이 그렇다 에야 적다 먹다 낫다 아무튼 처럼 프로틴 맛 대해 거부 상당하다 사람 내추럴 초콜렛 맛 그나마 무난 먹다 상세 리뷰 해봤다 도움 좋다',
#  '번째 구매 다이어트 웨이 먹다 임팩트 웨이 바꾸다 근육 많이 필요하다 밀크티 맛있다 주문 맛있다 근데 바닐라 맛 보다 자다 풀어지다 많이 덩어리 지다 엄청나다 흔들다 덩어리 그냥 먹다 돼다 근육 많아지다',
#  '초콜렛 스무 스물 자다 섞이다 맛 좋다',
#  '레드 괜찮다 비비 녹다 맛 느낌 인데 에게는 은근 괜찮다 좋아하다 만족감 높다 보다 크다 사이즈 출시 기다리다',
#  '생각 보다 민트 괜찮다 항상 아이스 라떼 사먹다 친구 추천 초콜릿 민트 구매 민트 맛 세지 초콜렛 맛 끝나다 묵직하다 느낌 정도 나서다 괜찮다 보다 자다 풀어지다',
#  '와우 생각 보다 맛있다 추천 인위 맛 나다 고민 프로틴 먹다 보다 인지 너무 너무 괜찮다 엄청 인공 맛나 느낌 아니다 상하 운동 모르다 먹다 나서다 피로 줄다 원래 저녁 항상 졸리 비타민 먹다 졸리다 프로틴 먹다 나선 뭔가 상쾌하다 느껴지다 우어 기분 이예',
#  '내츄럴 초콜렛 맛있다 배송 오래 걸리다 티맛 나다 계속 생각나다 맛',
#  '순하다 초코 딸기 우유 느낌 물이 먹다 너무 맛있다 먹다',
#  '만족하다 초코 브라우니 맛 처음 인데 무난 하고 호불호 없다 맛 이라서 좋다 카라멜 달다 좋아하다 들다 정도 도로 달달',
#  '언제나 믿다 먹다 마프 쉐이크 단백질 함유량 좋다 맛 실패 없다 마프 상승세 보이 종류 별로 먹다 보다 목표',
#  '무난 맛있다 특색 없다 크게 질리 맛 이에요 무난 좋다',
#  '맛있다 프로틴 파우더 먹다 너무 밍밍 하고 달걀 비리다 나다 이건 먹다 맛있다 블루베리 치즈케이크 맛 처음 구매 만족하다 내일 아몬드 브리즈 먹다 보다 맛있다',
#  '만족스럽다 생각 보다 맛 만족스럽다',
#  '아니다 배송 느리다 다렷어 아니다 진짜 맛 없다 버리다 크다 나다 밀크 티맛 제일 궁금하다 먼저 다가 간식 좋다 카페 파우더 밀크 티보 맛있다 티백 우린 밀크티 맛 나요 프로틴 이라 어쩔 없다 매끈하다 식감 이랑 자다 섞이다 거만 빼다 카페 파다 더란 맛있다 너무 없다 미리 주문 더하다 아니다 다시 생각 어이없다',
#  '여러 가지 주문 감미료 맛 힘드다 주문 운동 빡세 공복 먹다 맛있다',
#  '달달 하고 느끼하다 쿠앤크 사이 하얗다 크림 먹다 느낌 먹기 오트밀 이나 계란 이용 만들다 먹기 자다 어울리다 느끼하다 싫어하다 맞다 수도',
#  '제일 맛있다 먹다 보충 여러 가지 맛 돌리다 먹다 밀크티 훗카이도 밀크 제일 맛있다 현미 녹차 스트로베리 크림 주문 보다 단백질 비리다 맛 나다 최고',
#  '마프 처음 인데 만족하다 임펙트 웨이 풀림 좋다 맛 좋다 강추',
#  '맛 솔직하다 스트로베리 크림 호불호 많이 갈리다 딸기 우유 좋아하다 사람 라면 무조건 좋아하다 맛 친구 한테 솔티드 카라멜 선물 받다 먹다 보다 솔티드 카라멜 맛 괜찮다 개인 스트로베리 크림 맛있다',
#  '최고 가격 대비 맛 이나 풀리다 생각 역시 최고 추천 추천',
#  '아주 대기업 테디 셀러 보증 맛 영양성분 믿다 구매',
#  '맛 잇다 항상 크림 먹음',
#  '헐다 현미 녹차 맛 출시 해주다 계속 초콜릿 브라우니 맛 제일 안질리다 자다 먹다 현미 녹차 한정판 맛 만원 구매 사은 받다 너무 맛있다 출시 예정 없다',
#  '말차 라떼 강추 운동 단백질 중요성 마이 프로틴 구매 맛 종류 다양하다 선택 어렵다 많다 라떼 맛 좋다 러버 스타트 차로 시작 무료 배송 맞추다 키로로 했슴 맛 없다 처리 고민 하고 근데 다행하다 너무 맛있다 어요 단백질 쉐이크 라는 처음 먹다 보다 단백질 특유 맛 때문 거부 사람 보다 모르다 하필 맛있다 유명하다 마프 으로도 느끼다 예정 빨리 프로틴 먹다 운동 하고 싶다 배송 일주일 걸리다 너무 좋다 블프 걸리다 어쩌지 걱정 해외 배송 처음 이라 떨리다 들다 어쨌든 먹다 운동 평소 보다 좋다 라테 맛 추하다 웬만하다 카페 치다 맛',
#  '좋다 제품 단백질 가루 좋다 제품 좋다 가격 구매 먹다 아들 열심히 모습 보다 흐뭇하다 유해 성분 없다 걱정 기도 제품 인기 많다 보다',
#  '가성비 최고 프로틴 임팩트 웨이 프로틴 강력 추천 마이 프로틴 제품 먹다 다양하다 저렴하다 가성비 진짜 최고 해외 제품 이라 배송 오래 걸리다 주문 하므다 크게 격감 없다',
#  '헐다 밀크 맛 개맛 먹다 넘다 맛있다 리뷰 올리다 가다 캡챠뜰 끄다 버리다 넘다 맛있다 리뷰 올리다',
#  '뭐라다 맛 먹다 보다 질리다 맛 이라 역사 초코',
#  '믿다 묵다 묵다 리얼 스트로베리 꿀맛',
#  '맛 없다 맛 없다 그냥 초코 맛 레이 들다 자다 풀리다 좋다',
#  '최근 먹다 보다 보충 맛 평가 맛 아래 최근 먹다 보다 보충 제의 맛 비교 저먼 초콜릿 맛있다 보충 입문 먹다 컴뱃 웨이 카푸치노 인공 단맛 심하다 너무 달다 맛 그냥 단맛 카푸치노 맛 아니다 임팩트 웨이 아이스 라떼 맛있다 우유 필요 없다 먹다 커피 우유 맛 고대 맛 타지 아이스 라떼 맛 없다 취향 차이 선택 참고 지방 탄수화물 높다 불다 맛있다 초코 맛 계열 지겹다 먹다 최근 원픽 아이스 라떼',
#  '블루베리 치즈케이크 딸기 맛 나다 블루베리 맛 블루베리 깔끔하다 맛 질리',
#  '코코넛 두유 코코넛 신상 맛 블루베리 치즈케이크 이렇게 코코넛 맛 진짜 맛있다 맛있다 블치 배송 흐르다 오다 역시 타도 맛있다 두유 먹다 꿀맛 팥맛 굳다',
#  '프로틴 바나나 츄럴 초코렛 스트로베리 밀크 티맛 이렇게 프로틴 되게 많이 사서 맛 고르다 먹다 되게 맛있다 고르다 먹다 질리다 좋다 가격 프로틴 회사 보다 되게 저렴하다 성비 긋다 긋다 긋다 츄럴 초콜렛 진짜 가루 향 알다 티향 맛 티맛 되게 맛있다 츄럴 초콜렛 근본 이라고 보다 무방 맛 맛있다 추천 마프 문의 주시 분도 되게 착하다 친절하다 긋다 긋다 긋다',
#  '맛있다 버블 맛 먹다 맛있다',
#  '현미 녹차 라떼 현미 녹차 라떼 분유 맛 어리다 사촌 동생 빼다 먹다 추억 잠기다 맛있다 현미 녹차 라떼 분유 라떼',
#  '먹다 보다 아직 실패 없다 지금 먹다 보다 맛 초콜렛 스트로베리 크림 블루베리 화이트 초콜렛 아이스 라떼 말차 라떼 레드 훗카이도 밀크 가지 먹다 보다 리뷰 쓰다 니까 차다 많이 먹다 보다 초콜렛 그냥 가장 대중 맛 스트로베리 크림 입문 먹기 괜찮다 근데 많이 블루베리 향 좋다 맛 생각 보다 밋밋하다 화이트 초콜렛 우유 먹다 맛 인데 먹다 살짝 비림 아이스 라떼 우유 아몬드 브리 괜찮다 말차 라떼 근데 향 개인 라떼 가장 좋다 레드 하고 훗카이도 밀크 주관 좋다 특히 레드 팥맛 서다 이상하다 알다 최고',
#  '자다 먹다 싸다 좋다 계속 먹다 옮기다 먹다 나다',
#  '어머니 께서 만족하다 당뇨 중간 중간 허기 지다 들다 거리 찾다 주변 지인 추천 구매 어머니 께서 만족하다',
#  '로켓 배송 방금 받다 테이프 뜯다 내용물 없다 이랑 섞다 먹다 무맛 할인 자다 받다',
#  '스트로베리 크림 너무 맛있다',
#  '리얼 컬렉션 너무 맛있다 리얼 컬렉션 밀크티 키로 먹다 오다 웬만하다 카페 로열 밀크티 맛 보다 풀림 너무 좋다 넘김 깔다 끄다 단백질 비리다 맛 없다',
#  '좋다 저렴하다 자다 먹다 가성비 제품 많이 없다 저렴하다 자다 사다',
#  '마이 프로틴 추천 마이 프로틴 맛 괜찮다 먹다 보다 프로틴 가장 최고 마이 프로틴 추천',
#  '최고 프로틴 마이 프로틴 먹다 운동 더불다 영양소 섭취 자다 근육 많이 키우다 덕분 바디 프로필 무사하다 정말로 감사하다 번창 바라다',
#  '정말 좋다 맛 잇다 자다 먹다 잇다',
#  '최고 맛차 라떼 민트 초코 아이스 라떼 먹다 보다 아이스 라떼 최고 차갑다 무가 두유 넣다 쉐이크 쉐이크 먹다 그냥 연유 맛 살짝 커피 우유 맛있다',
#  '좋다 프로틴 처음 구매 맛있다',
#  '스트로베리 크림 사다 안질리다 먹다 거품 생기다 빼다 완벽 딸기 우유 맛 가끔 빨갛다 맛 나다 괜찮다',
#  '꿀맛 보충 처음 먹다 보다 원래 이렇게 맛있다 특히 우유 니까 초코우유 인데 맛 먹다 중임',
#  '홋카이도 밀크 구매 맛 진짜 설탕 섞다 맛 유당 확실하다 잔뜩 들어가다 먹다 만은',
#  '추하다 맛 거부 없다 자다 먹다 번째 먹다 주변 사람 한테 추천 드리다 싶다',
#  '차다 좋다 프로틴 제품 밀크티 맛 추천 맛 씁쓸하다 메이플 시럽 맛 맛있다',
#  '먹다 프로틴 스트로베리 크림 먹다 파인애플 맛 먹다 진짜 파인애플 향 음료수',
#  '민초 맛 최고 민초 매니아',
#  '훗카이도 밀크 페코 짱 훗카이도 밀크 캔디 맛 나다 복숭아 아이스티 내추럴 초콜릿 보다 풀림 덜하다 맛있다 좋다',
#  '맛 상위 놓이다 맛 인지 알다 커피 맛 나다 우유 물이 별로 두유 추천',
#  '밀크티 민트 초코 초코렛 스무 추천 쓰리다 탑인 스트로베리 크림 보통',
#  '임팩트 웨이 프로틴 항상 프로틴 먹다 친구 한테 추천 받다 네츄럴 초콜릿 맛 구매 제일 무난 구매 초콜릿 맛 실패 수가 없다 짜다 구매 넉넉하다 자다 먹다 프로틴 먹다 차갑다 이용 먹다 미지근하다 쪼금 넣다 완전 자다 녹다 부드럽다 넘다 어가 고요 추천 드릴',
#  '너무 맛있다 맛있다 담백하다 맛',
#  '좋다 로는 너무 금방 먹다 초콜릿 스무 키로로 사다 역시 좋다 카라멜 아이스 라떼 밀크티 먹다 보다 맛있다 초콜릿 스무 제일 무난 하고 거품 생기다 자다 안질리다 오래 먹기 좋다 으로도 계속 먹다 예정',
#  '먹다 프로틴 마이 프로틴 보다 가성비 좋다 프로틴 없다 생각 하고 스트로베리 크림 맛 최고',
#  '마프 스트로베리 맛 크림 먹다 있슴댜 딸기 맛 먹기 좋다 가끔 질리 네스퀵 이나 먹다 초코 맛 크다 라면 미숫가루 웨하스 맛 좋다 구매 상품 하고 맛 바뀌다 미끌미끌하다 거품 많아지다 이전 딸기 맛 좋다',
#  '좋다 하루 먹다 초코 맛 맛있다 자다 녹다',
#  '근본 헬스인 보다 준비물 아니다 그냥 카드 슬래쉬 솔티드 카라멜',
#  '가성비 항상 자다 챙기다 먹다',
#  '가성비 훌륭하다 가격 대비 이라는 용량 때문 가성비 휼륭하다 배송 빠르다 아주 좋다',
#  '단백질 쉐이크 텁텁함 없애다 민트 산뜻하다 단백질 쉐이크 질적 텁텁함 민트 없애다 한번 전해 구매 보다 개인 초코 바나나 보다 민트 초코 나은 진짜 텁텁함 잡다 맛 쉐이크 보다 물리다',
#  '맛있다 부담 없다 프로틴 맛 가격 부담 없다 좋다 초콜릿 스무 보다 내추럴 초콜렛 맛 좋다 차라 떼다 달다 특유 싸다 맛 좋아하다 이면 주문 좋다',
#  '굿굿 마이 프로틴',
#  '자다 먹다 라떼 맛 최애 재다 백프로',
#  '말차 개꿀 맛말 진심 개꿀 맛 이에요 후회 없다 선택 들다 보다 아니다 아니다 모르다 그냥 먹다 보다',
#  '정말 좋다 벌써 먹다 만큼 가성비 좋다 없다',
#  '프로틴 네추럴 초콜릿 주로 먹다 기준 으로는 우유 스푼 넣다 먹다 맞다 들어가다 좋다 기준 으로는 라떼 가장 맛있다 가다 없다 단점 이네',
#  '항상 먹다 좋다 말차 라떼 풀림 좋다 녹차 라떼 좋아하다 불다 굳다',
#  '너무 맛있다 가끔 우유 먹다 우유 먹다 진짜 딸기 우유 맛 나다 먹다',
#  '스트로베리 크림 딸기 맛 처음 먹다 보다 아주 달도 세다 웨이 프로틴 말다 마이 프로틴 초음목 늘다 괜찮다 주문 마이 프로틴 끄다',
#  '꿀맛 프로틴 프로틴 이렇게 맛있다 프로틴 처음 먹다 보다 프로틴 먹다 싶다 운동 정도 구매 후회 강추',
#  '맛있다 가루 자다 풀리다 맛 가격 싸다 역시 마이 프로틴',
#  '임펙트 웨이 프로틴 여러 가지 맛 특색 맛있다 특히 아이스 라떼 프로틴 맛있다',
#  '아이스 라테 항상 초콜릿 스무 구매 부모님 먹다 아이스 라테 맛 구매 어르신 초콜릿 향 좋아하다 분들 부모님 그렇다 취향 항상 혼합 마시다 옛날 스카치 캔디 맛 이라고 느껴지다 연한 커피믹스 맛 맛 대한 아쉬움 느껴지다 에스프레소 더블샷 내다 먹다 니다 아쉽다 맛 보태 주어 너무 좋다 아이스 라테 맛 아쉽다 에스프레소 더블샷 내다 타드 정말 맛 라이 해보다 맛 들다 질리다 맛 갈아 계획 이신 아이스 라테 후회 없다 가족 먹기 좋다',
#  '가성비 마이 프로틴 스트로베리 크림 보다 질리 맛 맛 스트로베리 크림 맛있다 네츄럴 초콜렛 무난 질리 좋다',
#  '식사 대용 활용 구성 무맛 먹다 처음 내추럴 스트로베리 주문 진작 먹다 그렇다 프로 빌다 성분 따다 무맛 먹다 후회 바쁘다 아침 팩트 웨이 프로틴 내추럴 스트로베리 스쿱 이스턴 오트 바닐라 스쿱 크레아틴 스쿱 시트 룰린 말레이 아미노산 알파 멀티 비타민 추가 이나 화분 넣다 좋다 넣다 아무 상관없다 이면 간편하다 아침 식사 대용 맛 정말 맛있다 심하다 유당 불다 인데 구성 아무 문제 없다',
#  '맛있다 요타 제품 이용 구매 해봤다 구매 먹다 보고 리뷰 남기다 이전 초코 맛 고수 스트로베리 먹다 보다 신세계 정량 넣다 이키 살짝 거품 덩어리 정도 넣다 기존 이용 제품 보다 이키 해주 니깐 해결 돼다 쉐이크 이용 남다 정도 먹다 맛 구매 해보다',
#  '아침 운동 먹기 좋다 제품 자다 챙기다 먹다 가성비 좋다 할인 행사 구매 하고',
#  '번째 재다 초코 브라우니 네추럴 초콜렛 추럴 스트로베리 스트로베리 크림 먹다 보다 그냥 추럴라인 최고',
#  '너무 맛있다 내추럴 초코 추천 받다 처음 먹다 보다 완전 티맛 맛있다 먹다 재다 예요',
#  '메이플 시럽 사이트 제품 먹다 넘어오다 배송 자다 오다 유당 대한 불편하다 없다 임팩트 웨이 선택 하고 맛 선택 고민 메이플 시럽 좋아하다 구매 시럽 맛 그대로 아니다 맛있다 자다 풀리다 으로는 마이 프로틴 구매 섭취',
#  '스트로베리 크림 꿀맛 평소 딸기 좋아하다 보다 너무 좋다 초코 맞다',
#  '솔티드 카라멜 후기 솔티드 카라멜 주문 하고 배송 걸리다 소금 맛 전혀 느끼다 부드럽다 카라 메다 맛 에는 무맛 먹다 충분하다 달달 하고 맛있다 실온 자다 풀리다 찬물 에는 풀림 좋다 넘김 좋다 스쿱 파우더 자다 찾아보다 들다',
#  '최고 예요 기본 초코 맛 먹다 그것 맛있다 질리다 갈다 먹다 스토 베리 크림 맛있다 쉐이커 섞이다 초코 보다 섞이다 그렇다 모르다 근데 맛 최고 예요 말고 구매 섞다 들다 그렇다 질리 들다 끄다',
#  '임팩트 웨이 프로틴 스트로베리 크림 임팩트 웨이 프로틴 스트로베리 크림 맛 주문 정말 맛있다 음료 프로틴 맛 가다 싶다 보다는 우유 먹다 맛있다',
#  '군대 먹다 프로틴 지금 많다 마이 프로틴 제품 구매 에서도 임팩트 레이 제품 많이 먹다 군대 오다 금전 줄이다 보고 가격 저렴하다 임팩트 웨이 제품 이용 해봤다 레이 가장 크다 차이점 유당 없다 차이 처럼 거부 임팩트 웨이 제품 해보다 좋다 군대 오다 크다 목적 운동 임팩트 웨이 제품 운동 하니 자다 커지다 가격 저렴하다 효율 좋다',
#  '좋다 맛 착하다 가격 항상 자다 챙기다 먹다 제품 다양하다 맛 초고 솔티드 제일 맛있다',
#  '해도 기본 초코 최고 차도 좋아하다 역시 초코 맛 최고 초코 맛 잔뜩 사다 쟁여두 먹다',
#  '정말 자다 먹다 아주 제품 좋다 정말 자다 먹다 아주 제품 좋다',
#  '맛있다 프로틴 삼키다 힘드다 이건 먹다 너무 맛있다',
#  '민초 맛 무조건 먹다 맛 오다 민초 맛 너무 맛 없다 민초',
#  '느끼하다 기준 느끼하다 우유 대신 먹다 짜다 리가 없다 다크 초콜릿 가다 가장 많이 판매 스무 가다 건데 그냥 짜다 다크 싶다 카카오 파우더 주문 향 잡다',
#  '맛 별로 먹다 맛 대부분 먹다 홋카이도 밀크 사다 마차 라떼 맛 처음 구매 마차 라떼 좋아하다 알다 아니다 보다 홋카이도 밀크 자판기 우유 탈지분유 맛 이에요 구수하다 추억 생각나다 무난 맛 블루베리 치즈 케익 맛 무조건 들다 남자 여자 성별 구분 없이 대박',
#  '민초 파라 먹다 덴마크 민초 우유 알다 그거 살짝 연한 맛임 민트 향 강하다 덴마크 민초 우유 졸업 싸다 가능',
#  '처음 사보다 아침 저녁 닭찌찌살 오트밀 먹다 가슴 질리다 아침 에는 가슴 먹다 점심 저녁 에는 마이 프로틴 말다 주문 맛 초코 하고 스토 베리 먹다 다이어트 시작 지다 달반 지나다 편하다',
#  '처음 사보다 아침 저녁 닭찌찌살 오트밀 먹다 가슴 질리다 아침 에는 가슴 먹다 점심 저녁 에는 마이 프로틴 말다 주문 맛 초코 하고 스토 베리 먹다 다이어트 시작 지다 달반 지나다 편하다',
#  '가장 무맛 가깝다 보충 마이 프로틴 여러 회사 무맛 보충 먹다 오다 최근 마이 프로틴 바꾸다 느끼다 건데 무맛 이라 해도 맛 마이 프로틴 무맛 진짜 무맛 가깝다 넘김 너무 편하다 만족',
#  '다양하다 즐기다 마이 프로틴 아들 먹다 프로틴 기적 주문 먹다 맛 좋다 베이 입장 보다 프로틴 카스테라 만들다 밀가루 설탕 없다 충분하다 맛 잇다 여러 가지 도움 많이 계속 구매 제품 화하다 상품 으로도 만들다 보다 생각 들다 기도',
#  '민초 주문 하고 받다 품절 실화 마이 프로틴 처음 초코 민트 츄럴 스트로베리 주문 배송 예정일 이르다 해외 배송 이라 오래 걸리다 보다 기다리다 도착 해외 배송 생각 배송 엄청 빠르다 맛 좋다 자주 이용',
#  '처음 사본 프로틴 오늘 받다 먹다 보다 맛 깔끔하다 넘김 괜찮다',
#  '홋카이도 밀크 밀크 골든 시럽 키로 구매 홋카이도 밀크 기준 별로 근데 밀크티 골든 시럽 지금껏 먹다 보다 보충 제일 맛있다 먹다 구매 구요',
#  '구매 지금 처럼 많다 알다 구매 해오다 구매 중이 가성비 정말 좋다 지금 제품 종류 엄청나다 성장하다 사다 자다 모르다 임펙트 웨이 꾸준하다 먹다 성장 최선 꾸준하다 이니까',
#  '진리 맛 찾다 마프 포함 마프 에도 여러 프로틴 경험 해보다 사람 님들 처럼 근데 최고 맛 찾다 말차 맛 진짜 소개 해주다 모든 사람 그렇다 엄청 맛있다 맛',
#  '맛있다 풀어지다 뭉치다 현상 빈번 일어나다 씹다 먹다 보충',
#  '빠르다 성장 원하다 가다 그렇다 코로나 보다 무섭다 손실 예방 차원 보다 빠르다 성장 원하다 가다 그렇다 무맛 추천 우유 먹다 먹다 정말 최악 맛 경험 인공 화합물 들어가다 다양하다 맛 보다는 순수 단백질 미네랄 이루어지다 무맛 경험 준비 보다 빠르다 성장 감당 없다 펌핑감 느끼다 참고 무맛 고등어 씻다 물맛 가깝다',
#  '임팩트 웨이 프로틴 스트로 베리 크림 임팩트 웨이 프로틴 스트로 베리 크림 리뷰 딸기 우유 좋아하다 리뷰 보고 키로 주문 엄청 많다 맛 딸기 우윤 엄청 달다 달다 우유 엄청 넣다 향 엄청나다 참고 샘플 초콜렛 바나나 초콜렛 스무 맛 좋다 초콜렛 나나 그렇다 보다 참고',
#  '진짜 맛있다 초코 아이스 라떼 사다 인기 많다 무난 제품 이라서 다행 아이스 라떼 특히 맛 임팩트 웨이 말다 운동',
#  '밀크 보이 너무 찌다 적당하다 이벤트 적용 사면 가성비 개쩌는데 쉐이크 스테인리스 넣다 쉐킹해 알갱이 그것 빼다 보이 맛',
#  '성장 위해 먹다 프로틴 떨어지다 친구 여기다 추천 구매 해봤다 배송 엄청 느리다 금방 오다 먹다 맛 초코 맛 이라 끄다 초코 구매 짜다 텁텁 느낌 들다 아쉽다 단백질 쉐이크 특유 비리다 맛 나서다 먹기 좋다 없다 쉐이 크다 쓰다 분들 쉐이크 쉐이커 쓸다 뭉치 자다 섞이다',
#  '초콜릿 맛 먹다 초콜릿 스무 맛 엄청 맛있다 괜찮다 느리다 흡수 카제인 초콜릿 맛 이랑 섞다 먹다 엄청 맛있다',
#  '패트 웨이 프로틴 확실하다 효과 보고 사람 따르다 다르다 효과 보고 좋다 딸기 맛 보고 싶다',
#  '맛 괜찮다 커피 딸기 초코 민트 초코 먹다 보다 딸기 무난 괜찮다 자다 섞이다 느낌 인데 딸기 자다 섞다 괜츈',
#  '스트로베리 크림 맛 후기 스트로베리 크림 맛 무난 하고 괜찮다 리뷰 진심 대신 아몬드 우유 먹다 맛남',
#  '단백질 보충 이제 다양하다 맛 즐기다 프로틴 최고 에는 맛 보다 에는 맛 보다 맛 추가 맛 보고 단백질 보충 하고 가성비 짱 마이 프로틴 역시 가성비 먼저 떠오르다 거기 맛 보너스 마이 프로틴 알다 단백질 보충 찾다 거리',
#  '입문 충분하다 가능하다 프로틴 맛 없다 인공 맛 없다 사람 마다 다르다 미각 매우 민감하다 사람 아니다 아주 강력 추천 가격 합리 이고 양도 좋다 맛 좋다 벌써 구매',
#  '초콜릿 스무 맛 나다 엄청나다 맛 아니다 제품 보다 쉐이크 특유 텁탑 덜하다 맛 나다 성분 골고루 좋다 잇다 애용',
#  '밀크티 리븅 맛있다 질리 먹다 근데 자다 섞다 미끌거리다',
#  '프로틴 최고 최애 프로틴 인도 너무 많이 해주다 이용 하고 운동 너무 많이 도움 곱다',
#  '맛있다 일어나다 스쿱 쇠질 스쿱 쇠질 스쿱 스쿱 깨다 스쿱',
#  '민초 짱짱 처음 민트 초코 맛 보다 처음 맛 라는 후회 들다 민트 초코 맛 짱짱',
#  '맛 진짜 완전 댕꿀맛 처음 키로 먹다 키로 먹다',
#  '가성비 최고 가성비 최고 보충 맛 종류 많다 질리 가격 비다 좋다 단백질 함량 높다',
#  '웨이 프로틴 쉐입 잡다 최고 죽다 먹다 먹다 게이 갈아타다 읍니',
#  '임팩트 웨이 프로틴 최근 많다 프로틴 먹다 맛 다양하다 제일 자다 맞다 거만 먹다 초콜릿 민트 커피 카라멜 초코 카라멜 스트로베리 크림 추천',
#  '초콜릿 맛있다 브라우니 보다 초콜릿 맛있다',
#  '너무 맛있다 당초 절대 실패 초코 믿다 들다',
#  '커피 카라 메다 맛 별로 에요 부터는 모험 베스트 갈래',
#  '민트 초코 좋다 민트 초코 맛 고민 고민 말다 최고 민트 초코 맛 단백질 민트 초코 라떼 굳이 먹다 진하다 얼음 띄우다 그게 민초 떼이다 얼음 정수기 사랑 일반 초코 맛 츄럴 브라우니 단백질 가루 자다 씻다 자다 안타 지는 반면 민초 맛 스트로베리 크림 맛 곱다 입자 자다 씻기다 너무 좋다 구매 기상 운동 먹다 금방 먹다 버리다 새롭다 빵빵 단백질 보다 기분 너무 좋아지다 민초 맛 들다 보다',
#  '처음 먹다 보다 마이 프로틴 사람 마이 프로틴 가성비 최고 키로 구매 먹다 인데 에도 자다 풀리다 자다 먹다',
#  '맛있다 맛있다 초코 느낌 솔트 카라멜 느낌 강하다',
#  '무맛 아이스 라떼 맛 꾸준하다 먹기 좋다 맛 퀄리티 무맛 작다 사이즈 구매 아이스 라테 크다 사이즈 이용 무맛 여러 디저트 간식 들다 단백질 대체 위해 사용 아이스 맛 수시로 마시다 사용 남매 라서 소비 많다 맛 밀크 커피 맛 부담 없이 많이 먹다 무맛 배송 오다 터지다 사고 정말 아쉽다 친절하다 해결 해주다 자다 해결',
#  '만족하다 운동 힘들다 간편하다 단백질 섭취 좋다 맛 기본 제품 크게 실패 하진',
#  '스트로베리 크림 복용 결과 맛 물의 비율 적다 많이 느끼하다 비율 상당하다 중요하다 희다 자다 섞이다 인데 덩어리 지다 가끔 발생 배송 해외 배송 이라 정도 예상 만에 도착',
#  '가성비 끝판 맛 정말 훌륭하다 가격 너무 저렴하다 번째 구매 인데 먹다 가다 주문',
#  '아이스 라떼 맛 그동안 커피 맛 좋다 구매 구매 커피 맛 나다 프로틴 특유 맛 믿다 구매 실망',
#  '딸기 우유 맛 국산 프로틴 먹다 처음 임팩트 웨이 프로틴 가성비 좋다 넘어오다 배송 대략 걸리다 스토 베리 크림 정말 맛 딸기 우유 맛 크다 많다 풀림 약하다 덩어리 많이 지다 리뷰 보다 자다 흔들다 자다 풀리다 흔들다 심하다 흔들다 거품 많다 거품 거품 가라앉다 기다리다 마시다 무방 먹다 녀석 마시다 보다 달달 맛 좋다',
#  '아이스 라떼 최고 진짜 너무 맛있다 입문 으로도 최고 달달 하고 커피 맛 최고',
#  '후배 구매 초콜릿 스무 타도 맛있다 솔티드 카라멜 심심함 우유 맛 우유 살찌다 겁나다 많다 딜레마 빠지다 그냥 많이 살다 정답 판매 초콜릿 스무디',
#  '아주 많다 맛 좋다 무맛 구매 해보다 없다 공백기 갖다 내추럴 초콜릿 맛 짜다 주문 짜다 처음 받다 보다 포대 자루 수준 이네 정말 큼직하다 맛 굉장하다 달다 향 맛 믹스 생각 너무 커서 적다 스쿱 찾다 서다 먹다 발견',
#  '스트로베리 크림 이건 무조건',
#  '굳다 매우 좋다 추하다',
#  '맛 불호 갈리다 기본 초콜렛 맛 여느 프로틴 쿠키 크림 진짜 비추다 스트로베리 딸기 우유 맛 나서다 보다 중간 중간 맛 바꾸다 차다',
#  '나이스 할인 덕분 좋다 프로틴 찾다 자다 게요',
#  '좋다 할인 사다 생각 보다 맛 괜찮다 좋다 계속 구매',
#  '마프 이건 필수 민트 초코 좋아하다 민트 초코 강추 우유 먹다 진짜 그냥 카페 음료 똑같다 민트 맛 강하다 그냥 잔해 자다 풀리다 아쉽다 가락 자다 풀다 먹다 맛 보장 정도 수고 로움 감수',
#  '임팩트 웨이 사고 싶다 찾다 가요 없다 건가',
#  '가성비 운동 하고 정수기 먹다 스트로베리 크림 이랑 솔티드 카라 메다 맛 먹다 맛있다 풀림 덜하다 크게 신경 쓰이다 정도 아니다',
#  '베이 크드 프로틴 오트 짱 맛 이런저런 먹다 마프 꺼느 처음 인데 성분 맛 되게 좋다',
#  '만족 주문 도착 배송 생각 보다 빠르다 스트로베리 크림 강추 서울 우유 딸기 맛 이랑 똑같다 가루 먹다 맛있다',
#  '키로 만에 먹다 또삼 항상 믿다 먹다 꾸준하다 운동 추천',
#  '코스 무스 맛 나다 스트로베리 맛있다 키로 먹다 키로 다시 마지막 물리다 초코 사다 물리다',
#  '임팩트 웨이 프로틴 맛 정도 맛 재다 의사',
#  '맛있다 자주 구매 먹다 득근',
#  '다이어트 필수 지금 스트로베리 크림 아이스 라떼 내추럴 초코 먹다 보다 스트로베리 이고 초코 괜찮다 라떼 비리다 정도 먹다 적당하다 배고프다 먹다 정말 좋다',
#  '너무 만족하다 남편 운동 하고 보충 벨트 구매 가성비 당연하다 최고 이고 맛 너무 만족스럽다 우유 먹다 맛 잇다 먹다 맛 잇다 우유 보다 적다 보충 많다 필수 먹다 구매 예약',
#  '유당불내증 유당 내증 때문 인지 뽀드락 생기다',
#  '프로틴 후기 가격 훌륭하다 맛 다양하다 좋다',
#  '쉐이크 헬린 장점 맛 나쁘다 스쿱 들다 좋다 단점 처음 스쿱 찾기 쉬다 처음 뜯다 부분 가루 제거 해주다 사용 가능하다 직구 상품 성분 번역 좋다 텐데 참고 제품 가루 단백질 포함',
#  '네츄럴 초콜렛 강츄 회사 프로틴 먹다 종종 얼굴 여드름 이나 트러블 생기다 마이 프로틴 없다 트러블 없다 우유 섞다 먹다 니까 하루 아침 쾌변 정도 맛 평가 보다는 먹다 트러블 없다 말씀드리다 싶다',
#  '좋다 가격 자다 구입 좋다 가격 자다 구입 가성비 좋다 대서 구입 해봤다 맛 좋다 성분 좋다 으로도 계속 구매 구요',
#  '가성비 맛 마리 음맛 이며 가격 이며 제일 풀림 좋다 먹기 좋다',
#  '맛 잇다 스트로베리 크림 맛 잇다 단백질 처음 사보다 처음 들다 거부 없이 받아들이다 느낌 이에요 소진 주문',
#  '민트 초코 제일 좋다 우유 어울리다 맛 반면 물이 자다 어울리다 맛 물이 가장 자다 어울리다 맛 민트 초코 우유 말고 먹다 니까 가장 베스트 우유 베이스 맛 과도 자다 어울림',
#  '프로틴 맛있다 자다 섞다 가루 남아 너무 먹기 좋다 니당다',
#  '가격 대비 만족하다 군대 아들 먹다 프로틴 보다 저렴하다 상품 좋다 사서 보내다 주다 매우 만족하다 먹다 프로틴 보다 저렴하다 품질 괜찮다 만족스럽다',
#  '밀크티 진짜 맛 공차 버블티 맛 거품 많다 맛 밀크티 조화 자다 살리다 내다 녹차 맛 이랑 밀크티 아직 먹다 보다 처음 마이 프로틴 사다 만족',
#  '스트로베리 크림 그냥 딸기 우유 맛 맛있다 딸기 우유 맛 먹다 다려지다',
#  '페트 웨이 프로틴 스트로베리 크림 헬스 초보자 먹기 넘김 뒤끝 맛 특유 프로틴 맛 없다 서울 우유 딸기 맛 강추 드림',
#  '너무 맛 잇다 쉐이크 라서 무조건 찬물 자다 녹다 따뜻하다 밀크 티맛 먹다 보다 맛 진하다 느져 그냥 밀크티 훗카이도 밀크 섞다 먹다 맛있다 라떼 추가 구매 로는 너무 많다 질리다 키로로 여러 가지 맛 먹다 보다 구여',
#  '마프 마프 베스트셀러 라기 시킴 좋다',
#  '제일 많이 주문 사람 많이 주문 제품 이라 그냥 구매 운동 프로틴 먹다 좋다 주문 해봤다 초코 맛 인데 적당하다 좋다',
#  '밀크티 내츄럴 초코 좋다 맛있다 밀크티 먹다 중독 맛 처음 어리다 먹다 처럼 익숙하다 초코 맛 내츄럴 초코 주로 먹다 요즘 밀크티 맛 먹다 질리다',
#  '아이스 라떼 버블티 먹다 당연하다 맛 없다 언스 위트 아몬드 브리즈 먹다 정말 너무 맛있다 그냥 속세 맛',
#  '좋다 프로틴 카페라떼 맛 미숫가루 맛 커피 맛 나다 좋다 달달 거나 보다',
#  '프로틴 무조건 마이 프로틴 프로틴 진짜 좋다 프로틴 인지 모르다 먹다 그냥 카페 팔다 음료 맛 나다 정도 퀄리티 가능하다 건지다 정말 좋다 재다 햇습니',
#  '아이스 라떼 맛 원래 스트로베리 크림 맛 먹다 아이스 라떼 맛있다 주문 진짜 맛있다 원래 찾다 먹다 스타일 이라 스트로베리 크림 달다 이건 좋다 맛 이냐 군대 믹스 커피 냉장고 넣다 아이스 믹스 커피 먹다 맛 인데 믹스 커피 찌다 그렇다 느낌 아니다 그렇게 지도 차다 설명 어렵다 그냥 적당하다 맛 주관 맛있다 아니다 누나 스트로베리 크림 맛 아이스 라떼 맛 먹다 보고 아이스 라떼 맛있다 가져가다 먹다',
#  '임펙트 웨이 프로틴 초콜릿 스무 스맛 프로틴 처음 먹다 보다 진짜 주변 팔다 초코우유 맛 인데 그거 보다는 달달 맛 이라고 보시 처음 먹다 보다 냄새 지도 진짜 요즘 프로틴 먹다 운동 수준 강추',
#  '임팩트 웨이 굿굿 역싀 가성비 좋다 믿다 먹다',
#  '밀크 티맛 훗카이도 밀크 맛 섞다 먹다 맛있다',
#  '맛 좋다 소화도 자다 제품 가격 너무 좋다 단백질 질도 너무 좋다',
#  '단백질 보충 후기 단백질 함유량 왠만하다 단백질 보충 용량 사면 비싸다 용량 구매 할인 받다 왠만하다 프로틴 보다 가격 싸다 맛 다양하다',
#  '맛있다 우유 태우다 먹다 여드름 사람 한텐 좋다 딸기 맛 태우다 마시다 맛있다',
#  '괜찮다 군대 서다 드리다 맛있다',
#  '국내 끄다 먹다 처음 보다 국내 기선 할인 받다 녹차 초콜렛 카라멜 정말 맛있다',
#  '스트룹 와플 맛 쏘다 우유 먹다 맛있다 앙이다 먹다 얼다 밍밍 와플 맛 나용 우유 먹다',
#  '마이 프로틴 초보 입문 저번 마이 프로틴 스트로베리 초콜릿 스무 사고 지금 꾸준하다 먹다 부작용 발생',
#  '많이 팔리다 맛 괜찮다 아니다 베스트셀러 스트로베리 크림 코스 무스 구매 읍니 스트로베리 크림 먹다 자판기 팔다 음료 트로피카나 딸기 라떼 맛 코스 무스 팔다 초코우유 섞다 맛 나오다 비릿함 완벽하다 저렇게 미리 먹다 보고 구매 바라다 스트로베리 크림 어찌어찌 먹다 코스 무스 아무리 생각 없다 심보 맛있다 추천 시체 결과 물이 라고 밖에 생각',
#  '필요하다 마프 헬창들 피다',
#  '마프 제일 무난 초코 주문 맛있다',
#  '초코 코스 무스 초코 맛 맛있다',
#  '민트 초코 무조건 들다 민트 초코 좋아하다 불다 무조건 들다 우유 먹다 진짜 그냥 카페 팔다 음료 보다 맛있다 신기하다 정도 민트 맛 살짝 그냥 초코 보다 질리다',
#  '좋다 제품 아들 군대 입대 선임 추천 받다 제품 꾸준하다 구매 먹다 제품 보다 안전하다 믿다 먹다 아들 얘기',
#  '비추다 마프 인데 진짜 인상 별로 먹다 노맛 우유 먹다 맛 인데 거품 뭉치다 때문 빡치다 헬스장 웨이트 보다 뭉치다 푸다 빡셈 그나마 우유 먹다 맛있다',
#  '딸기 맛 좋다 처음 먹다 보다 프로틴 인데 부담 없이 먹다 좋다',
#  '밀크티 주문 밀크티 처음 구매 달다 정말 만족하다 맛 리뷰 추천 부탁드리다 국산 저가 웨이 프로틴 계속 먹다 처음 마프 구매 시도 크다 먹다 밀크 티맛 주문 달다 너무 좋다 계속 먹다 국내 제품 달다 진짜 너무 달다 먹다 마다 불쾌하다 계속 고민 맛 추천 댓글 단맛 싫어하다 사람 말차 라떼 밀크티 가라 말차 라떼 가다 금방 품절 버리다 왠지 밀크티 단맛 너무 심하다 밀크티 선택 정도 안질리다 먹다 참고 원래 밀크티 즐기다 말다 좋아하다 마트 팔다 미리 짜다 밀크 음료수 설탕 빼다 맛 유청 단백 특유 텁텁 향 아주 살짝 올라오다 먹기 에는 전혀 거북하다',
#  '맛있다 운동 열심히 먹다 맛있다 먹다 먹다 구요',
#  '밀크티 미니 크다 스프링 넣다 섞다 거품 상당하다 많이 나다 풀리다 덩어리 작다 크다 한두 정도 맛 호불호 싶다 굉장하다 만족하다 홍차 밀크티 특유 향 하진 분명하다 밀키 맛 너무 지도 적당하다 수입 밀크티 믹스 보다 연하다 맛 밀크티 굉장하다 만족스럽다 맛 홍차 밀크티 싫어하다 거부 모르다 먹다 무조건 주문 라떼 밀크티 밀크티 개취 저격',
#  '좋다 다양하다 맛 먹기 좋다 즐기다 먹다 아이스 라떼 맛 입다 부탁드리다',
#  '맛있다 아이스 라떼 맛 맛있다 강추',
#  '아이스 라떼 아이스 라떼 맛 빼다 좋다',
#  '밀크티 출시 짜다 사서 너무 만족하다 용량 없다 단가 비싸다 아쉽다 다시다 먹다 생각 키로 나오다 주문 개인 차다 너무 너무 맛있다 박다 개봉 옆구리 찢어지다 가루 여기저기 나오다 고객 센터 문의 구매 보상 조치 해주다 재배 송도 가다 주문 맛 먹다 다시 주문 하렵 마프 서비스 만족',
#  '아이스 라떼 맛 비추다 당직 서면 보관 만들다 먹다 아이스 맥심 골드 맛 구요 자다 섞이다 덩어리 지다 에는 그냥 초코 맛',
#  '마프 초코 브라우니 내추럴 바나나 스트로베리 크림 먹다 보충 자체 마프 초코 브라우니 처음 시작 정말 맛 코코아 느끼다 보충 그렇다 알다 초코 맛 질리다 내추럴 바나나 맛 운동 접다 싶다 정도 끔찍하다 나날 단백질 특유 비리다 맛 중화 지금 생각 구역질 나오다 최악 맛 절반 먹다 나머지 버리다 억이 나다 한동안 마프 내추럴 바나나 충격 너무 강하다 다시 초코 브라우니 고민 맛없다 보충 트라우마 생기다 그것 보다 맛있다 늘다 보충 찾기 시작 찾다 소문 대로 정말 맛있다 보충 늘다 비싸다 운동 먹기 에는 부담스럽다 맛 어쩔 없이 다시 가성비 좋다 프로 돌아오다 에는 당하다 결심 여러 리뷰 살펴보다 심사숙고 맛 스트 베리 크림 주문 물건 도착 오늘 스트로베리 크림 스쿱 우유 먹다 보다 감상 단백질 보충 제의 혁명 딸기 우유 츄파츕스 딸기 맛 중간 어딘가 위치 달짝지근하다 익숙하다 감미료 향 좋다 감싸다 줍다 단백질 비리다 맛 에도 찾아보다 없다 코코아 분말 초코 브라우니 달리 가루 휘날리다 에는 자다 풀리다 역시 마프 대표 맛 이라고 자부 스트로베리 크림 정말 맛있다 초심자 추하다',
#  '맛 좋다 영양 만점 맛 상당하다 좋다 츄럴 초코 맛 맛 쿠키 초코 맛 제일 맛 잇다 추천 드리다 꾸준하다 랜들 사용 너무 맛 잇다 동생 에게도 추천 만큼 좋다 브랜드',
#  '우유 마프 우유 마프 한스쿱 들다 원래 보충 먹다 넣다 먹다 마프 맛있다 진짜 맛있다 초코우유 리가 넣다 진짜 맛있다 가성비 갑인 배송 안되다 짱 이에요',
#  '스트로베리 크림 별로 스트로베리 크림 맛 평가 좋다 먹다 보다 주변 사람 어리다 먹다 기약 맛 나서다 싫다',
#  '굳다 토피 맛 사다 맛 좋다 달달 텍스쳐 좋다 보다 가다 성비 짱',
#  '먹다 눈물 흘리다 진짜 민초 맛 미치다 진짜 구매 하고 배송 오다 적다 용량 살다 싶다 오늘 운동 끝내다 베타 크레 무맛 이랑 섞다 먹다 진짜 신세계 봉지 끄다 냄새 냄새 민트 맛 연하다 싶다 유랑 먹다 편의점 팔다 민초 맛 말다 신나다 흔들다',
#  '웨이 프로틴 쵸코 브라우니 임프루브 맛있다 좋다 예전 버전 좋다 역시 가성비 로는 무적',
#  '마프 깡패 제품 마프 깡패 제품 항상 포정 사먹다 코코넛 넣다 쏘다 쏘다 우유 넣다 필리핀 먹다 제대로 코코넛 스무디 맛 미치다 초코 브라우니 넣다 우유 넣다 깡패 초코 먹다 안질리다 우유 격차 크다 바나나 바나나 좋아하다 괜찮다 후반 질리다 밀크티 정도 먹다 질리다 우유 먹다 느끼하다',
#  '짱짱 항상 마프 먹음 사르다 오다',
#  '라떼 맛 고민 지르다',
#  '아이스 라떼 맛 진짜 좋다 거품 많이 생기다 초콜릿 거품 나다 당황 스럽다',
#  '베리 최고 대부분 무난 단맛 달다 땡기다 마시기 좋다 스트로베리 크림 딸기 향 강하다 단맛 딸기 우유 섞이다 좋다 말차 라떼 팔다 달달 라떼 자체 섞이다 좋다 쿠키앤크림 쿠키 반죽 느낌 그냥 연유 느낌 자다 섞이다 덩이 덩이 씹다 쿠키 씹다 먹다 려고 일부러 이렇게 만들다 건가 라는 생각 이듬',
#  '레이 후기 운동 간단하다 섭취 좋다 맛 너무 맛있다 먹기 위해 운동',
#  '겁나다 맛있다 찌다 맛있다 맛있다 근육 키우다 이만 맛 없다',
#  '돌다 돌아서다 내츄럴 초코 골고루 먹어봣 초코 장기 먹기 좋다 풀림 좋다 맛 좋다 오래 먹다 사람 무조건 초코 맛',
#  '프로틴 맛 괜찮다 스트로베리 크림 맛 구매 딸기 우유 냄새 맛 딸기 우유 맛 딸기 좋아하다 추천 드리다',
#  '좋다 군대 달다 꾸준하다 가다 단백질 챙기다 먹다 사다 짜다 정도 밖에 먹다 거지 색기 훔치다 사다 민초 킬런 생각 보다 민트 쎄다 옛날 편의점 파다 덴마크 민초 우유 기대하다 민트 보다 초코 맛 쎄다 초코 한테 묻히다 근데 먹다 살다 맛',
#  '찌다 리뷰 아이스 라떼 맛 진짜 단백질 느끼하다 없다 스트로베리 크림 맛 살짝 느끼다 진짜 맛있다',
#  '맛있다 리뷰 많다 아이스 라떼 사보다 맛있다 에도',
#  '',
#  '역시 역시 사람 추천 이유 알다 달달 운동 스쿱 운동 끝나다 스쿱 너무 좋다',
#  '솔티드 카라멜 나쁘다 솔티드 카라멜 이라고 맛 태우다 먹다 무차 맛 나다 초코 맛 비다 질리 단맛 특유 쓴맛 상대 적다 부담 없이 먹다 좋다 길다 섭취 완전 좋다 마프 대란 사기 만족하다',
#  '녹차 라떼 맛 지금 먹다 보다 맛 에선 넘김 깔끔하다 맛있다',
#  '맛있다 맛 네스 이랑 다르다 없다 운동 하고 흔들다 마시기 좋다',
#  '맛있다 딸기 맛 딸기 맛 맛있다 먹다 보다',
#  '카라멜 먹다 레깅스 말씀 드릴 운동 먹다 달콤하다 카라멜 감싸다 천사 찌르다 맛 나다 완전하다 김치 버리다 녹초 카라멜 뿌리다 숙성 레깅스 오늘 레깅스 찢다 내일 핑크',
#  '딸기 맛 최고 기존 초코 맛 먹다 처음 에는 맛있다 자다 먹다 질리다 딸기 맛 먹다 먹다 맛있다 딸기 우유 너무 추천 짱',
#  '진짜 맛 맛있다 가격 민트 초코 이렇게 맛있다 만들다 혁명 이에요',
#  '맛있다 맛있다 가성비 좋다',
#  '민초 초콜렛 민트 민초 프로틴 맛있다 일일 끄다 역시 민초 초콜렛 민트 맛 들다 민초 행복하다 세계 입성 가능하다',
#  '가성비 진짜 거만 없다 아무리 찾아보다 탄수화물 함량 만큼 낮다 서빙 가격 이만 제품 없다 스트로베리 크림 무난 소모 우유 에는 풀리다',
#  '이튼 메스 무료 사은 너무 맛있다 제품 없다 건가',
#  '말차 라떼 스트로베리 크림 초콜렛 스무 말차 라떼 너무 만족 아직 많이 크다 스트로베리 크림 좋다 정말 무난 초콜렛 스무 정말 취향 아니다 먹다 걱정 앞서다 밀크티 말차 라떼 스트로베리 크림 먹다 엄청 맛 나다 먹다 마프 초코 계열 대가 엄청 크다 회사 사도 초코 실패 없다 한국 포대 유청 초코 맛 익숙하다 맛 이건 뭔가 되게 낯선 맛 초콜렛 계열 만큼은 먹다 싶다',
#  '맛있다 프로틴 구입 이전 에는 아이스크림 먹다 보다 맛 와는 맞다 건지다 모르다 마이 프로틴 스트로베리 크림 마프 지키다 맛 인지 알다 맛있다',
#  '크게 기대다 하고 맛 먹다 보고 싶다 주문 생각 보다 맛있다 평소 딸기 우유 프라푸치노 제품 좋아하다 선택 보다 좋다 자다 풀어지다 넘김 나쁘다',
#  '블루베리 치즈 케익 오늘 처음 개봉 먹다 보다 맛 지도 밍밍 맛 나다 먹다 대신 블루베리 치즈 케익 향 정말 달콤하다 달콤하다 향 맛 밍밍 블루베리 치즈 케익 맛 구매 들다 너무 향 기대하다',
#  '사냥 맛 이네 아이스 라떼 추천 주문 더위 사냥 맛 지방 우유 넣다 말다 이만 없다 배송 느리다 제외 곱다',
#  '팔짱 재밌다 키로 짜다 아이스 라떼 맛 지르다 오다 재밌다 허다 달콤하다 커피 느낌 팔짱 도리 도리 고개 저으 맛 열심히 운동 하고 나서다 마시기 증말 좋다 김성수 얼른 오다 들다 보다',
#  '스트로베리 크림 맛 막히다 밀봉 자다 어쩔 없다 크다 덜다 먹다 괜찮다 그냥 딸기 우유 자체',
#  '말차 라떼 밀크티 스트로베리 크림 먹다 원래 진짜 좋아하다 말차 라떼 정말 만족하다 밀크티 정말 특별하다 느낌 없이 무난 느끼다 스트로베리 크림 담백하다 질리 먹다 보충 엄청 달다 분들 종종 계시다 단맛 대해 서다 국제 초코 맛 먹다 경험 때문 인지 원래 단맛 선호 모르다 전반 단맛 약하다 생각 제법 많이 달다 아무렇다 지장 없다 정도 달다 안질리다 즐겁다 먹다',
#  '추천 맛 추천 맛 개인 취향 이니 참고 강추 아이스 라떼 민트 초코 추천 초콜렛 스무 그냥 그렇다 마차 맛 나쁘다 빨리 물리다 작다 사이즈 밀크티 맛 괜찮다 풀림 별로 모카 진짜 생각 해도 화가 맛 짜다 커피 저렴 초코 맛 민트 코스 비아 리스 테린 맛 딸기 이건 딸기 보충 싫어하다 초콜렛 브라우니 풀림 좋다 초코 라서 먹다 기분',
#  '좋다 가성비',
#  '임팩트 웨이 스트로베리 크림 임팩트 웨이 스트로베리 크림 먹다 보다 우유 두유 먹다 딸기 우유 맛 진하다 나서다 맛있다 먹다 진하다 맛 덜하다 먹다 만하 달다 느껴지다 마프 임팩트 웨이 에선 맛있다 생각',
#  '딸기 우유 스트로베리 크림 왐볃 딸기 우유 맛',
#  '민초 맛 민초 맛 원래 민초 맛 좋아하다 대다 진짜 호불호 없다',
#  '아이스 라떼 대박 그냥 더위 사냥 녹이다 맛 최애 맛 거만 먹다',
#  '맛 잇다 맛 잇다 먹기 너무 간편하다 바쁘다 먹다 좋다',
#  '입맛 입맛 느끼하다 배송 넘다 느리다',
#  '스트로베리 크림 후기 메이커 무맛 먹다 딸기 맛 먹다 달다 해도 먹다 부담 없다 용량 이라 가격 부담 없다 자주 필요 없다 좋다 아들 사료 알다',
#  '민트 초코 맛 많이 나다 괜찮다 민트 초코 맛 많이 나다 괜찮다 단백질 특유 맛 때문 맛 먹다 거부 많이 민트 초코 가장 거부 없이 자다 넘어가다',
#  '추천 웨이 시작 구매 맛 좋다',
#  '임팩트 웨이 프로틴 추천 맛 먹다 보다 제일 베스트 화이트 초콜렛 이랑 섞다 먹다 맛있다 자다 크다',
#  '초코바나나 맛 운동 하고 섭취 인데 맛 괜찮다 거부 없다 너무 좋다',
#  '민초 맛있다 민초 맛 민초 최고 사랑 민초 맛있다 운동 싫다 에도 먹다 운동',
#  '확실하다 가성비 차다 좋다 할인 니까 양도 많다 먹다 싶다 수준 말차 라떼 맛 초반 벌컥벌컥 자다 마시다 확실하다 계속 먹다 보다 물리다',
#  '가성 비다 갖추다 입문 자다 프로틴 최근 운동 입대 자다 배치 받다 운동 겟다 프로틴 알아보다 마이 프로틴 가성비 좋다 한번 주문 짜다 동기 사서 현재 운동 먹다 잇다 결과 효과 좋다',
#  '맛있다 배송 걸리다 할인 받다 싸다 가격 민트 혐오 자다 시원하다 맛있다',
#  '믿다 먹다 마이 프로틴 항상 마이 프로틴 프로틴 구매 먹다 으로도 쭈욱 계속 자다 이용',
#  '내츄랄 초코 행복 느끼다 내츄랄 초코 내츄랄 초크 행복',
#  '실패 없다 레시피 골든 시럽 아이스 라떼 카누 쓰다 묵다 스벅 라떼 부럽다',
#  '미국 스타일 피넛 버터 맛 솔직하다 해외 유튭 에도 맛 대한 후기 없다 진짜 걱정 많이 먹다 실망하다 버리다 본인 검다 두유 먹음 아몬드 브리즈 견과류 아몬드 냄새 진짜 많이 두유 넣다 그렇다 진짜 맛있다 땅콩 이나 아몬드 견과류 음료 좋아하다 사람 한테 추천 괜찮다 단독 먹기 많이 느끼하다 금방 질리다 수도 듯함 느끼하다 싫어하다 사람 비추다 맛 꾸다 하고 아무튼 맛 자체 무거 결론 아몬드 브리즈 아몬드 설탕 넣다 맛 맛 아몬드 씹다 텁텁함',
#  '골든 시럽 후기 엄청 근데 알다 물리다 맛 개인 우유 보다 먹다 좋다',
#  '최고 가성비 좋다 맛 아주 좋다',
#  '맛 딸기 맛 맛임 저번 초코 먹다 너무 맛 없다 딸기 뭔가 플라스틱 냄새 나다 좋다',
#  '프로틴 초코 맛 자다 먹다 맛있다 굳다',
#  '내추럴 초콜릿 맛 끼다 완전 네스퀵 맛 맛 잇다 먹다 맛 미숫가루 섞다 맛 숭밍숭 원료 바뀌다',
#  '스트로베리 크림 무난 맛있다',
#  '아이스 라떼 맛제 지금 먹다 오입 깔다 끄다 쓰다 맛 솔직하다 모르다 맛 먹다 아니다 굳다 굳다 맛 좋다 아니다 먹다 보다 인지 알다',
#  '임팩트 웨이 무맛 리뷰 무맛 맛 없다 의견 많다 걱정 늘다 우유 섞다 먹다 보다 나다 첨가 제품 먹다 늘다 무맛 깔끔하다 오래도록 먹다 싸다 가격 자다 삿네 가성비 맛 잡다',
#  '임펙트 웨이 프로틴 스트로베리 크림 정말 제품 과는 다르다 특유 비리다 맛 없다 우유 먹다 딸기 우유 재다 의사 최고',
#  '웨이 프로틴 리뷰 계속 프로틴 바꾸다 먹다 돌다 돌다 마이 프로틴 가장 좋다 벌써 연속 번째 구매',
#  '츄럴 스트로베리 맛 프로틴 항상 초콜릿 브라우니 맛 먹다 네츄럴 스트로베리 맛 먹다 진짜 딸기 갈다 먹다 맛 좋다 멀다 가다 느낌 프로틴 자체 수분 아주 처럼 조금씩 뭉치다 그렇다 느낌 먹다 아무렇다 지장 없다 풀림 성도 좋다',
#  '아직 이만 프로틴 없다 중학생 철봉 달리기 시작 어느덧다 웨이 지다 정도 본론 좋다 프로틴 먹다 보다 개인 초코 맛 좋아하다 때문 맛 거기 거기 그렇다 가성비 제일 좋다 마프 살수 없다 계속 먹다 이만 가성비 없다 웨이 프로틴 제품 안행',
#  '좋다 가성 역시 제일 좋다',
#  '프로 프로틴 국산 끄다 먹다 먹다 올라가다 느낌 맛 으로도 완전 만족하다 진짜 맛있다',
#  '좋다 맛 좋다 가격 좋다 무조건 재다 매각 추천',
#  '매우 매우 만족 매우 매우 만족 많다 맛 정말 좋다 먹다 구매 가지 후회 전용 구입 후회되다 나중 구입 구매 매우 매우 만족 구입 들다 보다',
#  '먹다 잇다 맛 좋다 성분 먹다 다시 구해 거고 맛 정말 좋다 가성비 최고',
#  '가성비 최고 식단 짜다 하루 부족하다 주기 계속 먹다 하루 스쿱 먹다 더부룩하다 없다 좋다 임팩트 웨이 프로틴 이라 유당불내증 좋다 그렇다 소리 평소 우유 먹다 그렇다 부작용 없다 개월 먹다 근육 자다 붙다 근육 먹다 붙다 아니다 운동 붙다 크다 괜히 키로 만원 짜다 비싸다 프로틴 먹다 필요 없다 일반인 프로틴 섭취 흡수 단백질 그램 스쿱 그램 들다 마프 정말 좋다 추하다 맛 너무 쭉쭉 자다 들어가다',
#  '자다 먹다 먹다 자다 먹다',
#  '맛 먹다 싶다 샘플 먼저 프로틴 마이 프로틴 먹다 기존 초코 브라우니 오다 코스 무스 맛 먹다 초코 에는 가지 맛 깔끔하다 심플 맛 맛 먹다 보고 싶다 샘플 구매 지금 먹다 하고 쿠키 크림 맛 인데 주문 하고 먹다 맛 묵직하다 느끼하다 맛 속이다 좋다 이건 만의 개인 맛 리뷰 맛 괜찮다 샘플 초코 민트 커피 카라멜 인데 커피 카라멜 묵직하다 쿠크 다스 맛 느끼하다 맛 초코 민트 민트 초코 아이스크림 녹이다 맛 하고 똑같다 무조건 새롭다 맛 도전 기존 끄다 주문 샘플 주문 넣다 맛 보고 결정',
#  '먹다 운동 가요 그나마 식단 맛있다 먹다 단백질 쉐이 크다 그냥 먹기 양심 지갑 너무 찔리다 먹다 운동 가다',
#  '모카 건가 우유 먹다 연한 모카 라떼 맛 모카 향 밍밍 초코 느낌 부담 스럽지 맛 나쁘다',
#  '아이스 라떼 맛있다 진자 라떼 아주 자다 풀리다 더럽다 맛 없다 녹차 라떼 보다 자다 풀림 바닐라 초코 딸기 지치다 고르다',
#  '이건 믿다 먹다 번째 번째 재다 중인 제품 믿다 먹다 초코 맛',
#  '녹차 맛 맛있다 먹다 평소 무맛 계속 먹다 녹차 맛 주문 정말 맛있다 그냥 달달 녹차 아이스크림 맛 특식 먹다 기분 이네',
#  '선택 다양하다 맛 마프 기본 기본 프로틴 쿠키 크림 스트로베리 크림 솔티드 카라멜 메이플 시럽 훗카이도 밀크 밀크티 초콜릿 캬라멜 스트룹 와플 피넛 버터 팥맛 말차 라떼 맛있다 달다 맞다 이유 많다 주로 단맛 좋아하다 취향 이라 나열하다 모든 제품 황홀하다 정도 이고 평생 대신 로틴 먹다 해도 프로틴 선택 단맛 별로 좋다 거나 받다 유가 질적 번째 유가 체지방 많다 무조건 단맛 자다 받다 진짜 탄수화물 근육 크다 지방 빼다 온몸 선명 만들다 보다 체지방 가다 이라도 한순간 순삭 체지방 안다 자리 설탕 코코넛 크림 치즈 크림 트윅스 초콜릿 도넛 비스킷 바나나 찰떡 호떡 초코 무초 파운드 케이크 설탕 몰티저스 프레드 잔뜩 뿌리다 식빵 추러스 임팩트 웨이 프로틴 리터 캬라멜 사탕 입가심 커피 라떼 말다 지나다 폭발 일어나다 정도 땡기다 아무튼 마프 임팩트 웨이 맛 대해 다양하다 선택 정말 다행 이고 여러 가지 맛 향연 너무도 행복하다',
#  '처음 먹다 보다 마프 제품 여러 가지 먹다 보다 가다 지다 마프 먹다 보다 부드럽다 깔끔하다 좋다 제품 먹다 가끔 꾸르륵 거렸는데 이건 한테 맞다 좋다',
#  '맛 솔직 리뷰 솔직하다 프로틴 특유 비릿함 빼다 밀크티 맛 완벽 재현 저번 임펙트 다이어트 웨이 초코 맛보다 수십 배다 맛있다',
#  '커피 캬라멜 들다 참고 짜다 사서 정도 먹다 플라스틱 맛 나요 참고 먹다 먹다 참고',
#  '맛있다 단백질 제품 먹다 보다 제품 맛 여러 가지 선택 폭도 넓다 맛 괜찮다 꾸준하다 먹기 좋다 용량 구매 가격 저렴하다 가성비 좋다',
#  '밀크티 진짜 밀크 티맛 혁명 수많다 맛 들다 정도 맛 재현 높다 진짜 키로 제발 출시 주다 좋다 제발 제발',
#  '헬린이 평가 확실하다 케바케 소화기관 약하다 사람 인데 먹다 거나 소화 장애 적다 한번 없다 단점 이라고 하자 섭취 귀찮다 프로틴 맛 정도 맛 프로틴 치고 굉장하다 좋다 편입 아직 애기 핼린 고민 연하다 제품 사시 좋다 싶다',
#  '스트로베리 크림 맛 맛있다 우유 먹다 달달 딸기 우유 맛 이구 물이 먹다 맛 덜하다 많이 달달',
#  '임펙트 웨이 프로틴 여러 국내 제품 사먹다 여기저기 성분 장난 마이 프로틴 바꿧습니 아이스 라떼 정말 신세계 정말 맛 잇다 개인 취향 키로 먹다 가다',
#  '맛있다 웨이 먹다 친구 추천 바꾸다 넘다 맛있다 싸다 자다 사다',
#  '굳다 화이트 초콜렛 최애 굳다',
#  '맛 아주 그냥 맛있다 풀림 이랑 거품 생기다 기다리다 흔들다 기다리다 먹음',
#  '골든 시럽 달달 하고 맛있다',
#  '가격 저렴하다 좋다 가격 저렴하다 양도 많다 효능 좋다 운동 꾸준하다 섭취 하고 자주 구매',
#  '초코 맛 그다지 초코 맛 그냥 맹물 초코 가루 살짝 들어가다 맛 이라 그닥 맛있다 맛',
#  '주문 하루 두스 쿱씩 열심히 먹다 영양 맛 가성비 두루 갖추다 마프 살다 이유 없다 할인 코드 자다 쓸다 국내 끄다 말고 마프 사드 세요',
#  '가지 맛 먹다 보다 초코 딸기 말차 가지 맛 섭취 해봤다 맛 맛있다 초코 딸기 에도 자다 섞이다 거품 일어나다 말차 라떼 자다 풀리다 거품 너무 많이 일어나서 짜증 나다',
#  '운동 시작 추천 필요하다 가다 그대 지금 주문 하고 꾸준하다 운동 성장하다',
#  '여태 먹다 맛 평가 내추럴 초코 티맛 무난 먹기 편하다 자다 풀림 초콜릿 스무 내추럴 초코 크게 차이 없다 넘김 미세하다 차이 초콜릿 바나나 나름 괜찮다 크다 초코 먹다 쉬다 질리다 바나나 향 좋다 초콜릿 브라우니 칙촉 초코 맛 비스 무리 풀리다 정도 적당하다 괜찮다 스트로 크림 맛 딸기 우유 맛 감다 꾸다 넘김 드라이 무난 먹기 좋다 현재 애용 내추럴 스트로베리 스트로베리 크림 이랑 다르다 꾸다 딸기 베리 특유 맛 밉다 느낌 스트로베리 롤리 폴리 딸기 맛 나다 맛 아니다 그냥 밀가루 맛 로키 로드 초코 가루 묽다 풀다 먹다 느낌 맛 자체 괜찮다 이튼 메스 슈팅 스타 팝핑 캔디 맛 비슷 나쁘다 밀크티 일반 밀크티 없다 맛 좋다 아끼다 먹다 쿠키 크림 쿠키 맛 크림 식감 꾸다 훗카이도 밀크 질끈 감고 먹음 민트 초코 나다 도대체 산지 모름 바나 바나나 우유 맛 아니다 이면 아이스 라떼 맥심 맛 처음 호불호 나중 나름 괜찮다 복숭아 아이스티 립톤 립톤 좋다 살다 괜찮다 말차 피해 밀크티 재앙 그걸 누르다 순간 파국',
#  '딸기 향 스트로베리 크림 스트로베리 크림 사서 먹다 보다 배송 험하다 겪다 인지 개다 터지다 오다 터지다 프로틴 먹다 맛있다 특유 배다 비리다 향 나다 달달 딸기 우유 향 먹다 남다 봉지 먹다 친구 단백질 비리다 향 강하다 나오다 제품 구성 이렇게 맛 차이 심하다 가격 저렴하다 맛 다양하다 제품 민트 초코 홋카이도 밀크 오다 리뷰 해보다',
#  '초콜릿 스무 후기 처음 마프 구매 해봤다 초코우유 맛 나다 딱하다 남다 느낌 없다 좋다 유당 내증 까진 아니다 우유 먹다 먹다 정도 지나 니까 울렁거리다 아프다 부턴 레이 구매 맛 좋다 우유 자다 들다 추천',
#  '솔티드 카라 메다 솔티드 카라멜 서다 엄청 늦다 오다 알다 생각 보다 빨리 오다 말차 괜찮다 솔티드 카라멜 맛있다 부터는 느끼하다 느낌 만족스럽다 니당다',
#  '좋다 복숭아 아이스티 맛 상큼 좋다',
#  '만족도 웨이 프로틴 구매 아주 만족하다 맛 양도 배송 만족스럽다 재다 소비 구매 예정 다양하다 맛 체험 보고 자다 맞다 향 꾸준하다 구매',
#  '지금 먹다 보다 맛 지금 밀크 내츄럴 스트로베리 모카 스트로베리 크림 가지 먹다 보다 별로 좋아하다 사람 으로써는 밀크 내츄럴 스트로베리 대다 만족 모카 물리다 맛있다 스트로베리 크림 너무 달다 츄파츕스 딸기 맛 녹이다 느낌 맛 도전 해보다',
#  '밀크 스트로베리 맛있다 계속 먹다 질리다',
#  '역시 프로틴 임팩트 웨이 초코바나나 부르다 건강하다 프로틴 채우다 좋다',
#  '딸기 우유 맛 마시다 딸기 우유 맛 너무 맛있다 먹다',
#  '로키 추다 컬릿 마이 프로틴 꾸준하다 이용 중이 면서 리뷰 작성 맛 진짜 초콜릿 꾸다 덕함 그대로 진짜 제발 사드 세요 너무 맛있다 아시 제일 맛',
#  '굳다 굳다 말차 맛 엄청 맛있다 초코 브라우니 먹다 딸기 먹다 먹다 차갑다 재다 낫다 호불호 갈리다 맛 대다 만족',
#  '민초 사다 아무리 민초 싫어하다 마프 민초 먹다 싶다 맛없다 거만 먹다 맛있다 먹다 프로틴 먹다 맛 사다 계속 먹다 배송 예정일 보다 빨리 오다 택배 파업 이래서 걱정',
#  '기본 가장 좋다 티라미수 맛 도전 선택 티라미수 라기 보다 라비 껌맛 가깝다 먹다 정돈 아니다 딱하다 원하다 맛 아니다',
#  '구매 넘어서다 오다 일이 빨리 도착 너무 행복하다 맛 없다 너무 좋다 생각 설레다 헤으응',
#  '고르다 먹다 맛 브랜드 이렇게 다양하다 맛 프로틴 보유 하고 회사 가성비 최고 맛 그리다 까다롭다 정도 까다롭다 프로틴 자체 먹다 개인 훌륭하다 생각 풀림 좋다 효과 이건 브랜드 비교 어렵다 어차피 운동 퀄리티 따르다 다르다 맛 다양하다 사서 따르다 먹다 고르다 먹다 꿀잼',
#  '맛차 라떼 맛 킷캣 녹차 맛 이랑 똑같다',
#  '맛있다 솔직하다 초단 아니다 프로틴 먹다 맛있다',
#  '좋다 자다 먹다',
#  '좋다 가성비 좋다 맛 매우 좋다 만족',
#  '무맛 구매 약하다 분유 냄새 나다 과일 섭취 맛 좋다',
#  '키로 포대 먹다 후기 추럴 스트로베리 추럴 초콜렛 번갈아 가면 먹다 유당불내증 딱하다 없다 질량 맞추다 이만 가성비 없다',
#  '역시 마이 프로틴 믿다 먹다 차맛 좋아하다 맛 구매 맛 좋다 단백질 함량 좋다 운동 끝나다 스쿱 먹다 브랜드 보다 가다 성비 좋다 성분 좋다 믿다 먹다',
#  '괜찮다 편입 저렴하다 가격 품질 좋다 단백질 파우더 라고 생각 스트로베리 크림 맛 정말 호불호 갈리다 맛 너무나 서다 고생 어쩔 없이 먹다 보다 스트로베리 크림 적응하다 맛 추천 하고 싶다 맛 네츄럴 초코 초콜릿 스무 추천',
#  '굳다 밀크 티맛 추하다',
#  '무맛 사지 절대 타지 허들 너무 높다 소금 넣다 사골 국맛 상당하다 넘기다 힘드다 무맛 우유 그나마 먹다 만해 맛 소리 아니다 무맛 싸다 사면 무조건 후회',
#  '최고 맛 최고 가격 최고 배송 예전 마이 프로틴 임펙트웨이 자다 희다 지금 매우 자다 희다 맛있다 특히 코스 무스 맛 스트로베리 크림 마이 프로틴 먹다 사람 들이다 최고 라고 칭찬 맛 가격 회사 제품 보다 저렴하다 문제 지적 배송 부분 많이 개선 멀리 주일 이내 도착 도로 신속하다 아주 마음 들다',
#  '굉장하다 건강하다 맛 건강하다 맛 적당 달달 하고 에도 자다 풀리다 기회 이벤트 재다 의사',
#  '맛있다 맛 좋다 시나몬 맛 풀리다 단점',
#  '아주 좋다 운동 먹다 먹다 보다 변화 크다',
#  '이름 그대로 맛 맛 고르다 지다 고민 민트 초코 좋아하다 맛 사면 후회',
#  '맛있다 요거트 체리 좋아하다 주문 자다 맛 늘다 보통 사람 입맛 불호 많다 맛 이에요 남자친구 운동 맛 별로',
#  '마싯다 나름 괜찮다 입맛 특이하다 프로틴 맛 먹다 보다 맛 으로만 주문 입맛 자다 맞다',
#  '너무 맛있다 마프 가성비 최고 이제 서다 후회',
#  '득근 필수 요소 가격 가성비 최고 맛 어딜 가나 맛있다 맛 맛있다 다양하다 맛 항상 시도 해주다 마이 프로틴 이라 부분 정말 마음 듭니 가끔 함정 맛 풀림 웨이 프로틴 종류 늘다 먹다 보다 충분하다 좋다',
#  '초코 오렌지 초콜렛 이라 걱정 많이 외로 뒷맛 오렌지 향 올라오다 맛있다 진짜 제주 감귤 초콜렛 맛 나요',
#  '말차 프로틴 먹기 힘드다 넘다 맛 나다 그냥 차라 떼이다 두유 먹다 자꾸 먹다 싶다 여름 시원하다 먹음 짱 이겠다',
#  '굳다 맛 물리다 좋다 민트 초코 처음 인데 되게 시원하다 맛임 추천',
#  '가성비 영양 최고 가성비 좋다 함유량 원료 최고 에요',
#  '맛있다 먹다 보다 정말로 맛있다 배다 장이 약하다 인데 배다 아프다 여드름 지다 좋다',
#  '딛다 프로틴 분유 느낌스 프로틴 가끔 물이 질리다 우유 먹기 우유 먹다 너무 맛있다',
#  '굿굿굿 추천 이용 펙트 웨이 민트 초코 주문 너무 맛있다 맛 깔끔하다 주변 친구 에게도 추천 하고',
#  '효과 보다는 단백질 섭취 자다 먹다 식사 단백질 섭취 계산 해보다 많이 부족하다 아침 저녁 쉐이크 먹다',
#  '아잉 말굽 딸기 크림 맛 사다 맛 좋다 우유 프로틴 섞다 먹다 부르다 끄다',
#  '가성비 최고 지금 정도 애용 인데 가성비 정도 프로틴 없다 맛 다양하다 최고 에요',
#  '가성비 갑종 지뢰 맛 맞다 맞다 가격 정도 성분 맛 찾아보다 없다',
#  '좋다 계속 먹다 좋다',
#  '웨이 프로틴 가성비 좋다 여러 단백질 보충 구입 보다 가성비 마이 프로틴 임팩트 웨이 프로틴 단연 최고 마이 프로틴 할인 자주 때문 할인 자다 보고 사면 가계부 쓰다 칭찬 받다',
#  '가장 무난 맛 함량 높다 맛 먹기 가장 무난 하고 좋다 상품 운동 에는 먹다 식사 대용 먹다 아몬드 두유 오트 블루베리 견과류 햄프 씨드 카카오 닙스 넣다 대용 사용 하고',
#  '가성비 끝판 추천 받다 구매 가격 너무 싸다 영향 성분 니깐 만큼 이득 프로틴 없다 운동 가슴 먹다 말다 너무 편하다 츄럴 초코 추천',
#  '웨이 프로틴 내츄럴 초콜릿 맛 가성비 최고 맛 휼륭하다 풀림 좋다 편입',
#  '사다 아주 맛있다 자다 먹다',
#  '맛있다 정말 정말 츄파춥스 딸기 우유 맛 은은하다 맛있다',
#  '맛있다 초콜릿 스무 자다 섞이다 맛있다',
#  '처음 용량 구매 해봤다 맨날 구매 처음 구매 구매 브랜드 비교 비리다 맛 아예 없다 맛있다 가끔 식사 우유 먹기 우유 먹다 너무 맛있다 살찌다 걱정 정도',
#  '적극 추천 브랜드 초코 맛 많이 먹다 보다 딸기 맛 주문 너무 맛 적극 추천 드리다 진짜 팔다 딸기 우유',
#  '가성비 최고 맛 괜찮다 영양성분 비싸다 프로틴 못지않다 훌륭하다',
#  '너무 좋다 자번 키로 거지 맛 정말 맛있다 자다 풀리다 특히 가격 너무 싸다 장점',
#  '마이 프로틴 에서의 구매 용량 대비 가성비 죽여주다 들다 좋아하다 맛 선택 역시 그냥 태우다 먹다 맛있다 물이 밋밋하다 거기 방울 떨어뜨리다 먹다 신세계 덥다 맛 가격 잡다 마이 프로틴 상품 구매 절대로 후회 없다 생각',
#  '스트로베리 크림 맛 너무 달다 스트로베리 크림 맛 너무 달다',
#  '복숭아 복숭아 맛 많이 느껴지다 달다',
#  '프로틴 달다 싫어하다 적극 추천 질리다 근육 늘리다 체지방 이고 열심히 운동 여자 이고 다이어트 때문 열심히 먹다',
#  '처음 입문 스트로베리 요물 먹다 먹다 딸기 맛 맛 잇다 먹다 최소 본전 맛 입문 스트로베리',
#  '맛있다 맛 맛 식스 먹다 넘어오다 칼로리 부담 없다 차다 좋다',
#  '짱 짱 가성비 좋다 맛 만족하다',
#  '최고 가성비 다양하다 맛 최고 가성비 기간 구입 배송 기간 길어지다 단점 놓다 구매 정도 비싸다 구입 빠르다 배송 여러 샘플 들다 입맛 맛 늘다 제품 용량 구매 이득',
#  '맛 가성비 굿맛 가성비 좋다',
#  '임팩트 웨이 프로틴 초콜릿 민트 마이 프로틴 임팩트 웨이 프로틴 스테이 비아 민트 초고 넘다 맛있다',
#  '강력 추천 맛 너무 맛있다 흡수 자다',
#  '맛 좋다 맛 좋다 양도 많다 가격 좋다 최고',
#  '마프 프로틴 블루베리 치즈케이크 맛 주변 시식 평이 리뷰 보다 맛 없다 나름 먹다 맛 강하다 여운 남다 하여튼 먹다 만은 개인 으로는 사다 먹다 비추다 드리다',
#  '맛 가격 좋다 좋다 맛 가격 굿굿',
#  '아주 가성비 가다 심비 끝판 가격 대비 성분 좋다 맛 좋다 너무 좋다 디저트 재료 활용 좋다',
#  '맛있다 비리다 먹기 좋다',
#  '가성비 최고 구매 제품 인데 가성비 최고 맛 좋다 프로틴 만들다 넣다 먹다 정말 맛있다',
#  '',
#  '추천 초코 맛 딸기 맛 먹다 보다 가장 질리 자다 먹다 맛',
#  '마이 프로틴 믹스 맛있다 맛 확실하다 보장 효능 이야 없다 먹다 보다 찌다 걱정 정도 맛 좋다 너무 많이 먹다 걱정',
#  '매우 훌륭 성비 매우 훌륭하다 맛 정도 훌륭 먹다 이유 없다',
#  '맛있다 생각 보다 맛있다 밀크티 맛 나다 흡사 편의점 팔다 데자 맛 이나 밀크 연한 맛 좋아하다 구매',
#  '브라우니 맛 초코 쿠키 맛 이네 먹다',
#  '무맛 괜찮다 마이 프로틴 제품 처음 먹다 보다 대란 입다 무맛 구입 리뷰 찾아보다 우유 분유 맛 나다 보다 아기 분유 맛 알다 확실하다 비리다 맛 제거 분유 맛 근데 회사 종류 보충 먹다 보충 특유 맛 대란 구입 상당하다 저렴하다 가격 먹다 추천',
#  '싶다 맛 시나몬 사람 무조건 추천 시나몬 대니쉬 코코 요거트 아무 그릭 무당 요거트 오케이 시나몬 파우더 살짝 깜놀 끄다 이렇게 먹다 우유 아브 먹다 맛 모르다 근데 왠지 에는 같쥬',
#  '말차 라떼 존엄 질리다 맛있다 라떼 먹다 거야 아무 주문 말다',
#  '맛있다 가성비 맛',
#  '가성비 좋다 마이 프로틴 영양분 좋다 가성비 뛰어나다 많이 들어서다 훗카이도 밀크 스트로베리 크림 먹다 보다 훗카이도 밀크 분유 맛 면서 달달 맛있다 자판기 우유 차갑다 먹다 맛 스트로베리 크림 아직 먹다 보다 제일 무난 들어서다 딸기 우유 맛 예상',
#  '좋다 요타 제품 비다 비리 깔끔하다',
#  '달콤하다 맛 추천 리뷰 개다 맛 인데 오다 맛있다 팥빙수 녹다 맛 우유 맛보다 충격 받다 버리다 다시 맛보다 맛 없다 봉지 사다 어쩌 너무 박하다 가다 맛보다 점도 아깝다 따다 맛 사드 세요 제발',
#  '넘다 좋다 임팩트 웨이 프로틴 만족하다 제품 먹다 구매 먹다 늘다 맛 품질 만족하다',
#  '지금 먹다 보다 맛 무조건 우유 에만 먹다 스트로베리 크림 걸죽 딸기 우유 자체 그냥 맛있다 이건 크게 호불호 갈릴 맛 아니다 금방 질리다 모카 아무 모카 대한 리뷰 없다 반신반의 하고 가지 맛 먹다 보다 현재 최고 에는 안타 먹다 보다 모르다 우유 에는 서울 우유 커피 맛 아니다 편의점 커피 우유 맛 땅콩 버터 미국 대형 마트 식품 코너 섞다 맛 그냥 먹다 버리다 아깝다 빨리 먹다 치우다 버리다 싶다 맛 누가 반값 산다 허다 감사하다 아버 제품 사먹다 싶다 그렇다 맛',
#  '무맛 맛 인데 사람 무맛 맛 없다 먹다 이르다 근본 최고 먹다 보다 은은하다 우유 맛 나니 개꿀 맛 거임 들다 무맛 먹다 구라 아니다 개꿀',
#  '도둑 맛 쿠크 다스 커피 맛 맛 이네 달달 하이 맛있다',
#  '맛 스트로베리 크림 사다 진짜 맛 에만 먹다 보다 비리다 맛 없다 우유 먹다 진짜 맛일 듯용',
#  '맛있다 맛있다 얍얍',
#  '한번 마시기 시작 출구 보이다 코로나 운동 들이다 켜다 꿀맛 처음 스트로베리 크림 시작 내추럴 초콜릿 말다 최근 초콜릿 스무 마시다 개인 으로는 살짝 별로 맛 이라 그렇다 다시 내추럴 사다 가성비 끝내주다',
#  '가지 맛 대해 리뷰 가장 처음 마차 라떼 인데 풀림 좋다 우유 먹다 정말 녹차 라떼 흡사하다 만큼 맛있다 번째 초콜렛 스무 무난 생각 초코우유 와는 다르다 먹기 좋다 사은 받다 라떼 기호 에는 별로 맞다 풀림 별로 에요 덩어리 조금씩 생기다 맛 먹다 보고 리뷰 올리다',
#  '맛 좋다 제품 소화 자다 돼다 제품 소화 자다',
#  '웨이 프로틴 말차 라떼 이야 말차 라떼 맛 추천 받다 구매 만에 정도 먹다 맛 카페 녹차 라떼 치네다 달달 덜하다 아주 좋다',
#  '마이 프로틴 본적 프로틴 임팩트 웨이 후기 여러 맛 먹다 보다 훗카이도 밀크 보다 괜찮다 맛 임팩트 웨이 없다 옛날 자판기 뽑다 먹다 우유 맛 나다 우유 먹다 보다 적다 없다 굳이 래야 생각 들다 정도 우유 맛 강하다 기초 프로틴 맛 초코 딸기 바나나 질리다 이면 들다 보기 권하다',
#  '기준 스트로베리 크림 블루베리 라즈베리 스테비 골든 시럽 쿠키앤크림 블루베리 치즈 케이크 밀크티 초콜릿 카라멜 바나나 스테비 복숭아 살구 개인 초코 싫어하다 맛 이랑 자다 섞이다 지다 섞이다 지다 기준 나누다 짜다 진짜 싫어하다 프로틴 비리다 맛',
#  '가격 맛 괜찮다 최근 구매 먹다 보다 훗카이도 밀크 스테비 블루베리 코스 무스 인데 블루베리 너무 풀리다 아쉽다 밀크 너무 달다 단맛 줄이다 말차 해주다 좋다',
#  '좋다 믿다 구매 가성비 최고 맛 좋다',
#  '성비 싸다 맛 역시 맛 사실 그닥 나쁘다 프로틴 제품 이랑 효과 싸다 믿다 구매 대신 많다 맛 사이 별로 맛 많다 바나나 맛',
#  '맛있다 가지 먹다 보다 참고 까다롭다 입맛 아이스 라떼 쿠키 크림 민트 초코 맛있다 복숭아 아이스티 마이 쮸맛 바나나 맛 때문 강황 가루 들어가다 이상하 괜찮다',
#  '달달 맛있다 제품 오래드 분들 비추다 초코 처럼 물리다 느낌 아니다 설레임 맛 인데 기대하다 맛 보단 맛있다 달달 맛있다 들다 보시 구매 좋다',
#  '유명하다 스트로베리 크림 맛 주문 질리 먹다 맛 뭔가 맛 부족하다 느낌 다양하다 맛 맛 주문 해보다 예정 쉬다 그런 만족',
#  '맛있다 인위 커피 맛 카라멜 맛 나서다 카라멜 마끼 맛 많이 인위 맛 나요 비유 싸다 캔커피 맛 정도 정도 단백질 보통 이에요',
#  '맛있다 맛 많이 먹다 보다 초콜릿 스무 정도 제일 무난 우유 먹다 그냥 그대로 먹다 말다 먹다 힘들다 하라 좋다 먹다',
#  '추천 추천 쉬다 섭취 운동 열심히 섭취 니깐 많이 늘어나다 느낌 맛 좋다',
#  '마이 프로틴 후기 딸기 크림 민트 초코 종류 서다 먹다 맛있다 좋다 먹다 밍밍 맛있다 먹다',
#  '임팩트 웨이 프로틴 개선 필요 없다 정도 좋다 맛 너무 다양하다 좋다 지금 먹다 딸기 맛 정말 맛있다 아쉽다 맛 다양하다 맛 고르다 소량 구매 맛 시스템 좋다',
#  '임팩트 웨이 프로틴 개선 필요 없다 정도 좋다 맛 너무 다양하다 좋다 지금 먹다 딸기 맛 정말 맛있다 아쉽다 맛 다양하다 맛 고르다 소량 구매 맛 시스템 좋다',
#  '다양하다 맛 즐기다 좋다 단백질 쉐이크 아침 이나 저녁 간단하다 단백질 섭취 좋다 운동 끝나다 말다 좋다 최애 맛 민트 초코 맛 강력 추천 별로 맛 다크 초코 바나나 홋카이도 밀크티 개인 별로',
#  '품질 좋다 단백질 하루 섭취 단백질 가슴 계란 두부 고기 식품 으로만 채우다 너무 벅차다 간단하다 음료 단백질 섭취 바쁘다 일상 바쁘다 음식 많이 먹다 속도 너무 편하다 특히 지방 탄수화물 함량 없다 제품 이라 지방 탄수화물 신경 쓰다 조절 매우 적합하다 근육 가다 손실 방지 아니다 단순하다 건강 유지 목적 단백질 필수 크다 용량 봉지 서다 기본 스쿱 섭취 좋다 무맛 합성 감미료 민감하다 로서 만족스럽다 운동 많이 사람 에게는 필요하다 양식 아니다 싶다',
#  '리뷰 초콜렛 스무 초코 우유 스트로베리 크림 엄청 달달 딸기 우유 가루 냄새 맡다 밀크티 평소 좋아하다 노맛',
#  '맛있다 좋다 맛있다 좋다 스푼 자다 찾다 방법 좋다',
#  '만족스럽다 맛 기대 이고 텁텁함 심하다 두고두고 자다 먹다',
#  '웨이 프로틴 밀크티 홋카이도 밀크 차맛 제일 맛있다 따뜻하다 먹다 진짜 라떼 밀크티 맛 많이 가끔 자다 녹다 홋카이도 밀크 가루 에서는 신향 나다 막상 먹다 분유 맛 나요 어쨋거 저쨋거 맛있다',
#  '맛 골든 시럽 에도 자다 풀리다 맛 아주 좋다 호두 마루 맛 나다 맛 고정 먹다',
#  '화이트 초콜렛 이랑 달콤하다 팥맛 해봤다 좋다 화이트 초콜렛 살짝 바닐라 쉐이크 맛 기도 정말 만족 스럽게 먹다 우유 먹다 바닐라 쉐이크 맛 강하다 먹다 살짝 연하다 부드럽다 마시기 너무 좋다 달콤하다 맛 작다 사이즈 해보다 구매 좋아하다 그렇다 부담 스럽지 적당하다 달달 마시기 너무 좋다 초콜렛 스무 스트로베리 크림 코코넛 라떼 많다 종류 별로 해보다 순위 에서는 스트로베리 크림 화이트 초콜렛 정도 초콜렛 스무 정도 중간 순위 차지 하고',
#  '간편하다 단백질 섭취 최고 민트 초코 초코 밀크티 말차 라떼 구입 민트 초코 초코 진짜 프로틴 맛 나다 맛있다 반면 밀크티 맹맹하다 말차 라떼 재다 의사 없다 레이브 드롭스 사서 뿌리다 먹다 맛 먹음',
#  '운동 하고 여러 먹기 좋다 맛 따다 도전 해보다 무섭다 모르다 츄럴 초코 가장 무난',
# ...
#  '가성비 성비 진짜 라면 많이 섞다 풀리다 맛 맛있다 성분 괜찮다 가격 너무 괜찮다 재다 의사 완전',
#  '마이 프로틴 최고 여러 먹다 맛 깔끔하다 먹기 좋다 배송 느리다 맛 가격 가성비 최고',
#  '부드러움 운동 시작 처음 보충 사다 예상 보다 말다 부드럽다 넘어가다 거부 없다',
#  '프로틴 맛 진짜 괜찮다 브랜드 많이 먹다 보다 마프 만큼 가성비 좋다 맛 좋다 브랜드 없다',
#  '프로틴 마이 프로틴 마이 프로틴 처음 먹다 보다 달달 초코 맛 아주 맛 빠르다 크다 목적 구매 효과 보다 단백질 특유 비릿 냄새 맛 전혀 느끼다 맛 비교 브랜드 보다 나은 주문 넉넉하다 하루 스푼 먹다 근육 빠르다 붙다 너무 좋다',
#  '맛있다 맛있다 니당다',
#  '프로틴 후기 프로틴 먹다 보다 맛 때문 거부 느껴지다 마이 프로틴 하고 에는 먹다 거부 없다 맛 자다 섞이다 보고 에도 구매 하고 싶다 생각 들다 에는 새롭다 맛 구매 해보다 싶다',
#  '스트로베리 크림 보다는 초콜릿 스무 들다 스트로베리 크림 맛있다 주문 해봤다 초콜렛 스무 맛있다 진짜 개취 친구 초콜렛 스무 별로 라고 가능하다 샘플 먹다 보고 사다 초콜렛 스무 재다 의사 자다 풀리다 맛 괜찮다 가성비 없다 제품',
#  '무난 맛있다 가성비 진짜 무난 어울리다 맛 자다 모르다 들이다 그냥 초코 맛 사다 초코 무조건 평타 니까 바나나 맛있다 초코 괜찮다',
#  '괜찮다 대다 거품 거품 많다 스트로베리 크림 거북하다 거품 가라 앉히다 마시다 좋다',
#  '스트로베리 크림 장점 가장 맛 좋다 딸기 우유 정확하다 자판기 뽑다 마시다 딸기 라떼 맛 나다 물약 이나 맛 섞이다 단점 더럽다 풀리다 진짜 겁나다 흔들다 풀리다 진짜 진짜 이렇게 풀리다 처음 우유 가리다 더럽다 풀리다',
#  '스트로베리 크림 여러 먹다 보다 리뷰 따르다 스트로베리 크림 제일 낫다 맛 다양하다 먹다 보고 싶다 별로 고민 해보다 들다 보신 추천 인가요',
#  '제일 맛있다 생활관 친구 프로틴 먹다 보다 제일 꾸준하다 먹다 맛',
#  '자다 받다 자다 먹다 짱짱',
#  '프로틴 들다 여태 여러 브랜드 많이 먹다 늘다 가성비 좋다 맛 좋다 내추럴 초코',
#  '멸치 위장 좋다 체질 인데 소화 아주 자다 몇몇 평범하다 음식 먹다 위장 문제 겪다 위장 매우 좋다 체질 인데 운동 임팩트 웨이 프로틴 섭취 니까 너무 소화 자다 체형 체형 운동 체중 늘리다 단백질 섭취 맛 좋다 흡수 평가 싶다 상태 컨디션 별로 싶다 에도 정상 나오다 단백질 받아들이다 상당하다',
#  '임팩트 웨이 프로틴 최고 너무 맛있다 편하다 먹다 찌다 최고 가성비 좋다',
#  '도대체 번째 구매 인지도 모르다 항상 언제나 먹다 임팩트 웨이 프로틴',
#  '스트로베리 크림 좋다 냄새 웨하스 딸기 맛 동일 맛 딸기 우유 동일 끝맛 분유 느낌 추가 맛 보단 넘다 맛 좋다 느끼다 초반 며칠 느끼다 금방 적응하다 정도 맛 좋다 먹다 웨이 프로틴 처음 먹다 사람',
#  '프로틴 인가 초코우유 인가 여러 유명하다 보충 많이 마시다 보다 주로 초코 맛 먹다 가장 무난 마이 프로틴 유명하다 많이 들어서다 주문 해봤다 초코 맛 정말 맛있다 초코우유 풀림 아주 좋다 주문 추가 주문',
#  '홋카이도 밀크 맛 프로틴 구매 두근두근 마음 홋카이도 밀크 맛 사다 에도 너무 자다 섞이다 제일 좋다 맛 이네 커피 자주 섞다 마시다 이르다 커피 우유 맛 나서다 넘다 좋다',
#  '맛있다 걱정 거북하다 어쩔 끄다 먹다 보다 괜찮다 가성비 가다 만족하다',
#  '말차 라떼 누가 맛 없다 말차 라떼 맛 맛있다 여서 말차 라떼 사다 누가 라떼 맛 진짜 맛 없다 절대 사지 말르다 후회 하고 택배 도착 하고 먹다 보다 완전 맛있다 생각 으론 그냥 싫어하다 사람 완전 싫어하다 좋아하다 사람 완전 좋아하다 그렇다 근처 카페 라떼 들다 보고 맛있다 느끼다 무조건 말차 라떼 맛 사다 완전 취저입니',
#  '밀크 티맛 최고 원래 초코 브라우니 먹다 최근 밀크 티맛 주문 먹다 프로틴 이래도 싶다 정도 맛있다 밀크티 향 진하다 아니다 나오다 오다 음료수 맛 이랑 밀크 좋아하다 적극 추천 라떼 맛 새롭다 생기다 주문 해봤다 아직 먹다 보다 아마 밀크티 만큼의 닐까 생각 드네 배송 만에 오다 너무 만족 스럽다 밀크 티맛 들다 들다',
#  '프로틴 입문 프로틴 처음 사서 먹다 보다 정말 맞다 싶다 정도 초코우유 맛 나다 신기하다 그렇다고 너무 지도 질리 꾸준하다 자다 먹다',
#  '맛 식사 대용 먹다 주문 엄마 아빠 간식 너무 맛있다 거품 많다 그것 맛있다',
#  '도착 마프 맛 품질 가격 좋다 워낙 유명하다 배송 문제 배송 무사하다 자다 도착 마음 드네 주문 자다 도착 빌어 보다',
#  '자다 오다 배송 많이 개선 늦다 없다 역시 믿다 먹다 마프 초코 맛 그냥 칙촉맛 이에요 가성비 맛 좋다 빨리 보내다',
#  '챙기다 먹다 친구 배송 기다리다 힘들다 짜다 구매 만족하다 맛 맛있다 보다 가성비',
#  '스테비 블루베리 라즈베리 홋카이도 밀크 후기 스테비 블루 라즈베리 개인 생각 스트로베리 크림 맞먹다 맛 이라고 생각 세상 없다 포도 우유 느낌 인데 특별하다 물리 색다르다 맛 원하다 알맞다 비다 홋카이도 밀크 너무 달다 연유 분유 설탕 들이다 부다 맛 먹다 치우다 하니 최대한 거치 목구녕 때리다 박다',
#  '초코 브라우니 맛 초코 브라우니 처음 먹다 보다 말다 남다 미리 말다 노력 나르다 발견 믿다 사보다 진짜 달달 하고 맛있다',
#  '만족하다 평소 첨가 없이 프로틴 섭취 원하다 마프 무맛 주문 맛 대한 좋다 평이 많다 걱정 만족하다 입맛 에는 굉장하다 싱겁다 분유 맛 먹다 정도 아니다 금방 적응 단백질 함유 가장 많다',
#  '내츄럴 초코 스트로베리 크림 골드 시럽 가지 먹다 보다 스트로 베림 맛있다 거품 많다 골든 시럽 호두 마루 맛 인데 금방 질리다 내츄럴 초코 거품 많이 없다 안질리다 먹기 좋다 보충 초코 맛',
#  '번째 주문 저녁 식사 대용 운동 하고 말다 꿀맛 용량 늘리다 겠다',
#  '개존 맛 맛 사다 사다',
#  '괜찮다 먹다 국산 게이 그건 어찌나 던지다 당뇨 걸리다 알다 요건 확실하다 그렇게 많이 달다 질리다 먹다 없다 에도 자다 녹다 우유 먹다 맛있다 배송 느리다 많다 걱정 외로 빨리 오다 주문 점심 보다 그럭저럭 빨리 굉장하다 만족',
#  '마이 프로틴 처음 사보다 처음 사본 마이 프로틴 스트로베리 크림 맛 사보다 딸기 우유 맛 이나 질리 먹다 진짜 맛있다',
#  '프로틴 이라니 프로틴 이라고 믿어지다 만큼 신기하다 맛 우유 맛 정말 없다 그냥 음료수 라고 나누다 아무 모르다 맛 별로 사다 놓다 먹다 싶다',
#  '입문 보충 프로 입문 먹기 편하다 맛 좋다 꾸준하다 이용 좋다 결과 좋다',
#  '오다 대안 맛 아이스 라떼 처음 먹다 보고 후기 많이 없다 적다 용량 사보다 주문 짜다 주문 믹스 커피 맛 좋아하다 좋아하다 그렇다고 매우 진하다 믹스 커피 기대하다 안되다 그냥 연한 커피 맛 아이스크림 맛 이라고 생각 하고 구입 고려 해보다',
#  '민트 초코 라떼 주목 민트 초코 먹다 보다 민트 초코 먹다 맛있다 거부 없다 맛 민트 향 멘솔 피우다 사람 이면 싫어하다 수가 없다 맛 아쉽다 초코 시리즈 그렇다 단맛 한편 말차 라떼 번갈아 먹다 이건 우유 소량 섞다 만들다 흔하다 녹차 라떼 맛임 크리미 녹차 향 밸런스 좋다 민트 초코 단맛 편이 라면 이건 심하다 정도 단맛 싫어하다 사람 라면 녹차 라떼 좋다 선택',
#  '망고 오다 정말 맛있다 요망 정말 맛있다 덥다 여름 시원하다 달달 운동 망고 프로틴 한잔 하와이 열대 과일 맛 가득하다 느끼다 정말 달콤하다 시원하다 고향이 가득 퍼지다 망고 맛 추하다',
#  '좋다 스트로베리 크림 맛 우유 먹다 딸기 맛 아이스크림 이에요 얼리다 아이스크림 대신 자다 먹다 단백질 비리다 전혀 나다 좋다',
#  '굿굿 처음 구매 먹다 보고 생각 보다 너무 좋다 에도 구매',
#  '가성비 배송 들다 대란 배송 기간 기다 평소 보다 빨리 받다 평소 일정 걸리다 대란 당일 전날 저녁 정도 시작 주문 주일 오다 버리다 아침 일어나서 택배 보고 기분 좋다 배송 문제 정도 해결 더욱이 마프 믿다 주문 취소 교환 까다롭다 빼다',
#  '가성비 최고 헬창 화이팅',
#  '가성비 맛 괜찮다 아직 피부 트러블 먹다 지다 돼다 모르다 없다 좋다 성분 괜찮다 맛 좋다 운동 동기 부여 프로틴 먹다 생각 운동 스트로베리 크림 완전 딸기 우유 맛 이에요',
#  '말차 라떼 최고 밀크 맛 이랑 라떼 먹다 좋다 킬로 킬로 사다 맛있다 좋다 공복 운동 먹다 저녁 식사 대용 먹다',
#  '구매 인데 가성비 좋다 구매 인데 값싸다 가격 대비 많다 용량 보충 얻다 기분 좋다 맛 괜찮다 많다 스트로베리 맛 추천 얼른 먹다 먹다 보다',
#  '좋다 단백질 섭취량 적다 처음 사서 먹다 보다 단백질 들어가다 전보 성장 빠르다',
#  '대박 이네 처음 마프 주문 무난 초코 스무 맛 주문 먹다 보다 결과 불구 하고 너무 맛있다 장기간 먹다 늘다 질리다 없다 맛 너무 만족하다 자다 챙기다 먹다 득근',
#  '좋다 레이 보다는 풀어지다 정도 자다 풀어지다 맛 레이 종류 많다 맛 먹다 보다',
#  '아이스 라떼 말차 라떼 카페 가다 싶다 가보다 아이스 아메리카노 마시다 처지 탄하 다가 아이스 라떼 라떼 마시다 보다 웨이 프로틴 이라 그렇다 뭉치다 아이스 라떼 맛 진짜 라떼 맛 기대하다 먹기 보다는 고소하다 곡물 라떼 맛 기대하다 들다 좋다 맛 말차 라떼 원래 좋아하다 음료 여서 엄청 기대 보다는 지방 지방 우유 먹다 부드럽다 맛있다 먹다 맛 괜찮다 체적 만족하다',
#  '품질 맛 최고 성비 워낙 유명하다 마프 인데 맛 품질 좋다 운동 빡세 보상 단백질 보충 마시기 좋다 가성비 좋다 부담 없이 말다 좋다',
#  '오다 맛 맛',
#  '배송 상태 제품 아주 만족하다 역시 임팩트 웨이 스트로베리 배송 상태 제품 아주 만족스럽다',
#  '진짜 맛 잇다 골든 시럽 이나 메이플 시럽 자주 구입 최고 맛 구매 해도 시럽 맛 화이팅',
#  '스트로베리 지리다 맛 좋다 웨하스 딸기 맛 준비 꾸준하다 카라 메다 맛 먹다 보다 결과 임팩트 웨이 좋다 솔직하다 마프 자다 맞다 먹다 스트로베리 크림 세용',
#  '마프 마프 계속 프로 챙기다 먹다 초코 캬라멜 긋다',
#  '가성비 저렴하다 가격 낮다 칼로리 가성비 맛 먹다 맛있다',
#  '단백질 역시 마프 믿다 먹다 마이 프로틴 운동 먹기 좋다',
#  '시대 최고 프로틴 안녕하다 운동 사람 사이 밉다 유명하다 제품 이라 구매 해봤다 역시 사람 많이 찾다 제품 이유 가격 저렴하다 제품 맛 이나 성분 월등하다 뛰어나다 확실하다 느끼다 좋다 제품 만들다 주다 매우 감사 드리다 자주 이용 감사하다',
#  '프로틴 처음 먹다 정말 맛있다 스트로베리 크림 맛 먹다 보다 너무 만족스럽다 정말 딸기 우류 마시다',
#  '스무 추천 우유 에다 먹다 초코우유 맛 나다',
#  '사료 다리 알다 처음 조절 실패하다 느끼하다 생각 넣다 맛 괜찮다 정도 지나다 근육 많이 붙다 효과 좋다 계속 구매 의사',
#  '임팩트 웨이 프로틴 후기 원래 제품 먹다 할인 싸다 구매 먹다 보다 맛 굉장하다 좋다 가격 괜찮다 맛 다양하다 선택 고민 많다 맛있다 보이다 처음 보다 평범하다 내추럴 초콜렛 향 좋다 맛 좋다 알다 맛 건데 굿굿 많이 파다',
#  '역시 가성비 짱 마이 프로틴 구매 이후 국산 보충 저렴하다 가격 품질',
#  '맛있다 효과 꾸준하다 먹다 보다 풀림 아쉽다 맛 너무 좋다',
#  '맛있다 진짜 맛있다 우유 먹다',
#  '초콜릿 스무 아이스 라떼 맛 맛있다 초콜릿 스무 코코아 느낌 초코 맛 보충 아이스 라떼 맛 커피 우유 무맛 보충 섞다 맛일 중간 이상은',
#  '맛 좋다 가성비 좋다 맛 괜찮다 보다 가성비 찾다 맛 해보다',
#  '마프 구매 보충 먹다 처음 마프 주문 보다 골든 시럽 맛 사다 정말 이름 충실하다 시럽 들이키다 달달 자주 이용 추천',
#  '리뷰 그냥 보다는 우유 미숫가루 섞다 먹다 맛있다',
#  '항상 챙기다 먹다 프로틴 질감 없이 부드럽다 넘어가다 프로틴 사의 여러 프로틴 먹다 보다 마프 프로틴 먹다 만큼 속이다 편하다 제품 없다',
#  '구매 아이스 라떼 대안 정말 맛있다',
#  '임팩트 웨이 프로틴 우유 먹다 맛있다 마시다 맛있다 지금 과일 이랑 우유 마시다',
#  '아주 좋다 가다 성비 좋다 성분 효능 검증',
#  '유명하다 제품 가장 대표 제품 이니 길다 쓰다 가성비 짱 맛 적절 적당 자다 풀림',
#  '무맛 웨이 프로틴 생각 보다 괜찮다 먹다 배송 빠르다 운동 스쿱타 먹다 너무 좋다',
#  '아주 좋다 너무 좋다',
#  '마시쩡 바닐라 마시쩡 마시쩡 바닐라 마시쩡 너무 너무 마시쩡',
#  '마이 프로틴 초코 맛 리뷰 초코 맛 제품 비다 상당하다 맛있다 먹다 제품 가장 좋다 할인 이벤트 싸다 좋다 할인 코드 행사 자다 이용 싸다 장점 해외 배송 이라 배송 기간 걸리다 단점 빼다 없다',
#  '추밤 초콜릿 맛 사보다 생각 보다 맛있다 추천',
#  '구매 인데 좋다 임팩트 웨이 프로틴 내추럴 초코 맛 구매',
#  '구매 성공 말차 라떼 대안 우유 조합 끝내주다',
#  '맛 프로틴 파우더 처음 구매 건데 태어나다 처음 먹다 보다 건데 진짜 맛있다 맛 먹다 모르다 먹다 살다',
#  '역시 가성비 마프 마이 프로틴 역시 가성비 최고 프로틴 먹다 좋아지다 아니다 든든하다 맛 가격 좋다',
#  '가성비 최고 다양하다 맛 주문 먹다 질리 건강하다 제품 항상 만족하다',
#  '맛있다 예전 먹다 프로틴 냄새 나서다 별로 맛 좋다 먹기 편하다',
#  '골든 시럽 맛 호두 마루 맛 나요 풀림 스트로베리 크림 하고 찬물 자다 풀리다 믿다 먹다 마프',
#  '가성비 최고 마이 프로틴 맛 선택 신중하다 초콜렛 바나나 맛 맛있다 먹다 한지 딸리다 맛 절대 다시 초콜렛 스무 그대로 스무 밍밍 재다 의사 초코우유 많이 맛 초콜렛 브라우니 가장 초코 맛 그렇다고 완전 맛있다 재다 가능 스트로베리 크림 인공 딸기 향 싫어하다 별로 그렇다 아니다 무조건 사다 제일 맛있다 아이스 라떼 맛 괜찮다 기다 밍밍 재다 의사',
#  '좋다 우유 딸기 맛 인가요 그거 사다 달달 먹기 좋다 단백질 보충 자다 근육 금방 금방 붙다 느낌 나요 헬린 만족도 굳다 우유 먹다 전혀 없다',
#  '맛 최고 먹다 풀림 좋다 먹다 연한 감다 먹다 정도 아니다 맛있다 맛 다양하다 고르다 먹다 재미 우유 먹다 개존 맛',
#  '맛있다 가성비 내츄럴 초코 라떼 맛 먹다 내츄럴 초코 네스퀵 밍밍 맛 맛있다 말차 라떼 에는 초록색 이라 새싹 보리 먹다 맛있다 운동 미리 나누다 먹다 확실하다 먹다 근육 자다 붙다 마프 대란 재다 예정',
#  '가성비 임팩트 웨이 프로틴 탄수화물 이고 단백질 먹다 생각 보충 운동 근육 보강 주다 이야기 들다 어디서 구입 망설이다 가장 쉽다 방법 유튜브 검색 다양하다 후기 방법 설명 나오다 가성비 좋다 가격 저렴하다 편이 기간 자다 맞추다 싸다 구입 맛 종류 다양하다 질리 다양하다 맛 선택 좋다 개인 으로는 컬릿 스무 질리 맛 좋다 배송 느리다 때문 내심 필요하다 으로도 번창',
#  '초콜릿 브라우니 추천 믿다 먹다 마프 초콜릿 브라우니 맛 자다 풀리다 맛 너무 좋다',
#  '가성비 최고 제품 맛 다양하다 고르다 먹다 재미 잇다',
#  '역시 마프 대란 임펙트 웨이 프로틴 좋다 마프 대란 장만 가슴 웅장 믿다',
#  '골든 시럽 너무 맛있다 한국 아이스크림 메가톤바 맛 달달',
#  '만족스럽다 운동 꾸준하다 수입 적기 때문 프로틴 섭취 천장 단백질 바르다 매달 놓다 년판 자리다 고비 마냥 입맛 다시 단백질 보충 상상 하고는 마이 프로틴 합리 가격 프로틴 구매 이후 로는 제법 자다 챙기다 먹다 기부 좋다 과장하다 운동 인생 이프 로틴 구매 나누다 생각 요즘 친구 이름 부르다 붙이다 불다 새롭다 돼다 이상은 스쿼트 보여주다 완전하다 달라지다 솔직하다 에일리 좋아하다',
#  '맛있다 스트로베리 크림 홋카이도 밀크 먹다 보다 먹다 맛있다 우유 먹다 맛있다 칼로리 생각 우유 물반 먹다 괜찮다 개인 추천 스트로베리 크림 그냥 딸기 우유 맛 상큼 달달 운동 끝나다 기분 좋아지다 홋카이도 밀크 자판기 우유 맛 분유 맛 인데 많이 서다 미리 먹다 보다 금방 질리다 들다 보다 번갈아 가다 들다 추천 드리다 가지 찬물 자다 풀리다 오래 흔들다 작다 뭉치다 맛 좋다 종류 다양 용량 다양하다 계속 먹다',
#  '마프 개봉 마프 마프 이유 알다 가성비 맛 좋다 가격 착하다 에도',
#  '웨이 프로틴 맛 정말 다양하다 흡수 너무 자다',
#  '역시 스트로베리 크림 맛있다 부드럽다',
#  '좋다 요원하다 제품 빠르다 받다 정도 걸리다',
#  '가성비 최고 스트로베리 크림 먹다 상당하다 만족스럽다 맛 궁금하다 스무디 미리 사다 대기',
#  '스트로베리 크림 훗카이도 밀크 스트로베리 크림 정말 맛있다 중간 질리다 무난 맛있다 훗카이도 밀크 연유 맛 이라고 우유 맛 나다 호불호 갈릴 수도',
#  '강추 드리다 영양분 영양분 맛 정말 맛있다 먹다 밍밍',
#  '가성비 자체 성비 성분 장난 질처 서다 합성 첨가 잔뜩 섞이다 제품 비싸다 주다 먹다 에야 마프 먹다 이득 먹다 소고기 먹다 라도 사다',
#  '만족 가격 저렴하다 성분 우수하다 계속 주문',
#  '명불허전 꿀맛 가다 성비 최고',
#  '가성비 좋다 떨어지다 마다 먹다 마차 라떼 맛 지금 먹다 단백질 보다 맛 좋다 으로도 먹다',
#  '우유 먹다 맛있다 먹다 미묘 솔티드카 메다 맛 구매 지방 지방 우유 먹다 괜찮다 우유 먹다 추천 프로틴 이랑 가루 액체 섞이다 많이 흔들다 맛 자체 생각 보다 맛있다 종종 먹다',
#  '말차 라떼 맛 말차 라떼 먹기 힘들다 좋다',
#  '너무 좋다 너무 맛있다 제품 비다 다양하다 맛 맛있다 성분 너무 좋다',
#  '웨이 프로틴 최고 제품 맛 가격 단백질 함량 박자 고루 갖추다 마이 프로 임팩트 웨이 프로틴 최고 특히 스트로베리 크림 맛 딸기 우유 보다 맛있다 제품 먹다 그랬는데 마이 프로틴 제품 그렇다 없다 아마 좋다 원료 만들다 그렇다 싶다 최고 제품 마이 프로틴 임팩트 웨이 프로틴 강력하다 추천',
#  '딸기 맛 맛있다 지난 에는 밀크 티맛 소이 프로틴 무맛 사다 금방 먹다 그냥 지르다 많이 유명하다 크림 맛 고르다 먹다 밀크 맛보다 맛있다 우유 먹다 그냥 아주 좋다 죽다 소이 프로틴 대고',
#  '내츄럴 초코 너무 맛있다 마이 프로틴 처음 인데 초코 추천 받다 구매 초코우유 먹다 맛 이니 전혀 거부 감다 없다 배송 만에 도착 프로틴 맛 가성비 좋다 프로틴 추천',
#  '구매 마프 새롭다 맛 항상 많다 질리다 크다 장점',
#  '말차 라떼 맛 후기 녹차 맛 좋아하다 보다 굳다 먹다 우유 맛 나요 개다 금액 맞추다 키로 넘다 많다 가다 싶다 살짝 후회 후회 들어가다 맛 평소 녹차 맛 좋아하다 라떼 한번 들다 보다 맛',
#  '맛 잘못 내츄럴 초콜렛 아이스 라떼 아이스 라떼 맛있다',
#  '역시 마프 곱다',
#  '초기 구매 배송 기간 오래 걸리다 용량 구입 깔끔하다 포장 계량컵 먹기 편리하다 상단 지퍼 보관 용이 부분 상단 지퍼 대신 뚜껑 처럼 플라스틱 마개 부분 생각 해보다',
#  '스트로베리 크림 여태 많다 프로틴 먹다 보고 요즘 가성비 시대 이제야 마이 프로틴 이렇게 문명 멀리 지내다 사람인 가다 싶다 제일 많이 들다 추천 스트로베리 크림 먹다 정말 딸기 우유 맛 맛 그닥 좋아하다 에게는 많이 거부 감다 없다 으로도 프로틴 마프 먹다',
#  '좋다 딸기 맛 처음 먹다 보다 정말 딸기 맛 이에요 더부 끼다 없다 여드름 늘어나다 가성비 좋다',
#  '만에 오다 완전 빨르다 적어도 걸리다 알다 생각 보다 엄청 빨리 오다 깜짝 감사하다 프로틴 처음 이라 무난 초코 브라우니 맛 우유 먹다 초코우유 맛 똑같다 진짜 맛있다',
#  '요것 리뷰 풀림 처음 보충 먹다 시절 차이 많이 나다 방금 배송 서다 한스쿱 넣다 생수 넣다 흔들다 풀리다 리얼 스트로베리 스트로베리 크림 고민 리얼 사라 딸기 크림 우유 맛 아니다 크림 맛 맛 군대 리얼 스트로베리 먹다 스트 베리 크림 맛 아니다 먹다 재다 의사 프로 먹다 봉지 하자',
#  '맛 정말 다양하다 스트로베리 크림 구매 해봤다 상당하다 만족하다',
#  '프로틴 다르다 맛 훨신 진하다 마싯다 거부 없이 먹기 좋다',
#  '계속 끄다 초코 맛 가루 자다 풀어지다 먹다 다시 주문항 끄다',
#  '좋다 맛있다',
#  '아주 좋다 운동 끝나다 좋다',
#  '맛 좋다 좋다',
#  '너무 맛있다 푸드 무맛 먹다 바꾸다 너무 맛있다 운동 하고 헬스장 가다 운동 하고 프로틴 먹다',
#  '가성비 가성비 훌륭하다',
#  '맛있다 프로틴 처음 먹다 보다 먹다 먹다 만해 달달 하고 맛 괜찮다 프로틴 먹다 똑같다 다시',
#  '마프 단백질 보충 효과 맛 맛 효과 아주 좋다 운동 하고 챙기다 먹다 아주 만족하다',
#  '맛있다 진짜',
#  '새롭다 맛 맛있다 라떼 아이스 라떼 맛 진짜 추하다',
#  '',
#  '언제나 믿다 먹다 바닐라 스테비 프로 바나나 맛 가성비 언제나 프로틴 비다 우월하다',
#  '좋다 생각 보다 배송 라서 좋다 코로나 인하다 늦다 배송 알다',
#  '마프 프로틴 리뷰 원래 단백질 특유 냄새 싫어하다 인데 맛 그렇다 냄새 되게 적다 개인 되게 만족하다',
#  '말차 라떼 진짜 맛 추하다 형님 지금 다양하다 회사 프로틴 마이 프로틴 에서는 스트로베리 크림 밀크티 초콜렛 스무 모카 훗카이도 밀크 먹다 보다 원래 카페 팔다 녹차 라떼 되게 좋아하다 라떼 보다 개봉 녹차 냄새 라떼 보다는 진짜 향 가깝다 우유 보다 본인 우유 좋아하다 냄새 으음 별로 녹차 라떼 냄새 냄새 때문 입견 가지 새롭다 맛 도전 마다 실패하다 기억 마시다 보다 오다 오다 오다 진짜 카페 팔다 녹차 라떼 녹차 프라푸치노 그렇다 맛 나다 진짜 댕존 맛 스트로베리 크림 처음 먹다 오다 딸기 우유 인데 맛 구만 그거 보다 맛있다 대다 사건 궁금하다 먹다 보다 우유 맛있다 깔끔하다 녹차 라떼 향 나서다 맛있다 처음 맛있다 먹다 보충 결론 원래 녹차 라떼 좋아하다 분들 말차 라떼 사다 진짜 맛 우유',
#  '들다 추천 많이 보통 주문 동생 가성비 좋다 주문 주문 아직 되게 남아 조바심 바나나 주문 사람 가성비 가성비 비다 배송 빠르다 받다 많다 빠르다 걸리다 암튼 보충 구매 끄다 간식 항상 가슴 먹다 브라우니 프로틴 쿠키 사보다 요즘 떨어지다 먹다 보다',
#  '맛 프로틴 이라고 군대 시절 처음 동기 한테 얻다 먹다 프로틴 먹다 맛 없다 거란 편견 초코 맛 그렇다 너무 달달 하고 맛있다',
#  '마음 들다 맛 좋다 먹기 부담 스럽지 좋다',
#  '좋다 초콜렛 스무 스트로베리 크림 모카 초콜렛 민트 밀크티 말차 라떼 맛 먹다 보다 맛있다 재다 초콜렛 스무 스트로베리 크림 생각 보다 프로틴 맛 맛 좋다',
#  '말차 라떼 밀크티 민트 초코 라떼 지방 우유 쉐킷 쉐킷 먹다 맛 우유 먹다 맛있다 카페 밖에 마시다 슬프다 슬프다 밀크티 지방 우유 먹다 맛 쪼금 많이 달기 구리 좋아하다 사람 상관 없다 자다 녹이다 먹다 쪼금 짜증나다 이유 모르다 쓰다 암튼 밀크티 버블티 덕후 한테 늘다 최고 민트 초코 남자친구 덕후 인데 먹다 맛있다 우유 먹다 맛있다 민초 맛있다 이해 팔다 음료 다르다 바라다 없다 팔다 음료 머겅다 암튼 민초 덕후 입맛 에는 맞다 생각 보다 스트로베리 크림 주문 아직 먹음 근데 워낙 후기 좋다',
#  '초콜렛 바나나 맛 괜찮다 예전 남자친구 먹다 주다 그냥 초코 맛 알다 초코 바나나 덥다 달콤하다 맛 좋아하다 특히 바나나 우유 좋아하다 엄청 좋아하다 개인 대다 만족 남자친구 블루베리 치즈케이크 맛 먹다 그것 달콤하다 먹다 맛 괜찮다 에는 맛 으로도 구매 예정',
#  '마이 프로틴 먹다 트러블 제일 크다 프로틴 맛 이랑 트러블 유무 가장 중요하다 생각 먹다 보다 맛 느끼다 그대로 적다 보다 초콜릿 브라우니 밀크 초콜릿 다크 초콜릿 사이 처음 사고 무난 해보다 싶다 추천 스트로베리 크림 서울 우유 딸기 우유 인데 살짝 우유 비리다 맛 나다 신경 쓰이다 정도 아니다 초코 맛 질린다 적극 추천 쿠키 크림 크림 많다 깜뜨 맛 외국 먹다 오레오 느낌 아이스 라떼 최근 나오다 건데 새롭다 맛 이라 해봤다 맛있다 덴마크 모카 라떼 맛 나다 예전 바닐라 맛 먹다 보다 맛 처음 이고 거부 없다 맛 찾다 우유 자다 어울리다 재료 들어가다 맛 추천 쿠앤크 딸기 우유 라떼 아무래도 유청 단백질 베이스 우유 보다 맛 그렇다 선택 무난 베스트',
#  '가성비 가성비 이유 내츄럴 초코 맛 주문 스쿱 섞다 섭취 인데 살짝 밍밍 허쉬 초코 맛 맛있다 좋다',
#  '아이스 라떼 키로 아이스 라떼 키로 부탁드리다',
#  '민초 코로나 인하다 배송 가량 걸리다 어쩔 없다 부분 민트 초코 맛 상당하다 달콤하다',
#  '먹다 만해 맛있다 히힛',
#  '좋다 주변 마프 가성비 좋다 들다 이야기 처음 주문 가격 보고 주문 만큼 가장 많이 먹다 스트로베리 크림 주문 배송 많다 일주일 만에 오다 보다 무난 수준',
#  '너무 만족하다 부족함 없다 쌓다 먹다 너무 만족하다 구매 하고 싶다',
#  '말차 라떼 맛 대박 우유 먹다 완전 말차 라떼',
#  '보충 먹다 맛 운동 진성 민트 초코 초코 맛 충분하다 민트 맛 상대 약하다 근데 민트 맛 묻히다 정도 약하다 아니다 화하다 느낌 나다 민트 초코 맛 정도',
#  '달콤하다 달콤하다 프로틴 대해 가지 편견 깨지다 음료수 먹다 기분 맛있다 먹다 으로도 계속 이용 계획',
#  '너무 맛 좋다 가성비 짱 맛있다 가성비 이네 생각 보다 엄청 많다 감사하다',
#  '맛 먹다 마다 죄책감 느껴지다 맛 너무 맛있다 아니다 초코 스트로베리 강추 말차 그냥 쏘다 쏘다',
#  '항상 먹다 건데 당연하다 좋다 가성비 무맛 최고',
#  '항상 애용 마이 프로틴 임팩트 웨이 느끼하다 풀림 좋다 맛 여러 가지 라서 질리 먹다',
#  '맛 잇다 개인 마프 맛 블루베리 치즈 케익 제일 맛있다 초코 딸기 블루베리 먹다 보다 입맛 블루베리 치즈 케익 맛 잇다 참고 레이 임팩트 웨이 프로틴 이랑 맛 여도 레이 틀다 맛 씁쓸하다 맛 느끼다 맛 일반 웨이 프로틴 맛 잇다 때문 인지 유제품 섞이다 그렇다 늘다 자다 모르다',
#  '너무 감동 맛 맛있다 배송 만에 오다 너무 감사하다 프로틴 하루 먹다 남다 사랑 마이 프로틴',
#  '맛 먹다 느끼하다 자다 풀어지다 보다 맛 예요',
#  '스트로 배리 크림 맛 살다 고민 리뷰 스트로베리 크림 추천 많다 주문 해봤다 먹다 보다 사람 많이 주문 지다 맛 이고 효과 좋다 제일 크다 다시 주문 강추',
#  '먹다 재활 블루베리 치즈케이크 맛 구매 지금 사고 재활 인데 재활 운동 꾸준하다 먹다 먹다 민트 초코 맛 입맛 맛있다 나름 괜찮다 가격 품질 만족하다',
#  '생각 보다 아주 좋다 딸기 맛 처음 먹다 보다 생각 보다 질리 낳다 먹다 싫어하다 단맛 강하다 느껴지다 먹다 근육 빵빵',
#  '마프 프로틴 먹다 가격 품질 맛 좋다',
#  '맛있다 단백질 보충 처음 먹다 보다 맛있다 먹기 쉽다 가성비 좋다',
#  '최고 스트로베리 크림 맛 최고',
#  '민초 맛있다 입맛 까다롭다 일지 모르다 맛있다 구매 이니 만큼 걱정 많다 프로틴 맛 싸구려 민트 초코 라고 불안하다 한텐 프로 맛 모르다 알다 민트 초코 맛 이라 겁나다 좋다 살다',
#  '만족 맛 좋다 냄새 좋다 여러 모로 마음 듭니 저렴하다 좋다',
#  '너무 맛 나다 좋다 너무 맛있다 좋다 근데 입맛 에는 우유 보다 먹다 맛있다 부담 없다 우유 쌉싸름하다 맛 살짝 꺼지다',
#  '마이 프로틴 스트로베리 크림 후기 지금 운동 프로틴 먹다 지다 확실하다 부족하다 프로틴 보충 운동 으로도 효과 나타나다 우유 항상 먹다 가루 자다 풀리다 맛 정말 맛있다 달다 달다 먹다 정도 아니다 기준 먹기 미리 주문 놓다',
#  '너무 좋다 가성비 너무 좋다 품질 너무 좋다 양도 많다 먹다 모르다 먹다 나서다 구미',
#  '다양하다 맛 이라 좋다 빨리 흡수 대서 먹다 나다 금방 배고프다 다양하다 맛 이라 좋다 개정 도의 맛 먹다 보다 피치 피치 보다는 복숭아 라떼 느낌 애플 크다 럼블 커스터드 록키 로드 개인 으론 맛있다',
#  '',
#  '베드 홋카이도 우유 맛 사다 우유 맛 먹다 느끼하다 초코 맛 이랑 섞다 먹다 맛있다 지다',
#  '가성비 가격 대비 좋다 트러블 없이 자다 먹다',
#  '와우 맛 역시 성비 마프 맛있다 더더 좋다',
#  '마프 성비 역시 성비 마프 맛있다 더더 좋다',
#  '마프 성비 역시 성비 마프 맛있다 더더 좋다',
#  '추천 맛 좋다 성장 에도 도움 많이',
#  '우유 먹다 레알 밀크티 먹다 맛 임존 맛',
#  '민초 초코 민트 맛 무조건 들다 맛 초코 달달 맛 상쾌하다 느껴지다 초단 라면 당연하다 선택 맛 이라고 단언 추가 마이 프로틴 먹다 따다 제품 다도 안보 주변 인들 추천 하고 초코 민트',
#  '가성비 최강 마이 프로틴 항상 마이 프로틴 구매 좋다 품질 저렴하다 가격 맛 좋다',
#  '맛있다 지인 추천 받다 사다 배송 정말 오래 걸리다 먹다 자다 섞이다 맛 좋다 편하다 재다 의사',
#  '맛있다 우유 먹다 맛 살다 보통 그냥 들이다 려고 마시기 풀림 좋다 맛있다 초코바나나 골든 시럽 나서다 먹기 힘들다',
#  '솔직하다 초코바나나 가장 자다 풀리다 맛 좋다 스트로베리 크림 사다 풀리다 처리',
#  '그렇다 가성비 좋다 그렇다 가성비 최고 보충 추천 여태 먹다 보다 쿠키 크림 스트로베리 크림 복숭아 무맛 요즘 아침 그릭 요거트 쿠키 크림 맛 보충 섞다 먹다 맛 먹다 싶다 맛 아침 대용 추천',
#  '맛있다 여러 보충 먹다 보다 맛있다 오다 비교 전혀 꾸다 에도 자다 녹다 초코 브라우니 맛 강추',
#  '네추럴 초콜렛 헬린 이고 처음 단백질 보충 먹다 보다 맛 종류 어마 제일 많이 먹다 추럴 초콜렛 사다 운동 하고 먹다 맛 요즘 뭔가 인지 모르다 근육 빨리 올라오다 느낌 맛 최고 예요 초코 맛',
#  '먹다 아프다 없다 자다 맞다 처음',
#  '웨이 프로틴 가성비 굳다 가격 대비 맛 이랑 차다 좋다 에게나 추천 제품',
#  '가성비 굿맛 아무리 생각 초코 카라멜 무난 맛있다 원하다 맛 사다',
#  '운동 먹다 맛있다 좋다',
#  '너무 좋다 성장 필수 추천',
#  '말차 라떼 맛있다 녹차 덕후 라서 키로 사보다 맛있다 달달 녹차 프라 푸르다 푸다 얼음 이랑 섞다 먹다',
#  '가장 맛있다 좋다 프로틴 여러 계열 프로틴 먹다 보기 마이 프로틴 가장 맛있다 근육 자다 붙다 맛 초콜릿 스무디 스트로베리 계열 주로 먹다 추천 맛',
#  '',
#  '남자친구 추천 해주다 먹다 중인 프로틴 만들다 주다 감사하다 마이 프로틴',
#  '보충 스트로베리 라떼 맛 제일 무난 하고 맛있다 주문 우유 태우다 먹다 진짜 카페 팔다 딸기 쉐이크 맛 태우다 먹다 엄청 맛있다',
#  '맛있다 골든 시럽 마차 라떼 맛 너무 맛있다 후회',
#  '맛있다 식단 챙기다 먹다 업무 많아지다 프로틴 구매 프로틴 처음 이라 무난 초코 스무 스시 켜다 먹다 맛있다 없다 여드름 이나 드름 나다 좋다',
#  '가성비 짱짱 스트로베리 크림 맛있슴돠',
#  '먹다 보다 후기 솔티드 캬라멜 자다 녹지 거품 많이 나다 맛 취향 맛 내추럴 초콜릿 자다 녹지 자다 흔들다 거품 적다 맛 진짜 맛있다 먹기 편하다 자다 녹다 거품 적다 맛 진하다 녹차 맛 스트로베리 크림 자다 녹다 거품 적다 맛 달달 딸기 우유 달다 싫어하다 스쿱 기준',
#  '역시 초코 맛 사다 역시 맛있다',
#  '최고 맛 최고 풀림 좋다 최고 예요 에는 믿다 구매 겁니다',
#  '구매 대다 만족 맛 프로틴 외국 사라 라는 따르다 마이 프로틴 방문 스트로베리 크림 맛 짜다 사다 할인 많이 돼다 두고두고 먹기 좋다 로라 엄청 많다 얼른 먹다 맛 먹다 보고 싶다',
#  '맛 고르다 정말 힘들다 초콜렛 계열 아니다 라떼 스트로베리 크림 골든 시럽 이렇게 추천',
#  '유통 기한 짧다 오다 걱정 늘다 기다 오다 좋다 스트로베리 크림 맛 너무 맛있다 배송 걸리다 좋다 가성비 높다 점수 주다 싶다',
#  '프로틴 초콜렛 초보 라면 내추럴 초콜렛 갈다 추천',
#  '임펙트 웨이 프로틴 무맛 대한 후기 너무 좋다 걱정 우유 섞이다 맛 정도 생각 구매 게요',
#  '펙트 웨이 프로틴 가성비 좋다 백질',
#  '마이 프로틴 임팩트 웨이 처음 시도 단백질 쉐이크 인데 마이 프로틴 결정 정말 자다 제품 후기 보다 너무 인공 향 만들다 내다 먹기 힘들다 의견 많다 마이 프로틴 제품 전혀 그렇다 불편하다 없다 좋다 넉넉하다 먹기 충분하다 들다 계량 스쿱 편리하다',
#  '시나몬 데니 단호박 이랑 먹다 충격 맛있다',
#  '말차 최고 지금 먹다 보다 보충 제일 질리 보충 먹다 느낌 그만큼 오래 먹다 거부 없다 우유 먹다 맛',
#  '프로틴 항상 먹다 프로틴 없다 아주 좋다 건강하다 운동 생활',
#  '자다 구매 간편하다 좋다 가격 할인 자다 막입 이라서 맛 괜찮다',
#  '내츄럴 초코 내츄럴 스트로베리 주문 먹다 크다 부담 없다 딸기 맛 거품 많이 나다 맛 자체 무난 하고 가성비 좋다 먹다 마음 듭니 회사 프로틴 이랑 성분 차이 떨어지다 맛 이랑 풀림 생각 제품 이라고 알려지다 프로틴 뽑다 정도 늘다 부분 감안 자다 선택']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %matplotlib inline
def displayWordCloud(data = None, backgroundcolor = 'white', width=None, height=None):
    wordcloud = WordCloud(font_path= '/content/drive/MyDrive/malgun.ttf',
                          background_color = backgroundcolor,
                          width = width,
                          height = height).generate(data)
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
displayWordCloud(data = ' '.join(words_list), width=600, height=400)
