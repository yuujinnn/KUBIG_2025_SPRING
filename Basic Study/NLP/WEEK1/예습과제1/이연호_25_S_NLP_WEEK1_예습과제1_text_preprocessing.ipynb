# %% [markdown]
# ##0. GOAL
# 승현은 부쩍 헬스에 관심이 많이 생겼다고 합니다.
# 주변 헬스인들에게 이 사실을 알리니, 프로틴 보충제 사이트를 추천해주더군요.
#
# 며칠 전 텍스트 전처리를 배운 동주는 해당 사이트에서 보충제 리뷰를 크롤링해와 워드클라우드를 그려보기로 결심합니다.
#
# 파이프라인은 다음과 같습니다.
#
#  1. 정규표현식으로 한글만 추린다
#  2. 띄어쓰기를 교정한다(PyKospacing)
#  3. 형태소로 토큰화한다(okt)
#  4. 불용어를 제거한다
#  5. 원하는 단어를 Konlpy 사전에 추가한다
#  6. 워드클라우드를 그린다

# %% [markdown]
# ##1. import, load data

# %%
# !pip install konlpy
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-a6jjdkvq
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-a6jjdkvq
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit b32a889cbd10b006d2f4aba118f0cd5b677e2979
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=2.16.2 in /usr/local/lib/python3.10/dist-packages (from pykospacing==0.5) (2.17.1)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from pykospacing==0.5) (3.12.1)
# Collecting argparse>=1.1.0 (from pykospacing==0.5)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from h5py>=3.10.0->pykospacing==0.5) (1.26.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.16.2->pykospacing==0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.16.2->pykospacing==0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->pykospacing==0.5) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=2.16.2->pykospacing==0.5) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow>=2.16.2->pykospacing==0.5) (0.1.2)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import pandas as pd
import numpy as np
import re
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/KU-BIG/KUBIG_2024_SPRING/main/BASIC%20STUDY/NLP/WEEK1/protein.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            title  \
# 0           0  처음 사먹어 보는데 맛있네요
# 1           1   말해 뭐합니까 ㅋㅋㅋ 역시
# 2           2              좋넹요
# 3           3         매우 만족합니다
# 4           4             마싯어요
#
#                                              content  \
# 0                              맛이 좋아서 꾸준히 먹고 있습니다.^^
# 1  가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있습니다요! \n\n    ...
# 2              맛있습니다. 저번에 말차라떼도 먹어봤는데 그것보다 더 나은거 같네요
# 3  5키로는 정말 엄청크네요.\n    평점이 좋아서 스트로베리크림으로 주문했는데 좋습...
# 4                   약간 달긴 하지만 물에 잘 녹고 가루날림이 거의없어 좋아요
#
#                                                 text
# 0               처음 사먹어 보는데 맛있네요맛이 좋아서 꾸준히 먹고 있습니다.^^
# 1  말해 뭐합니까 ㅋㅋㅋ 역시가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있...
# 2           좋넹요맛있습니다. 저번에 말차라떼도 먹어봤는데 그것보다 더 나은거 같네요
# 3  매우 만족합니다5키로는 정말 엄청크네요.\n    평점이 좋아서 스트로베리크림으로 ...
# 4               마싯어요약간 달긴 하지만 물에 잘 녹고 가루날림이 거의없어 좋아요

# %% [markdown]
# ## 2. 정규표현식으로 한글 단어만 남기기
#
# 이제 정규표현식으로 한글 단어만 남기고 모두 제외합니다.

# %%
def extract_hangul(text):
  hangul = re.sub('[^가-힣]', ' ', text)
  return hangul

# %%
example = extract_hangul(df['text'][1])
print("전처리 이전: ",df['text'][1])
print("전처리 이후: ",example)
# Out:
# 전처리 이전:  말해 뭐합니까 ㅋㅋㅋ 역시가성비 갑 제품 + 맛도 다양해서 ㅋㅋㅋ 항상 구매하고 있습니다요!
#
#     스트로베리 크림치즈가 가장 맛있었네요!
# 전처리 이후:  말해 뭐합니까     역시가성비 갑 제품   맛도 다양해서     항상 구매하고 있습니다요        스트로베리 크림치즈가 가장 맛있었네요

# %% [markdown]
# ## 3. 띄어쓰기 교정(PyKoSpacing)
#
# `PyKoSpacing`은 띄어쓰기가 되지 않은 문장을 띄어쓰기가 된 문장으로 교정해주는 패키지입니다다. 앞서 한글 외 다른 문자를 공백으로 치환했는데, 중첩된 공백들도 이 띄어쓰기 교정으로 하나의 공백으로 바꿔줄 수 있습니다.

# %%
from pykospacing import Spacing
spacing = Spacing()

# %%
def spacing_text(text):
  spaced_text = spacing(text)
  return spaced_text

# %%
spaced = spacing_text(example)
print("전처리 이전: ",example)
print("전처리 이후: ",spaced)
# Out:
# 전처리 이전:  말해 뭐합니까     역시가성비 갑 제품   맛도 다양해서     항상 구매하고 있습니다요        스트로베리 크림치즈가 가장 맛있었네요
# 전처리 이후:  말해 뭐 합니까 역시 가성비 갑 제품 맛도 다양해서 항상 구매하고 있습니다 요 스트로베리 크림치즈가 가장 맛있었네요

# %% [markdown]
# ## 4. 형태소 분석기(okt)
#
# 한국어에서 토큰화를 해주는 대표적인 도구는 `konlpy`입니다. 가장 대표적인 형태소 분석기는 `Okt` 모델입니다.

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
def extract_morphs(text):
  morphs_ = okt.morphs(text, stem=True)
  return morphs_

# %%
morphs_ = extract_morphs(spaced)
print("전처리 이전: ",spaced)
print("전처리 이후: ",morphs_)
# Out:
# 전처리 이전:  말해 뭐 합니까 역시 가성비 갑 제품 맛도 다양해서 항상 구매하고 있습니다 요 스트로베리 크림치즈가 가장 맛있었네요
# 전처리 이후:  ['말', '하다', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '있다', '요', '스트로베리', '크림', '치즈', '가', '가장', '맛있다']

# %% [markdown]
# ## 5. 불용어 제거
#
# 분석에 있어 큰 의미가 없는 '불용어(stopword)'를 지정해줘야 합니다. '하다', '도', '는', '이다' 등 의미가 없는 어미나 조사같은 것을 지워주기로 합니다.
#
# 불용어 참고 사이트: https://www.ranks.nl/stopwords/korean
#
# 위 불용어 자료에서 몇 개의 단어를 추가해서 저장해두었습니다.

# %%
with open('/content/drive/MyDrive/stopword.txt') as f:
    list_file = f.readlines()

stopwords_list = []
for stopword in list_file:
  stopwords = re.sub('[\n]', '', stopword)
  stopwords_list.append(stopwords)

def remove_stopwords(text):
  remove_stop = [x for x in text if x not in stopwords_list]
  return remove_stop

# %%
remove_stop = remove_stopwords(morphs_)
print("전처리 이전: ",morphs_)
print("전처리 이후: ",remove_stop)
# Out:
# 전처리 이전:  ['말', '하다', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '있다', '요', '스트로베리', '크림', '치즈', '가', '가장', '맛있다']
# 전처리 이후:  ['말', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '요', '스트로베리', '크림', '치즈', '가장', '맛있다']

# %% [markdown]
# 추가적으로, 불용어로만 걸러내기엔 한계가 있고 아예 한 글자 단어들을 전부 없애주는 것이 나은 경우가 있습니다. 하지만, '맛', '향', '짱'과 같은 핵심적인 단어들은 남겨두기로 했다.

# %%
def remove_one(text):
  except_list = ['맛','향','짱']
  remove_one_ = [x for x in text if len(x)>1 or x in except_list]
  return remove_one_

# %%
remove_one_ = remove_one(remove_stop)
print("전처리 이전: ",remove_stop)
print("전처리 이후: ",remove_one_)
# Out:
# 전처리 이전:  ['말', '뭐', '합', '니까', '역시', '가성비', '갑', '제품', '맛', '도', '다양하다', '항상', '구매', '하고', '요', '스트로베리', '크림', '치즈', '가장', '맛있다']
# 전처리 이후:  ['니까', '역시', '가성비', '제품', '맛', '다양하다', '항상', '구매', '하고', '스트로베리', '크림', '치즈', '가장', '맛있다']

# %% [markdown]
# 그런데 몇 단어들을 찾아보니 `가성비`는 `가`, `성비`가 나뉘고 `프로틴`은 `프로`, `틴`이 나뉘는 안타까운 상황이 발생했습니다.
#
# 이런 경우, konlpy 사전에 직접 단어를 등재시키는 방법이 있습니다.
#
# 아래처럼 `os` 모듈을 사용하여 코랩 패키지에 저장된 konlpy 폴더에 손을 대는 방식입니다.
#
# 우선 `chdir`로 경로를 이동해주고 `makedirs`로 임시폴더를 만들어준 후. 이 임시폴더에서 단어 사전을 수정한 뒤 원본 폴더에 저장해줍니다.
#
# ** FileNotFoundError가 발생하는 경우 아래 directory에서 python 버전이 잘못된 경우일 수 있습니다.

# %%
import os

os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java')
os.getcwd()
os.makedirs('./aaaa')

# %%
os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa') #임시 폴더로 이동
os.getcwd()

# %% [markdown]
# 임시폴더에 konlpy 사전 파일의 압축을 풀어줍니다.

# %%
# !jar xvf ../open-korean-text-2.1.0.jar
# Out:
# java.io.FileNotFoundException: ../open-korean-text-2.1.0.jar (No such file or directory)
# 	at java.base/java.io.FileInputStream.open0(Native Method)
# 	at java.base/java.io.FileInputStream.open(FileInputStream.java:219)
# 	at java.base/java.io.FileInputStream.<init>(FileInputStream.java:157)
# 	at java.base/java.io.FileInputStream.<init>(FileInputStream.java:112)
# 	at jdk.jartool/sun.tools.jar.Main.run(Main.java:413)
# 	at jdk.jartool/sun.tools.jar.Main.main(Main.java:1686)

# %% [markdown]
# 압축이 잘 풀렸으니 이제 명사들이 등재되어 있는 names.txt를 열어봅니다.

# %%
with open(f"/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

# %% [markdown]
# 아래처럼 다양한 단어들이 저장되어있는 것을 볼 수 있다. 여러 사용자들의 니즈를 반영하여 몇 단어들이 추가된 것으로 보입니다.

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n프로틴\n가성비\n밀크티\n'

# %% [markdown]
# 일단 세 개의 단어를 추가해보도록 합시다. 그리고 쓰기 모드로 변경하여 새롭게 파일을 저장합니다.
#
# 예시로는 아래 세 가지 단어를 넣었지만, 여러분께서 마음껏 원하는 단어를 넣어보셔도 좋습니다.

# %%
data += '프로틴\n가성비\n밀크티\n'

with open("/usr/local/lib/python3.10/dist-packages/konlpy/java/aaaa/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)

# %% [markdown]
# 이제 다시 파일을 압축시키면 완료! 런타임을 재실행해야 제대로 반영이 됩니다.

# %%
# !jar cvf ../open-korean-text-2.1.0.jar *
# Out:
# added manifest
# adding: aaaa/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/OpenKoreanTextProcessor$.class(in = 7716) (out= 2400)(deflated 68%)
# adding: aaaa/org/openkoreantext/processor/util/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap$1.class(in = 1531) (out= 571)(deflated 62%)
# adding: aaaa/org/openkoreantext/processor/util/adjective/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/adjective/adjective.txt(in = 27250) (out= 9357)(deflated 65%)
# adding: aaaa/org/openkoreantext/processor/util/Hangul$DoubleCoda$.class(in = 2155) (out= 963)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/util/Hangul.class(in = 3981) (out= 2731)(deflated 31%)
# adding: aaaa/org/openkoreantext/processor/util/Hangul$.class(in = 7625) (out= 3114)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/util/substantives/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/substantives/family_names.txt(in = 299) (out= 197)(deflated 34%)
# adding: aaaa/org/openkoreantext/processor/util/substantives/suffix.txt(in = 325) (out= 224)(deflated 31%)
# adding: aaaa/org/openkoreantext/processor/util/substantives/given_names.txt(in = 1407) (out= 609)(deflated 56%)
# adding: aaaa/org/openkoreantext/processor/util/substantives/modifier.txt(in = 3395) (out= 1346)(deflated 60%)
# adding: aaaa/org/openkoreantext/processor/util/typos/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/typos/typos.txt(in = 5146) (out= 2300)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/util/Hangul$DoubleCoda.class(in = 2930) (out= 1348)(deflated 53%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanDictionaryProvider$.class(in = 20197) (out= 7488)(deflated 62%)
# adding: aaaa/org/openkoreantext/processor/util/CharacterUtils.class(in = 3703) (out= 1716)(deflated 53%)
# adding: aaaa/org/openkoreantext/processor/util/CharArraySet.class(in = 4886) (out= 1944)(deflated 60%)
# adding: aaaa/org/openkoreantext/processor/util/Hangul$HangulChar.class(in = 3185) (out= 1421)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class(in = 4390) (out= 1610)(deflated 63%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap$MapEntry.class(in = 2433) (out= 1078)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanConjugation.class(in = 1550) (out= 1237)(deflated 20%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class(in = 3062) (out= 859)(deflated 71%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanConjugation$.class(in = 22440) (out= 7972)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/util/example_tweets.txt(in = 86271) (out= 38336)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class(in = 3118) (out= 1270)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/util/freq/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/freq/entity-freq.txt.gz(in = 385753) (out= 385873)(deflated 0%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class(in = 3157) (out= 1089)(deflated 65%)
# adding: aaaa/org/openkoreantext/processor/util/noun/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/noun/foreign.txt(in = 10485) (out= 4686)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/util/noun/lol.txt(in = 1337) (out= 744)(deflated 44%)
# adding: aaaa/org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt(in = 1971964) (out= 686708)(deflated 65%)
# adding: aaaa/org/openkoreantext/processor/util/noun/kpop.txt(in = 5371) (out= 2495)(deflated 53%)
# adding: aaaa/org/openkoreantext/processor/util/noun/nouns.txt(in = 219319) (out= 84134)(deflated 61%)
# adding: aaaa/org/openkoreantext/processor/util/noun/spam.txt(in = 202) (out= 157)(deflated 22%)
# adding: aaaa/org/openkoreantext/processor/util/noun/geolocations.txt(in = 5423) (out= 2267)(deflated 58%)
# adding: aaaa/org/openkoreantext/processor/util/noun/bible.txt(in = 2032) (out= 1005)(deflated 50%)
# adding: aaaa/org/openkoreantext/processor/util/noun/congress.txt(in = 26494) (out= 9351)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/util/noun/names.txt(in = 963) (out= 571)(deflated 40%)
# adding: aaaa/org/openkoreantext/processor/util/noun/entities.txt(in = 108142) (out= 44095)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/util/noun/profane.txt(in = 569) (out= 337)(deflated 40%)
# adding: aaaa/org/openkoreantext/processor/util/noun/company_names.txt(in = 1631) (out= 905)(deflated 44%)
# adding: aaaa/org/openkoreantext/processor/util/noun/twitter.txt(in = 254) (out= 162)(deflated 36%)
# adding: aaaa/org/openkoreantext/processor/util/noun/pokemon.txt(in = 1781) (out= 965)(deflated 45%)
# adding: aaaa/org/openkoreantext/processor/util/noun/slangs.txt(in = 1565) (out= 921)(deflated 41%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap$EntrySet.class(in = 2788) (out= 1181)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class(in = 2824) (out= 1393)(deflated 50%)
# adding: aaaa/org/openkoreantext/processor/util/example_chunks.txt(in = 522978) (out= 163253)(deflated 68%)
# adding: aaaa/org/openkoreantext/processor/util/verb/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/verb/verb.txt(in = 32758) (out= 10723)(deflated 67%)
# adding: aaaa/org/openkoreantext/processor/util/verb/verb_prefix.txt(in = 47) (out= 52)(deflated -10%)
# adding: aaaa/org/openkoreantext/processor/util/verb/eomi.txt(in = 12618) (out= 3556)(deflated 71%)
# adding: aaaa/org/openkoreantext/processor/util/verb/pre_eomi.txt(in = 285) (out= 185)(deflated 35%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanSubstantive.class(in = 1336) (out= 1087)(deflated 18%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanPos$.class(in = 12173) (out= 4669)(deflated 61%)
# adding: aaaa/org/openkoreantext/processor/util/Hangul$HangulChar$.class(in = 2389) (out= 1022)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class(in = 1634) (out= 659)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class(in = 2053) (out= 725)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanPos.class(in = 6890) (out= 3877)(deflated 43%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanDictionaryProvider.class(in = 3430) (out= 2003)(deflated 41%)
# adding: aaaa/org/openkoreantext/processor/util/KoreanSubstantive$.class(in = 14990) (out= 6195)(deflated 58%)
# adding: aaaa/org/openkoreantext/processor/util/auxiliary/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/auxiliary/conjunctions.txt(in = 398) (out= 189)(deflated 52%)
# adding: aaaa/org/openkoreantext/processor/util/auxiliary/determiner.txt(in = 63) (out= 63)(deflated 0%)
# adding: aaaa/org/openkoreantext/processor/util/auxiliary/exclamation.txt(in = 1759) (out= 757)(deflated 56%)
# adding: aaaa/org/openkoreantext/processor/util/josa/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/josa/josa.txt(in = 5219) (out= 1476)(deflated 71%)
# adding: aaaa/org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class(in = 2577) (out= 1282)(deflated 50%)
# adding: aaaa/org/openkoreantext/processor/util/adverb/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/util/adverb/adverb.txt(in = 65572) (out= 18741)(deflated 71%)
# adding: aaaa/org/openkoreantext/processor/util/CharArrayMap.class(in = 11923) (out= 4878)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/stemmer/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/stemmer/KoreanStemmer.class(in = 1439) (out= 972)(deflated 32%)
# adding: aaaa/org/openkoreantext/processor/stemmer/KoreanStemmer$.class(in = 7044) (out= 2892)(deflated 58%)
# adding: aaaa/org/openkoreantext/processor/KoreanPosJava.class(in = 2457) (out= 1241)(deflated 49%)
# adding: aaaa/org/openkoreantext/processor/OpenKoreanTextProcessor.class(in = 4428) (out= 1997)(deflated 54%)
# adding: aaaa/org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class(in = 3470) (out= 1422)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/normalizer/KoreanNormalizer.class(in = 2980) (out= 2181)(deflated 26%)
# adding: aaaa/org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class(in = 2577) (out= 989)(deflated 61%)
# adding: aaaa/org/openkoreantext/processor/normalizer/KoreanNormalizer$.class(in = 11553) (out= 5102)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/tools/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class(in = 2516) (out= 1784)(deflated 29%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateConjugationExamples.class(in = 2367) (out= 1659)(deflated 29%)
# adding: aaaa/org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class(in = 7154) (out= 3133)(deflated 56%)
# adding: aaaa/org/openkoreantext/processor/tools/UpdateAllTheExamples$.class(in = 4383) (out= 1794)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class(in = 5487) (out= 2305)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class(in = 3825) (out= 1443)(deflated 62%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class(in = 3718) (out= 1429)(deflated 61%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class(in = 3569) (out= 1415)(deflated 60%)
# adding: aaaa/org/openkoreantext/processor/tools/Runnable.class(in = 964) (out= 694)(deflated 28%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class(in = 833) (out= 566)(deflated 32%)
# adding: aaaa/org/openkoreantext/processor/tools/UpdateAllTheExamples.class(in = 1089) (out= 756)(deflated 30%)
# adding: aaaa/org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class(in = 5989) (out= 2472)(deflated 58%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class(in = 2787) (out= 997)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateParsingExamples$.class(in = 5517) (out= 2327)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateConjugationExamples$.class(in = 5881) (out= 2385)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class(in = 2974) (out= 1020)(deflated 65%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateParsingExamples.class(in = 2427) (out= 1732)(deflated 28%)
# adding: aaaa/org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class(in = 2842) (out= 1010)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class(in = 1117) (out= 823)(deflated 26%)
# adding: aaaa/org/openkoreantext/processor/qa/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class(in = 2376) (out= 952)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchTokenizeTweets$.class(in = 10867) (out= 4401)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class(in = 3080) (out= 1338)(deflated 56%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class(in = 2418) (out= 1015)(deflated 58%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class(in = 3153) (out= 1446)(deflated 54%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchTokenizeTweets.class(in = 2720) (out= 2031)(deflated 25%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchGetUnknownNouns.class(in = 2307) (out= 1702)(deflated 26%)
# adding: aaaa/org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class(in = 1464) (out= 823)(deflated 43%)
# adding: aaaa/org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class(in = 8751) (out= 3532)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/qa/KoreanProcessorSandbox.class(in = 824) (out= 575)(deflated 30%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class(in = 3399) (out= 1429)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer.class(in = 6968) (out= 4384)(deflated 37%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class(in = 1092) (out= 712)(deflated 34%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class(in = 3359) (out= 1497)(deflated 55%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/ParsedChunk$.class(in = 3973) (out= 1500)(deflated 62%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/TokenizerProfile.class(in = 16403) (out= 6666)(deflated 59%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanChunk$.class(in = 2361) (out= 1010)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanChunker.class(in = 4232) (out= 2887)(deflated 31%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class(in = 25564) (out= 8451)(deflated 66%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class(in = 3976) (out= 1402)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class(in = 4043) (out= 1704)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanChunk.class(in = 5611) (out= 2907)(deflated 48%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class(in = 9889) (out= 4174)(deflated 57%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class(in = 2893) (out= 1136)(deflated 60%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/ParsedChunk.class(in = 20517) (out= 8914)(deflated 56%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class(in = 2862) (out= 1067)(deflated 62%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/Sentence.class(in = 5985) (out= 3125)(deflated 47%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class(in = 3459) (out= 1111)(deflated 67%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class(in = 1660) (out= 1133)(deflated 31%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class(in = 6336) (out= 2633)(deflated 58%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanChunker$.class(in = 17975) (out= 6790)(deflated 62%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/Sentence$.class(in = 2339) (out= 1012)(deflated 56%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class(in = 4616) (out= 1645)(deflated 64%)
# adding: aaaa/org/openkoreantext/processor/tokenizer/TokenizerProfile$.class(in = 8169) (out= 2408)(deflated 70%)
# adding: aaaa/org/openkoreantext/processor/KoreanTokenJava.class(in = 1976) (out= 931)(deflated 52%)
# adding: aaaa/org/openkoreantext/processor/OpenKoreanTextProcessorJava.class(in = 5901) (out= 1995)(deflated 66%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class(in = 3358) (out= 1148)(deflated 65%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class(in = 6005) (out= 3967)(deflated 33%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class(in = 3564) (out= 1087)(deflated 69%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class(in = 4857) (out= 1609)(deflated 66%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class(in = 37855) (out= 12404)(deflated 67%)
# adding: aaaa/org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class(in = 6942) (out= 2591)(deflated 62%)
# adding: aaaa/META-INF/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/META-INF/MANIFEST.MF(in = 133) (out= 111)(deflated 16%)
# adding: aaaa/META-INF/maven/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/META-INF/maven/org.openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/META-INF/maven/org.openkoreantext/open-korean-text/(in = 0) (out= 0)(stored 0%)
# adding: aaaa/META-INF/maven/org.openkoreantext/open-korean-text/pom.properties(in = 119) (out= 110)(deflated 7%)
# adding: aaaa/META-INF/maven/org.openkoreantext/open-korean-text/pom.xml(in = 9127) (out= 2208)(deflated 75%)
# adding: aho-corasick.jar(in = 79138) (out= 76068)(deflated 3%)
# adding: bin/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/okt/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/okt/OktInterface.class(in = 3075) (out= 1460)(deflated 52%)
# adding: bin/kr/lucypark/jhannanum/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/jhannanum/hannanum/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/jhannanum/hannanum/WorkflowFactory.class(in = 2931) (out= 1095)(deflated 62%)
# adding: bin/kr/lucypark/jhannanum/comm/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/jhannanum/comm/HannanumInterface.class(in = 3352) (out= 1633)(deflated 51%)
# adding: bin/kr/lucypark/kkma/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/kkma/KkmaInterface$3.class(in = 469) (out= 312)(deflated 33%)
# adding: bin/kr/lucypark/kkma/KkmaInterface$1.class(in = 453) (out= 297)(deflated 34%)
# adding: bin/kr/lucypark/kkma/KkmaInterface$4.class(in = 471) (out= 305)(deflated 35%)
# adding: bin/kr/lucypark/kkma/KkmaInterface.class(in = 2762) (out= 1476)(deflated 46%)
# adding: bin/kr/lucypark/kkma/KkmaInterface$2.class(in = 455) (out= 291)(deflated 36%)
# adding: bin/kr/lucypark/komoran/(in = 0) (out= 0)(stored 0%)
# adding: bin/kr/lucypark/komoran/KomoranInterface.class(in = 2460) (out= 1213)(deflated 50%)
# adding: conf/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/SupplementPlugin/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/SupplementPlugin/PosProcessor/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/SupplementPlugin/PosProcessor/SimplePOSResult22.json(in = 858) (out= 541)(deflated 36%)
# adding: conf/plugin/SupplementPlugin/PosProcessor/SimplePOSResult09.json(in = 592) (out= 420)(deflated 29%)
# adding: conf/plugin/SupplementPlugin/PosProcessor/NounExtractor.json(in = 319) (out= 244)(deflated 23%)
# adding: conf/plugin/SupplementPlugin/PlainTextProcessor/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/SupplementPlugin/PlainTextProcessor/SentenceSegmentor.json(in = 886) (out= 515)(deflated 41%)
# adding: conf/plugin/SupplementPlugin/PlainTextProcessor/InformalSentenceFilter.json(in = 950) (out= 568)(deflated 40%)
# adding: conf/plugin/SupplementPlugin/MorphemeProcessor/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/SupplementPlugin/MorphemeProcessor/UnknownMorphProcessor.json(in = 457) (out= 332)(deflated 27%)
# adding: conf/plugin/SupplementPlugin/MorphemeProcessor/SimpleMAResult22.json(in = 943) (out= 594)(deflated 37%)
# adding: conf/plugin/SupplementPlugin/MorphemeProcessor/SimpleMAResult09.json(in = 677) (out= 468)(deflated 30%)
# adding: conf/plugin/MajorPlugin/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/MajorPlugin/PosTagger/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/MajorPlugin/PosTagger/HmmPosTagger.json(in = 1216) (out= 640)(deflated 47%)
# adding: conf/plugin/MajorPlugin/MorphAnalyzer/(in = 0) (out= 0)(stored 0%)
# adding: conf/plugin/MajorPlugin/MorphAnalyzer/ChartMorphAnalyzer.json(in = 2203) (out= 1085)(deflated 50%)
# adding: data/(in = 0) (out= 0)(stored 0%)
# adding: data/models/(in = 0) (out= 0)(stored 0%)
# adding: data/models/transition.model(in = 6703) (out= 6708)(deflated 0%)
# adding: data/models/observation.model(in = 2933941) (out= 2933253)(deflated 0%)
# adding: data/models/irregular.model(in = 191851) (out= 191911)(deflated 0%)
# adding: data/models/pos.table(in = 295) (out= 205)(deflated 30%)
# adding: data/stat/(in = 0) (out= 0)(stored 0%)
# adding: data/stat/PWT.pos(in = 190722) (out= 45476)(deflated 76%)
# adding: data/stat/__init__.py(in = 0) (out= 0)(stored 0%)
# adding: data/stat/PTT.pos(in = 12165) (out= 5153)(deflated 57%)
# adding: data/stat/PTT.wp(in = 24368) (out= 10707)(deflated 56%)
# adding: data/stat/__pycache__/(in = 0) (out= 0)(stored 0%)
# adding: data/stat/__pycache__/__init__.cpython-310.pyc(in = 166) (out= 133)(deflated 19%)
# adding: data/kE/(in = 0) (out= 0)(stored 0%)
# adding: data/kE/connections.txt(in = 1923) (out= 620)(deflated 67%)
# adding: data/kE/__init__.py(in = 0) (out= 0)(stored 0%)
# adding: data/kE/connections_not.txt(in = 211) (out= 167)(deflated 20%)
# adding: data/kE/tag_set.txt(in = 4035) (out= 1436)(deflated 64%)
# adding: data/kE/dic_analyzed.txt(in = 13231) (out= 3664)(deflated 72%)
# adding: data/kE/dic_system.txt(in = 4602635) (out= 1153147)(deflated 74%)
# adding: data/kE/dic_user.txt(in = 167) (out= 135)(deflated 19%)
# adding: data/kE/__pycache__/(in = 0) (out= 0)(stored 0%)
# adding: data/kE/__pycache__/__init__.cpython-310.pyc(in = 164) (out= 131)(deflated 20%)
# adding: jhannanum-0.8.4.jar(in = 164665) (out= 151367)(deflated 8%)
# adding: kkma-2.0.jar(in = 7722928) (out= 7707040)(deflated 0%)
# adding: komoran-3.0.jar(in = 133514) (out= 119633)(deflated 10%)
# adding: open-korean-text-2.1.0.jar(in = 1739042) (out= 1716673)(deflated 1%)
# adding: scala-library-2.12.3.jar(in = 5246851) (out= 4880676)(deflated 6%)
# adding: shineware-common-1.0.jar(in = 39039) (out= 34907)(deflated 10%)
# adding: shineware-ds-1.0.jar(in = 14396) (out= 11874)(deflated 17%)
# adding: snakeyaml-1.12.jar(in = 270779) (out= 236161)(deflated 12%)
# adding: twitter-text-1.14.7.jar(in = 50722) (out= 47116)(deflated 7%)

# %% [markdown]
# 원래 두 단어로 나뉘어서 나오던 것들이 올바르게 한 단어로 출력되는 것을 볼 수 있습니다.

# %%
print(okt.nouns("가성비"))
print(okt.nouns("프로틴"))
# Out:
# ['가성비']
# ['프로틴']

# %% [markdown]
# 전 과정을 하나로 통합하면 아래와 같습니다.

# %%
from konlpy.tag import Okt
okt = Okt()

from pykospacing import Spacing
spacing = Spacing()

except_list = ['맛','향','짱']

with open('/content/drive/MyDrive/stopword.txt') as f:
    list_file = f.readlines()

stopwords_list = []
for stopword in list_file:
  stopwords = re.sub('[\n]', '', stopword)
  stopwords_list.append(stopwords)

def review_to_words(raw_review):
  text = re.sub('[^가-힣]', ' ', raw_review)
  text = spacing(text)
  text = okt.morphs(text, stem=True)
  text = [x for x in text if x not in stopwords_list]
  text = [x for x in text if len(x)>1 or x in except_list]
  text = " ".join(text)
  return text

# %% [markdown]
# 이제 `words_list`를 만들어 전처리한 단어들을 하나의 리스트에 모아줍니다. 띄어쓰기 교정 과정에서 약간 지연됩니다.

# %%
import tqdm
df_len = df.shape[0]
words_list = []
for i in range(df_len):
  words_list.append(review_to_words(df['text'][i]))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %matplotlib inline
def displayWordCloud(data = None, backgroundcolor = 'white', width=None, height=None):
    wordcloud = WordCloud(font_path = '/content/drive/MyDrive/MALGUN.TTF',
                          background_color = backgroundcolor,
                          width = width,
                          height = height).generate(data)
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
displayWordCloud(data = ' '.join(words_list), width=600, height=400)
